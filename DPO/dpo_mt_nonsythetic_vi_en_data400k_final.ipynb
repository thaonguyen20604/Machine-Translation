# %% [markdown]
# #### Library

# %%
import os
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import copy
import math
import numpy as np

# %% [markdown]
# #### Load dataset

# %%
from datasets import load_dataset

ds = load_dataset("Eugenememe/mix-en-vi-500k")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# train.json:   0%|          | 0.00/183M [00:00<?, ?B/s]
# validation.json:   0%|          | 0.00/20.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/495942 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/55105 [00:00<?, ? examples/s]

# %%
print(ds.keys())
print(ds)
# Out:
# dict_keys(['train', 'validation'])
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 495942
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 55105
#     })
# })

# %%
def convert_data(example):
    return {
        "English": example["translation"]["en"],
        "Vietnamese": example["translation"]["vi"],
    }
ds = ds.map(convert_data)
# Out:
# Map:   0%|          | 0/495942 [00:00<?, ? examples/s]
# Map:   0%|          | 0/55105 [00:00<?, ? examples/s]

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation', 'English', 'Vietnamese'],
#         num_rows: 495942
#     })
#     validation: Dataset({
#         features: ['translation', 'English', 'Vietnamese'],
#         num_rows: 55105
#     })
# })

# %%
from datasets import DatasetDict

train_valid = ds  # dataset bạn đang có

train_test = train_valid["train"].train_test_split(
    test_size=0.1,
    seed=42
)

train = train_test["train"]          # 90% của train gốc
test  = train_test["test"]           # 10% của train gốc
valid = train_valid["validation"]    # giữ nguyên validation

new_ds = DatasetDict({
    "train": train,
    "validation": valid,
    "test": test
})

new_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation', 'English', 'Vietnamese'],
#         num_rows: 446347
#     })
#     validation: Dataset({
#         features: ['translation', 'English', 'Vietnamese'],
#         num_rows: 55105
#     })
#     test: Dataset({
#         features: ['translation', 'English', 'Vietnamese'],
#         num_rows: 49595
#     })
# })

# %%
new_ds = DatasetDict({
    "train": new_ds["train"].remove_columns(["translation"]),
    "validation": new_ds["validation"].remove_columns(["translation"]),
    "test": new_ds["test"].remove_columns(["translation"]),
})
new_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['English', 'Vietnamese'],
#         num_rows: 446347
#     })
#     validation: Dataset({
#         features: ['English', 'Vietnamese'],
#         num_rows: 55105
#     })
#     test: Dataset({
#         features: ['English', 'Vietnamese'],
#         num_rows: 49595
#     })
# })

# %%
train_df = pd.DataFrame(new_ds['train'])
val_df = pd.DataFrame(new_ds['validation'])
test_df = pd.DataFrame(new_ds['test'])

print("Train DataFrame head:")
display(train_df.head())
# Out:
# Train DataFrame head:
#                                              English  \
# 0  The book is most famous for its vivid , arguab...
# 1  The post-1945 borders meant that the need for ...
# 2  Robertson went on to establish the first blood...
# 3  Research local : Banquet halls Union halls Chu...
# 4  The Princess Palatine was Henrietta 's first c...
#
#                                           Vietnamese
# 0  Cuốn sách nổi tiếng về tính sáng sủa , bị cho ...
# 1  Biên giới sau năm 1945 khiến nhu cầu kết nối đ...
# 2  Robertson tiếp tục thành lập bộ máy truyền máu...
# 3  Hãy tìm hiểu những cơ sở sau tại địa phương : ...
# 4  Công chúa Palatine là anh em họ đầu tiên của H...

# %% [markdown]
# #### EDA Original Data

# %% [markdown]
# ##### Overview for 3 `train`, `valid`, and `test`

# %%
def eda_basic(df, split_name):
    print(f"\n===== {split_name.upper()} SET =====")

    # Thông tin tổng quan
    print("\nDataFrame Info:")
    print(df.info())

    # Kiểm tra giá trị thiếu
    print("\nMissing values per column:")
    print(df.isnull().sum())

    # Kiểm tra dòng trùng lặp
    print("\nTotal duplicate rows:")
    print(df.duplicated().sum())

    # In vài dòng đầu tiên để xem cấu trúc
    print("\nSample data:")
    display(df.head())

# %%
eda_basic(train_df, "train_df")
eda_basic(val_df, "validation")
eda_basic(test_df, "test")
# Out:
# ===== TRAIN_DF SET =====
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 446347 entries, 0 to 446346
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   English     446347 non-null  object
#  1   Vietnamese  446347 non-null  object
# dtypes: object(2)
# memory usage: 6.8+ MB
# None
#
# Missing values per column:
# English       0
# Vietnamese    0
# dtype: int64
#
# Total duplicate rows:
# 4129
#
# Sample data:
#                                              English  \
# 0  The book is most famous for its vivid , arguab...
# 1  The post-1945 borders meant that the need for ...
# 2  Robertson went on to establish the first blood...
# 3  Research local : Banquet halls Union halls Chu...
# 4  The Princess Palatine was Henrietta 's first c...
#
#                                           Vietnamese
# 0  Cuốn sách nổi tiếng về tính sáng sủa , bị cho ...
# 1  Biên giới sau năm 1945 khiến nhu cầu kết nối đ...
# 2  Robertson tiếp tục thành lập bộ máy truyền máu...
# 3  Hãy tìm hiểu những cơ sở sau tại địa phương : ...
# 4  Công chúa Palatine là anh em họ đầu tiên của H...
# ===== VALIDATION SET =====
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55105 entries, 0 to 55104
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   English     55105 non-null  object
#  1   Vietnamese  55105 non-null  object
# dtypes: object(2)
# memory usage: 861.1+ KB
# None
#
# Missing values per column:
# English       0
# Vietnamese    0
# dtype: int64
#
# Total duplicate rows:
# 145
#
# Sample data:
#                                              English  \
# 0  Nintendo later released the Nintendo Channel ,...
# 1  'Cause, baby, you know I'd do anything for you...
# 2  If you're gonna treat me like an insane person...
# 3  In northern and western Europe, vegetable prod...
# 4  Was it a truth serum that could be used in int...
#
#                                           Vietnamese
# 0  Nintendo sau đó phát hành kênh Nintendo , cho ...
# 1  Vì anh biết đấy cưng, em sẽ làm mọi thứ vì anh...
# 2  Nếu anh định đối xử với em như kẻ mất trí và b...
# 3  Ở Bắc và Tây Âu, các nhà sản xuất rau có thể t...
# 4  Nó có thể là thuốc sự thật có thể dùng trong t...
# ===== TEST SET =====
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49595 entries, 0 to 49594
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   English     49595 non-null  object
#  1   Vietnamese  49595 non-null  object
# dtypes: object(2)
# memory usage: 775.1+ KB
# None
#
# Missing values per column:
# English       0
# Vietnamese    0
# dtype: int64
#
# Total duplicate rows:
# 122
#
# Sample data:
#                                              English  \
# 0    Lieutenant, Robbery-Homicide, Major Crime Unit.
# 1                    It's all right. It's all right.
# 2  As with most exoplanets , the name " Kepler - ...
# 3  Jerry's staying on, so do your best not to eng...
# 4  Characteristic of the remaining bronze periods...
#
#                                           Vietnamese
# 0  Trung úy, Ban trộm cắp và giết người. Đơn vị T...
# 1                                 Ổn mà. Sẽ ổn thôi.
# 2  Như với hầu hết các ngoại hành tinh , cái tên ...
# 3    Anh ấy ở lại, cố gắng đừng đánh động tới cô bé.
# 4  Đặc trưng của các thời kỳ đồ đồng còn lại là n...

# %% [markdown]
# ##### Detail for `train` dataset

# %% [markdown]
# Phân bố độ dài câu

# %%
train_df['en_len'] = train_df['English'].apply(lambda x: len(x.split()))
train_df['vi_len'] = train_df['Vietnamese'].apply(lambda x: len(x.split()))

plt.figure(figsize=(10,5))
plt.hist(train_df['en_len'], bins=50, alpha=0.6, label='English')
plt.hist(train_df['vi_len'], bins=50, alpha=0.6, label='Vietnamese')
plt.xlabel("Sentence Length (words)")
plt.ylabel("Count")
plt.legend()
plt.title("Distribution of Sentence Lengths (English vs Vietnamese)")
plt.show()

# %% [markdown]
# Tỷ lệ độ dài En/Vi (độ khớp giữa 2 ngôn ngữ)

# %%
train_df['len_ratio'] = train_df['vi_len'] / train_df['en_len']
sns.histplot(train_df['len_ratio'], bins=50)
plt.title("Length Ratio (Vietnamese / English)")
plt.xlabel("Ratio")
plt.ylabel("Count")
plt.show()

# %%
# Cặp có độ lệch lớn
outliers = train_df[(train_df['len_ratio'] == 3.0)]

# In tổng số cặp bị lệch
# print(f"Tổng số cặp bị lệch độ dài: {len(outliers)}")

# Hiển thị vài ví dụ đầu
from IPython.display import display
display(outliers[['English', 'Vietnamese', 'en_len', 'vi_len', 'len_ratio']].head(10))
# Out:
#               English            Vietnamese  en_len  vi_len  len_ratio
# 143     -Yeah. -Boys?  - Ừ. - Con trai nhỉ?       2       6        3.0
# 370           Thanks.           Cảm ơn anh.       1       3        3.0
# 764   intimidation...          sự đe dọa...       1       3        3.0
# 1235         Anybody?        Ai biết không?       1       3        3.0
# 1367          Please.            Làm ơn đi.       1       3        3.0
# 2082    -Yeah. -Yeah.      - Có ạ. - Thế à?       2       6        3.0
# 2438    Motherfucker.        Thằng súc vật.       1       3        3.0
# 2962      Podiatrist.          Bác sĩ chân.       1       3        3.0
# 4638          Please.            Làm ơn đi.       1       3        3.0
# 4883      Reciprocal.          Hỗ trợ nhau.       1       3        3.0

# %% [markdown]
# Thống kê mô tả độ dài (mean, median, std)

# %% [markdown]
# Mục đích của thống kê này là để chọn tham số max_length hợp lý khi tokenize. Khi huấn luyện mô hình dịch (như ViT5, mT5, MarianMT) cần phải đặt tham số max_length.
#  * Nếu max_length quá thấp → cắt mất nội dung câu.
#  * Nếu quá cao → lãng phí bộ nhớ, tốc độ train chậm.

# %%
print("English length stats:")
print(train_df['en_len'].describe())

print("\nVietnamese length stats:")
print(train_df['vi_len'].describe())
# Out:
# English length stats:
# count    446347.000000
# mean         24.260239
# std          16.434104
# min           1.000000
# 25%          12.000000
# 50%          22.000000
# 75%          33.000000
# max         241.000000
# Name: en_len, dtype: float64
#
# Vietnamese length stats:
# count    446347.000000
# mean         30.471071
# std          21.312977
# min           1.000000
# 25%          13.000000
# 50%          28.000000
# 75%          41.000000
# max         262.000000
# Name: vi_len, dtype: float64

# %% [markdown]
# Từ phổ biến nhất (Word Frequency)

# %%
en_words = ' '.join(train_df['English']).split()
vi_words = ' '.join(train_df['Vietnamese']).split()

en_common = Counter(en_words).most_common(20)
vi_common = Counter(vi_words).most_common(20)

pd.DataFrame(en_common, columns=['Word', 'Count']).plot.bar(x='Word', y='Count', title='Top 20 English Words', figsize=(10,4))
pd.DataFrame(vi_common, columns=['Word', 'Count']).plot.bar(x='Word', y='Count', title='Top 20 Vietnamese Words', figsize=(10,4))
plt.show()

# %% [markdown]
# Heatmap tương quan độ dài En–Vi

# %%
plt.figure(figsize=(6,6))
plt.hexbin(train_df['en_len'], train_df['vi_len'], gridsize=40, cmap='Blues', mincnt=1)
plt.xlabel('English length')
plt.ylabel('Vietnamese length')
plt.title('Length Correlation: English vs Vietnamese')
plt.colorbar(label='Count')
plt.show()

# %% [markdown]
# Phân bố chính tập trung gần đường chéo (y ≈ x). Điều này cho thấy độ dài câu giữa hai ngôn ngữ có mối tương quan tuyến tính mạnh. Khi câu tiếng Anh dài hơn, câu tiếng Việt cũng dài hơn tương ứng.
#
# Phần lớn dữ liệu tập trung tại vùng 5–15 (English) và 7–20 (Vietnamese). Có thể thấy đa phần các câu trong dữ liệu ngắn hoặc trung bình.
#
# Không có dấu hiệu lệch hoặc nhiễu.

# %%
corr = train_df['en_len'].corr(train_df['vi_len'])
print(f"Hệ số tương quan Pearson giữa độ dài câu: {corr:.3f}")
# Out:
# Hệ số tương quan Pearson giữa độ dài câu: 0.964

# %% [markdown]
# Hệ số tương quan giữa độ dài câu tiếng Anh và tiếng Việt đạt r ≈ 0.833, cho thấy hai ngôn ngữ có mức độ tương ứng cao về mặt cấu trúc.

# %%
display(train_df.head())
# Out:
#                                              English  \
# 0  The book is most famous for its vivid , arguab...
# 1  The post-1945 borders meant that the need for ...
# 2  Robertson went on to establish the first blood...
# 3  Research local : Banquet halls Union halls Chu...
# 4  The Princess Palatine was Henrietta 's first c...
#
#                                           Vietnamese  en_len  vi_len  \
# 0  Cuốn sách nổi tiếng về tính sáng sủa , bị cho ...      35      64
# 1  Biên giới sau năm 1945 khiến nhu cầu kết nối đ...      40      50
# 2  Robertson tiếp tục thành lập bộ máy truyền máu...      25      28
# 3  Hãy tìm hiểu những cơ sở sau tại địa phương : ...      35      63
# 4  Công chúa Palatine là anh em họ đầu tiên của H...      44      50
#
#    len_ratio
# 0   1.828571
# 1   1.250000
# 2   1.120000
# 3   1.800000
# 4   1.136364

# %% [markdown]
# #### Data Preproccessing

# %%
# !pip install langid
# Out:
# Collecting langid
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 37.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from langid) (2.0.2)
# Building wheels for collected packages: langid
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941171 sha256=fff6d11e4dec47d0b799dd344cf4a1da84a1915c0c3069ac48fc056d12082fd6
#   Stored in directory: /root/.cache/pip/wheels/3c/bc/9d/266e27289b9019680d65d9b608c37bff1eff565b001c977ec5
# Successfully built langid
# Installing collected packages: langid
# Successfully installed langid-1.1.6

# %%
from datasets import load_dataset, concatenate_datasets
import html, re, unicodedata
from bs4 import BeautifulSoup
import langid
import regex

# %%
# =======================
# CLEAN TEXT FUNCTION
# =======================
def clean_text(text):
    if not isinstance(text, str):
        return ""

    # 0) Trim và bảo đảm là str
    text = str(text).strip()

    # 1) Remove HTML + decode entities
    text = BeautifulSoup(text, "html.parser").get_text()
    text = html.unescape(text)

    # 2) Unicode normalize
    text = unicodedata.normalize("NFC", text)

    # Remove leading hyphen
    text = re.sub(r"^\s*-\s*", "", text)


    # 3) Remove zero-width + control chars early
    text = re.sub(r"[\u200B-\u200F\uFEFF\x00-\x1F\x7F]", " ", text)

    # 4) Replace fancy punctuation
    text = text.replace("’", "'").replace("‘", "'")
    text = text.replace("“", '"').replace("”", '"')
    text = text.replace("⋯", "…")
    text = text.replace("...", "…")

    # 5) Remove URLs, emails, tags
    text = re.sub(r"http\S+|www\.\S+", "", text)
    text = re.sub(r"\S+@\S+", "", text)
    text = re.sub(r"[@#]\w+", "", text)

    # 6) Convert repeated dash sequences to em-dash with spaces around (but keep single hyphen)
    text = re.sub(r"[\u2012\u2013\u2014\u2015\-]{2,}", " — ", text)

    # 7) Remove uncommon symbols
    text = re.sub(r"[◆●■♡→•※✦►◄▽▼▲♦★☆■□▪▫]", "", text)

    # 8) Preserve Vietnamese letters but remove weird chars:
    # allow letters (including Vietnamese range), digits, basic punctuation and some symbols
    text = re.sub(r"[^0-9A-Za-zÀ-ỹà-ỹẠ-ỹạ-ỹ \t\n\r\.,!\?\;:\'\"\-\(\)\/%—…]", " ", text)

    # 9. Fix multiple punctuation repeats: ellipsis etc.
    # first collapse any "dot + spaces + dot + spaces + dot" variants into '...'
    text = re.sub(r"\.\s*\.\s*\.+", "...", text)   # . . .  or .... -> ...
    text = re.sub(r"\.{4,}", "...", text)          # more than 3 -> ...
    # normalize sequences of 2 dots -> single dot (we treat .. -> .)
    text = re.sub(r"\.{2}", ".", text)
    # repeated commas/exclam/question
    text = re.sub(r",{2,}", ",", text)
    text = re.sub(r"!{2,}", "!", text)
    text = re.sub(r"\?{2,}", "?", text)

    # 10) Allow only valid characters (EN + VI + punctuation)
    # text = re.sub(r"[^0-9A-Za-zÀ-ỹ ,.!?;:'\"()\-\%/…]", " ", text)
    text = regex.sub(r"[^\p{Letter}\p{Number}\p{Punctuation}\p{Separator}]", " ", text)

    # 11) Normalize repeating chars (soooo → soo)
    text = re.sub(r"(.)\1{2,}", r"\1\1", text)

    # 12) Normalize spaces
    text = re.sub(r"\s+", " ", text).strip()
    # === FIX: Add space before single-quote starting a phrase ===
    # Example: chọn ' Download ' → chọn 'Download'
    #          chọn'Download'   → chọn 'Download'
    text = re.sub(r"(?<=\S)'\s*(?=\w)", r" '", text)


    # === FIX: add space before quote starting a phrase ===
    # text = re.sub(r"(?<=\S)'(?=[A-Za-zÀ-ỹ])", r" '", text)


    # 13) Fix punctuation spacing safely (quotes, apostrophes, periods)

    # 13.1 Fix space BEFORE punctuation (except opening quotes)
    text = re.sub(r"\s+([,.!?;:])", r"\1", text)

    # 13.2 Fix space BEFORE closing quote
    text = re.sub(r'\s+(")', r'\1', text)

    # 13.3 Fix spacing for possessive 's (Truman's)
    text = re.sub(r"\s+'s\b", r"'s", text)

    # 13.4 Add space AFTER punctuation if missing (but NOT for apostrophes)
    text = re.sub(r"([,.!?;:])([A-Za-z0-9])", r"\1 \2", text)

    # 13.5 Ensure space before opening quote and no space after it
    text = re.sub(r'\s*"\s*([A-Za-z])', r' "\1', text)


    # 13.6 Fix closing quotes: remove space before punctuation
    text = re.sub(r'" ([,.!?;:])', r'"\1', text)

    # Remove space just before closing single quote: abc  ' -> abc'
    text = re.sub(r"([A-Za-zÀ-ỹ0-9])\s+'", r"\1'", text)



    # 14) Fix stuck parentheses
    text = re.sub(r"\(\s+", "(", text)
    text = re.sub(r"\s+\)", ")", text)

    # 15) Fix "'s"
    text = re.sub(r"\s+'s\b", "'s", text)

    # 16) Fix spaces in abbreviations composed of capital letters with dots:
    # Examples to handle: "U. S. ,", "U. K. ,", "D. C." etc.
    # Step: remove spaces between single capitals and dots: "U. S." -> "U.S."
    text = re.sub(r"\b([A-Z])\.\s+([A-Z])\.", r"\1.\2.", text)
    # If longer sequences like "U. S. A." -> "U.S.A."
    # loop until no change (to collapse chains)
    prev = None
    while prev != text:
        prev = text
        text = re.sub(r"\b([A-Z])\.\s+([A-Z])\.", r"\1.\2.", text)

    # 17) Remove spaces after dots within abbreviations: "U.S. , " -> "U.S.,"
    text = re.sub(r"([A-Z]\.)\s+,", r"\1,", text)

    # 18) Fix digits separated by comma + space like "12, 00" -> "12,00"
    text = re.sub(r"(\d)\s*,\s*(\d)", r"\1,\2", text)

    # 19) Fix English + Vietnamese stuck together
    text = regex.sub(r"([A-Za-z])(\p{Letter}&&\p{Script=Latin}&&\p{M}?)", r"\1 \2", text)

    # 20) Final trim
    text = re.sub(r"[\u200B-\u200F\uFEFF]", "", text)
    text = re.sub(r"\s+", " ", text).strip()

    return text


# ==========================
# PREPROCESS FUNCTION
# ==========================
def preprocess_text(text):
    text = clean_text(text)
    return text

print("=== ORIGINAL COUNTS ===")
print("Train:", len(train_df))
print("Valid:", len(val_df))
print("Test :", len(test_df))


# =======================
# PREPROCESS
# =======================
print("Preprocess on train...")
train_df["en"] = train_df["English"].apply(preprocess_text)
train_df["vi"] = train_df["Vietnamese"].apply(preprocess_text)

# print("Preprocess on valid...")
val_df["en"] = val_df["English"].apply(preprocess_text)
val_df["vi"] = val_df["Vietnamese"].apply(preprocess_text)

# print("Preprocess on test...")
test_df["en"] = test_df["English"].apply(preprocess_text)
test_df["vi"] = test_df["Vietnamese"].apply(preprocess_text)

print("\n=== AFTER CLEAN ===")
print("Train:", len(train_df))
print("Valid:", len(val_df))
print("Test :", len(test_df))


# =======================
# REMOVE EMPTY ROWS
# =======================
print("Remove empty rows on train...")
train_df = train_df[(train_df["en"].str.strip() != "") & (train_df["vi"].str.strip() != "")]

print("Remove empty rows on valid...")
val_df   = val_df[(val_df["en"].str.strip() != "") & (val_df["vi"].str.strip() != "")]

print("Remove empty rows on test...")
test_df  = test_df[(test_df["en"].str.strip() != "") & (test_df["vi"].str.strip() != "")]

print("\n=== AFTER REMOVE EMPTY ===")
print("Train:", len(train_df))
print("Valid:", len(val_df))
print("Test :", len(test_df))


# =======================
# REMOVE DUPLICATES
# =======================
print("Remove duplicate rows on train...")
train_df = train_df.drop_duplicates(subset=["en", "vi"])

print("Remove duplicate rows on valid...")
val_df   = val_df.drop_duplicates(subset=["en", "vi"])

print("Remove duplicate rows on test...")
test_df  = test_df.drop_duplicates(subset=["en", "vi"])

print("\n=== AFTER REMOVE DUPLICATES ===")
print("Train:", len(train_df))
print("Valid:", len(val_df))
print("Test :", len(test_df))


# =========================
# FILTER BY SENTENCE LENGTH
# =========================
print("Filter length on train...")
train_df = train_df[
    train_df["en"].str.split().str.len().between(1, 80) &
    train_df["vi"].str.split().str.len().between(1, 80)
]

print("Filter length on valid...")
val_df = val_df[
    val_df["en"].str.split().str.len().between(1, 80) &
    val_df["vi"].str.split().str.len().between(1, 80)
]

print("Filter length on test...")
test_df = test_df[
    test_df["en"].str.split().str.len().between(1, 80) &
    test_df["vi"].str.split().str.len().between(1, 80)
]

print("\n=== AFTER LENGTH FILTER ===")
print("Train:", len(train_df))
print("Valid:", len(val_df))
print("Test :", len(test_df))


# =================
# FILTER BY LANGID
# =================
langid.set_languages(["en", "vi"])

# ---- Train ----
print("Filter language on train...")
train_lang_mask = (
    (train_df["en"].apply(lambda x: langid.classify(x)[0]) == "en") &
    (train_df["vi"].apply(lambda x: langid.classify(x)[0]) == "vi")
)

train_removed_df = train_df[~train_lang_mask]  # lưu mẫu bị loại
train_df = train_df[train_lang_mask]           # giữ lại mẫu đúng

# ---- Val ----
print("Filter language on valid...")
val_lang_mask = (
    (val_df["en"].apply(lambda x: langid.classify(x)[0]) == "en") &
    (val_df["vi"].apply(lambda x: langid.classify(x)[0]) == "vi")
)

val_removed_df = val_df[~val_lang_mask]
val_df = val_df[val_lang_mask]

# ---- Test ----
print("Filter language on test...")
test_lang_mask = (
    (test_df["en"].apply(lambda x: langid.classify(x)[0]) == "en") &
    (test_df["vi"].apply(lambda x: langid.classify(x)[0]) == "vi")
)

test_removed_df = test_df[~test_lang_mask]
test_df = test_df[test_lang_mask]

print("\n=== AFTER LANGID FILTER ===")
print(f"Train: {len(train_df)} (removed: {len(train_removed_df)})")
print(f"Valid: {len(val_df)} (removed: {len(val_removed_df)})")
print(f"Test : {len(test_df)} (removed: {len(test_removed_df)})")
# Out:
# === ORIGINAL COUNTS ===
# Train: 446347
# Valid: 55105
# Test : 49595
# Preprocess on train...
#
# === AFTER CLEAN ===
# Train: 446347
# Valid: 55105
# Test : 49595
# Remove empty rows on train...
# Remove empty rows on valid...
# Remove empty rows on test...
#
# === AFTER REMOVE EMPTY ===
# Train: 446347
# Valid: 55105
# Test : 49595
# Remove duplicate rows on train...
# Remove duplicate rows on valid...
# Remove duplicate rows on test...
#
# === AFTER REMOVE DUPLICATES ===
# Train: 439921
# Valid: 54919
# Test : 49444
# Filter length on train...
# Filter length on valid...
# Filter length on test...
#
# === AFTER LENGTH FILTER ===
# Train: 433379
# Valid: 54143
# Test : 48695
# Filter language on train...
# Filter language on valid...
# Filter language on test...
#
# === AFTER LANGID FILTER ===
# Train: 432284 (removed: 1095)
# Valid: 54007 (removed: 136)
# Test : 48569 (removed: 126)

# %%
# train_df = train_df.rename(columns={
#     "vi": "input_text",
#     "en": "target_text"
# })

# val_df = val_df.rename(columns={
#     "vi": "input_text",
#     "en": "target_text"
# })

# test_df = test_df.rename(columns={
#     "vi": "input_text",
#     "en": "target_text"
# })

# %%
from datasets import Dataset

def df_to_hfds(df):
    ds = Dataset.from_pandas(df.reset_index(drop=True))
    if "__index_level_0__" in ds.column_names:
        ds = ds.remove_columns(["__index_level_0__"])
    return ds

ds_train = df_to_hfds(train_df)
ds_valid = df_to_hfds(val_df)
ds_test  = df_to_hfds(test_df)

# %%
# =======================
# PREFIX BUILDING
# =======================
def to_prefix_vi2en(example):
    """Prefix cho Việt → Anh"""
    prefix = f"vi_en: {example['vi']}"
    return {'input_text': prefix, 'target_text': example['en']}


print("Mapping to prefix on train...")
ds_vi2en_train = ds_train.map(to_prefix_vi2en, \
                              remove_columns=ds_train.column_names, \
                              num_proc=4)

print("Mapping to prefix on valid...")
ds_vi2en_valid = ds_valid.map(to_prefix_vi2en, \
                              remove_columns=ds_valid.column_names, \
                              num_proc=2)

print("Mapping to prefix on test...")
ds_vi2en_test = ds_test.map(to_prefix_vi2en, \
                            remove_columns=ds_test.column_names, \
                            num_proc=2)
# Out:
# Mapping to prefix on train...
# Map (num_proc=4):   0%|          | 0/432284 [00:00<?, ? examples/s]
# Mapping to prefix on valid...
# Map (num_proc=2):   0%|          | 0/54007 [00:00<?, ? examples/s]
# Mapping to prefix on test...
# Map (num_proc=2):   0%|          | 0/48569 [00:00<?, ? examples/s]

# %%
print(f"train: {len(ds_vi2en_train)} samples, valid: {len(ds_vi2en_valid)} samples, "
      f"test: {len(ds_vi2en_test)} samples")
# Out:
# train: 432284 samples, valid: 54007 samples, test: 48569 samples

# %%
for i in range(5):
    print(ds_vi2en_train[i])
    print("------")
# Out:
# {'input_text': 'vi_en: Cuốn sách nổi tiếng về tính sáng sủa, bị cho là mang nhiều yếu tố chủ quan, phác hoạ hình ảnh những trận chiến của Frederick, trong tác phẩm, Carlyle đã truyền đạt được góc nhìn của ông về toàn cảnh của sự hỗn loạn cực độ được nhà lãnh đạo xuất chúng xử lý một cách tài tình.', 'target_text': "The book is most famous for its vivid, arguably very biased, portrayal of Frederick's battles, in which Carlyle communicated his vision of almost overwhelming chaos mastered by leadership of genius."}
# ------
# {'input_text': 'vi_en: Biên giới sau năm 1945 khiến nhu cầu kết nối đường bộ công suất cao trên tuyến đường đó đã biến mất và mặc dù phần lớn công việc xây dựng đã được thực hiện, nhưng nó không được chính phủ Ba Lan tiếp tục sau chiến tranh.', 'target_text': 'The post-1945 borders meant that the need for a high - capacity road connection on that route disappeared and even though much of the construction work was already done, it was not continued by the postwar Polish government.'}
# ------
# {'input_text': 'vi_en: Robertson tiếp tục thành lập bộ máy truyền máu đầu tiên tại Trạm dọn dẹp thương binh ở Mặt trận phía Tây vào mùa xuân năm 1917.', 'target_text': 'Robertson went on to establish the first blood transfusion apparatus at a Casualty Clearing Station on the Western Front in the spring of 1917.'}
# ------
# {'input_text': 'vi_en: Hãy tìm hiểu những cơ sở sau tại địa phương: Nhà hàng tiệc cưới Nhà văn hoá Nhà thờ có hội trường Các khu nhà đẹp thuộc loại di tích lịch sử Khu du lịch Việc tiếp khách thường bao gồm các phần chính sau: chiêu đãi tiệc, phát biểu thân mật, ăn tráng miệng và khiêu vũ.', 'target_text': 'Research local: Banquet halls Union halls Churches with large fellowship halls Historical properties on the registry Wineries Most receptions will consist of a meal, some informal comments, desert, and dancing.'}
# ------
# {'input_text': 'vi_en: Công chúa Palatine là anh em họ đầu tiên của Henrietta đã bị loại bỏ, vì cha của người sau (Charles I của Anh và Scotland) là anh trai của bà nội của Elisabeth Charlotte, Elisabeth Stuart, Electress Palatine và Nữ hoàng của Bohemia.', 'target_text': "The Princess Palatine was Henrietta's first cousin once removed, since the latter's father (Charles I of England and Scotland) was the brother of Elisabeth Charlotte's paternal grandmother, Elisabeth Stuart, Electress Palatine and Queen of Bohemia."}
# ------

# %%
n = len(ds_vi2en_train)
ds_train[n-5 : n]
# Out:
# {'English': ['In the early summer of 1876 , Allen was elected by the Nuttall Ornithological Club to replace Charles Johnson Maynard and Henry Augustus Purdie as editor of their Bulletin .',
#   'Section 247 of the Income Tax Act ( Canada ) Information Circular 87 - 2R - International Transfer Pricing ( 1999 ) Information Circular 94 - 4R - International Transfer Pricing : Advance Pricing Arrangements ( APAs ) ( 2001 ) TPM 07 - Referrals to the Transfer Pricing Review Committee ( 2005 ) TPM 09 - Reasonable efforts under section 247 of the Income Tax Act ( 2006 )',
#   'Unibeast and MacPwn were updated to support El Capitan as well , since El Capitan , Unibeast ( and Multibeast ) use the Clover bootloader instead of Chimera ( a Chameleon - based bootloader ) .',
#   'In the 19th century , the number of Jews grew in Niebylec , and by the early 20th century , they made the majority of the population .',
#   'Around 200km west of Hanoi, the commune, named after a mountain that it hosts, is an emerging tourism hotspot for good reason.'],
#  'Vietnamese': ['Vào đầu mùa hè năm 1876 , Allen được Câu lạc bộ Điểu học Nuttall bầu chọn để thay thế Charles Johnson Maynard và Henry Augustus Purdie làm biên tập viên tờ Bulletin của họ .',
#   'Mục 247 của Đạo luật thuế thu nhập ( Canada ) Thông tin 87-2 R - Giá chuyển nhượng quốc tế ( 1999 ) Thông tư Thông tin 94-4 R - Giá chuyển nhượng quốc tế : Sắp xếp giá trước ( APA ) ( 2001 ) TPM 07 - Giới thiệu đến Uỷ ban đánh giá chuyển nhượng ( 2005 ) TPM 09 - Những nỗ lực hợp lý theo mục 247 của Đạo luật thuế thu nhập ( 2006 )',
#   'Unibeast và MacPwn cũng được cập nhật để hỗ trợ El Capitan , \x08từ El Capitan , Unibeast ( và Multibeast ) sử dụng bootloader Clover thay vì Chimera ( bootloader dựa trên Chameleon ) .',
#   'Vào thế kỷ 19 , số người Do Thái tăng cao ở Niebylec và đến đầu thế kỷ 20 , họ đã chiếm phần lớn dân số khu vực .',
#   'Cách Hà Nội khoảng 200 km về phía Tây, xã Tà Xùa được đặt theo tên của một ngọn núi mà nó là chủ sở hữu, là một điểm nóng du lịch mới nổi vì lý do chính đáng.'],
#  'en_len': [30, 70, 36, 28, 22],
#  'vi_len': [36, 82, 36, 30, 39],
#  'len_ratio': [1.2,
#   1.1714285714285715,
#   1.0,
#   1.0714285714285714,
#   1.7727272727272727],
#  'en': ['In the early summer of 1876, Allen was elected by the Nuttall Ornithological Club to replace Charles Johnson Maynard and Henry Augustus Purdie as editor of their Bulletin.',
#   'Section 247 of the Income Tax Act (Canada) Information Circular 87 - 2R - International Transfer Pricing (199) Information Circular 94 - 4R - International Transfer Pricing: Advance Pricing Arrangements (APAs) (2001) TPM 07 - Referrals to the Transfer Pricing Review Committee (2005) TPM 09 - Reasonable efforts under section 247 of the Income Tax Act (2006)',
#   'Unibeast and MacPwn were updated to support El Capitan as well, since El Capitan, Unibeast (and Multibeast) use the Clover bootloader instead of Chimera (a Chameleon - based bootloader).',
#   'In the 19th century, the number of Jews grew in Niebylec, and by the early 20th century, they made the majority of the population.',
#   'Around 200km west of Hanoi, the commune, named after a mountain that it hosts, is an emerging tourism hotspot for good reason.'],
#  'vi': ['Vào đầu mùa hè năm 1876, Allen được Câu lạc bộ Điểu học Nuttall bầu chọn để thay thế Charles Johnson Maynard và Henry Augustus Purdie làm biên tập viên tờ Bulletin của họ.',
#   'Mục 247 của Đạo luật thuế thu nhập (Canada) Thông tin 87-2 R - Giá chuyển nhượng quốc tế (199) Thông tư Thông tin 94-4 R - Giá chuyển nhượng quốc tế: Sắp xếp giá trước (APA) (2001) TPM 07 - Giới thiệu đến Uỷ ban đánh giá chuyển nhượng (2005) TPM 09 - Những nỗ lực hợp lý theo mục 247 của Đạo luật thuế thu nhập (2006)',
#   'Unibeast và MacPwn cũng được cập nhật để hỗ trợ El Capitan, từ El Capitan, Unibeast (và Multibeast) sử dụng bootloader Clover thay vì Chimera (bootloader dựa trên Chameleon).',
#   'Vào thế kỷ 19, số người Do Thái tăng cao ở Niebylec và đến đầu thế kỷ 20, họ đã chiếm phần lớn dân số khu vực.',
#   'Cách Hà Nội khoảng 200 km về phía Tây, xã Tà Xùa được đặt theo tên của một ngọn núi mà nó là chủ sở hữu, là một điểm nóng du lịch mới nổi vì lý do chính đáng.']}

# %% [markdown]
# #### Model

# %%
ds_vi2en_train.save_to_disk("train")
ds_vi2en_valid.save_to_disk("valid")
ds_vi2en_test.save_to_disk("test")

# %%
# !pip install protobuf==3.20.*
# !pip install evaluate
# !pip install sacrebleu
# !pip install rouge_score sacrebleu

# %%
# %%writefile mt_train_script.py

from datasets import load_from_disk
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from torch.utils.data import DataLoader
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq, EarlyStoppingCallback



import evaluate
import torch
import numpy as np

# LOAD DATASET
ds_train = load_from_disk("train")
ds_valid = load_from_disk("valid")


# LOAD MODEL & TOKENIZER

MODEL_NAME = "VietAI/ViT5-base"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)





# TOKENIZE FUNCTION
def tokenize_fn(batch):
    model_inputs = tokenizer(
        batch["input_text"],
        max_length=64,
        padding="max_length",
        truncation=True,
    )

    labels = tokenizer(
        batch["target_text"],
        max_length=64,
        padding="max_length",
        truncation=True,
    )["input_ids"]

    labels = [
        [(t if t != tokenizer.pad_token_id else -100) for t in label]
        for label in labels
    ]

    model_inputs["labels"] = labels
    return model_inputs

train_tok = ds_train.map(tokenize_fn, batched=True, remove_columns=ds_train.column_names)
valid_tok = ds_valid.map(tokenize_fn, batched=True, remove_columns=ds_valid.column_names)




# METRIC (BLEU)
metric = evaluate.load("sacrebleu")

def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels


def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result






# TRAINING ARGUMENTS
training_args = Seq2SeqTrainingArguments(
    output_dir="./nlp_mt_endterm_vi_en_v5_data400k",
    eval_strategy="steps",
    eval_steps=6000,

    save_strategy="steps",
    save_steps=6000,

    logging_strategy="steps",
    logging_steps=1000,

    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    gradient_accumulation_steps=2,

    num_train_epochs=10,
    learning_rate=1e-4,
    warmup_ratio=0.05,
    label_smoothing_factor=0.1,
    weight_decay=0.01,


    fp16=True,
    report_to="none",
    run_name="vit5_en_vi_ft",
    group_by_length=True,
    gradient_checkpointing=True,
    predict_with_generate=True,

    load_best_model_at_end=True,
    metric_for_best_model="bleu",
    greater_is_better=True
)





# TRAINER
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_tok,
    eval_dataset=valid_tok,
    processing_class=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(early_stopping_patience=3)  # STOP nếu BLEU không cải thiện 3 lần liên tiếp
    ]
)





# TRAIN
trainer.train()
trainer.save_state()
# Out:
# Writing mt_train_script.py

# %%
# !pip install accelerate

# %%
# !accelerate config default

# %%
# !accelerate launch mt_train_script.py

# %% [markdown]
# #### Test

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/checkpoint-33780.zip

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_path = "/content/checkpoint-33780"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path).to("cuda")

text = "vi_en: Đêm trường trung cổ là nỗi ám ảnh kinh hoàng của lịch sử châu Âu"
inputs = tokenizer(text, return_tensors="pt").to("cuda")
output = model.generate(**inputs, max_length=64)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The night of medieval schools is the horrific obsession of European history

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

state_path = "/content/checkpoint-33780/trainer_state.json"

with open(state_path, "r") as f:
    state = json.load(f)

logs = state["log_history"]

df = pd.DataFrame(logs)

train_df = df[df["loss"].notnull()]
val_df   = df[df["eval_loss"].notnull()]

plt.figure(figsize=(10,5))
plt.plot(train_df["step"], train_df["loss"], label="Train Loss")
plt.plot(val_df["step"], val_df["eval_loss"], label="Validation Loss")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Push to Hugging Face

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import create_repo
create_repo("machine-translation-v1-data400k", private=True)

# %%
from huggingface_hub import upload_folder

upload_folder(
    repo_id="tnguyen20604/machine-translation-v1-data400k",
    folder_path="checkpoint-33780",
    commit_message="Upload checkpoint"
)

# %% [markdown]
# #### Download fine-tuning model

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("tnguyen20604/machine-translation-v1-data400k")

model = AutoModelForSeq2SeqLM.from_pretrained(
    "tnguyen20604/machine-translation-v1-data400k",
    torch_dtype="float16",
    device_map="auto"
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/820k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# 2025-11-29 12:51:04.891664: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764420665.105329      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764420665.169644      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# model.safetensors:   0%|          | 0.00/904M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/accelerate/utils/modeling.py:1614: UserWarning: The following device_map keys do not match any submodules in the model: ['decoder.embed_tokens']
#   warnings.warn(

# %%
text = "vi_en: Đêm trường trung cổ là nỗi ám ảnh kinh hoàng của lịch sử châu Âu"
inputs = tokenizer(text, return_tensors="pt").to("cuda")

output = model.generate(**inputs, max_length=64)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The night of medieval schools is the horrific obsession of European history

# %% [markdown]
# #### RF - DPO

# %% [markdown]
# ##### Get Vietnamese Data

# %% [markdown]
# ###### Crawl wiki

# %%
from urllib.parse import quote
import requests

def search_wiki(keyword, limit=20):
    url = "https://vi.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "list": "search",
        "srsearch": keyword,
        "format": "json",
        "srlimit": limit
    }

    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    r = requests.get(url, params=params, headers=headers, timeout=10)
    data = r.json()

    links = []
    for item in data.get("query", {}).get("search", []):
        title = item["title"]
        safe = quote(title.replace(" ", "_"))
        links.append("https://vi.wikipedia.org/wiki/" + safe)

    return links

# %%
keywords = [
    "đời sống", "công việc", "du lịch", "học tập", "cảm xúc",
    "tai nạn", "vấn đề xã hội", "công nghệ", "khoa học",
    "gia đình", "môi trường", "văn hóa", "giao thông"
]

wiki_links = []
for kw in keywords:
    wiki_links.extend(search_wiki(kw, limit=40))   # mỗi keyword lấy 40 bài

wiki_links = list(set(wiki_links))  # unique
len(wiki_links)
# Out:
# 446

# %%
# !pip install requests beautifulsoup4 langdetect
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.12/dist-packages (1.0.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect) (1.17.0)

# %%
import requests
from bs4 import BeautifulSoup
import re
from langdetect import detect
from urllib.parse import quote

def split_vi_sentences(text):
    return [s.strip() for s in re.split(r'(?<=[.!?])\s+', text) if s.strip()]

def clean_sentence(s):
    s = re.sub(r"^\d+\s+", "", s)       # remove leading numbers
    s = re.sub(r"\[\d+\]", "", s)       # remove [12] references
    s = re.sub(r"\s+", " ", s).strip()
    return s

def crawl_wiki_page(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
    }

    html = requests.get(url, headers=headers, timeout=10).text
    soup = BeautifulSoup(html, "html.parser")

    # lấy TẤT CẢ <p> trong trang (không phụ thuộc vào mw-parser-output)
    all_p = soup.find_all("p")
    if not all_p:
        print("⚠ Không tìm được <p>:", url)
        return []

    full_text = " ".join(p.get_text(" ", strip=True) for p in all_p)

    full_text = re.sub(r"[^A-Za-zÀ-ỹ0-9 \,\.\!\?]", " ", full_text)
    full_text = re.sub(r"\s+", " ", full_text).strip()

    sentences = split_vi_sentences(full_text)

    final = []
    for s in sentences:
        s = clean_sentence(s)

        if len(s.split()) < 8 or len(s.split()) > 35:
            continue

        try:
            if detect(s) == "vi":
                final.append(s)
        except:
            pass

    return final

# %%
u = "https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_%C4%90%E1%BA%A1i_h%E1%BB%8Dc_B%C3%A1ch_khoa,_%C4%90%E1%BA%A1i_h%E1%BB%8Dc_Qu%E1%BB%91c_gia_Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh"
sent = crawl_wiki_page(u)
len(sent), sent[:10]
# Out:
# (25,
#  ['Tiền thân của Trường Đại học Bách khoa là Trung tâm Quốc gia Kỹ thuật được thành lập từ năm 1957 dưới chính thể Việt Nam Cộng hòa .',
#   'Đến năm 1972, Trung tâm Quốc gia Kỹ thuật được đổi tên thành Học viện Quốc gia Kỹ thuật.',
#   'Năm 1974, Học viện Quốc gia Kỹ thuật được sát nhập vào Viện Đại học Bách khoa Thủ Đức và đổi tên thành Trường Đại học Kỹ thuật.',
#   'Năm 1972, Trung tâm Quốc gia Kỹ thuật được đổi tên thành Học viện Quốc gia Kỹ thuật theo Sắc lệnh 135SL GD ngày 15 tháng 9 năm 1972.',
#   'Năm 1973, Học viện Quốc gia Kỹ thuật bị giải tán, trường được đổi tên Trường Đại học Kỹ thuật và là thành viên của Viện Đại học Bách khoa Thủ Đức.',
#   'Năm 1976, Trường được mang tên Trường Đại học Bách khoa theo Quyết định số 426 TTg ngày 27 tháng 10 năm 1976.',
#   'với 5 khoa chuyên ngành đầu tiên là Xây dựng, Điện Điện tử, Thủy lợi , Cơ khí và Hóa học .',
#   'Từ đó, 27 tháng 10 được chọn là ngày thành lập Trường Đại học Bách khoa.',
#   'Năm 1978, Khoa Địa chất được thành lập.',
#   'Năm 1991, trường bắt đầu đào tạo cao học.'])

# %%
def crawl_wiki_topics(topics, target=5000):
    results = []
    for url in topics:
        print("Crawling:", url)
        sentences = crawl_wiki_page(url)
        results.extend(sentences)
        print(" → lấy được", len(sentences), "câu")

        if len(results) >= target:
            break

    # unique + shuffle
    results = list(set(results))
    print("Tổng số câu sau khi unique:", len(results))
    return results[:target]

# %% [markdown]
# ###### Save data file

# %%
sentences = crawl_wiki_topics(wiki_links, target=5000)

with open("vi_wiki_5k.txt", "w", encoding="utf-8") as f:
    for s in sentences:
        f.write(s + "\n")

print("DONE. Saved vi_wiki_5k.txt")
# Out:
# Crawling: https://vi.wikipedia.org/wiki/Tai_n%E1%BA%A1n_giao_th%C3%B4ng
#  → lấy được 25 câu
# Crawling: https://vi.wikipedia.org/wiki/Ho%E1%BA%A1n_quan
#  → lấy được 85 câu
# Crawling: https://vi.wikipedia.org/wiki/Qu%E1%BB%91c_h%E1%BB%99i_Vi%E1%BB%87t_Nam
#  → lấy được 69 câu
# Crawling: https://vi.wikipedia.org/wiki/Alg%C3%A9rie
#  → lấy được 81 câu
# Crawling: https://vi.wikipedia.org/wiki/Bi%E1%BB%83n_b%C3%A1o_giao_th%C3%B4ng_t%E1%BA%A1i_Vi%E1%BB%87t_Nam
#  → lấy được 15 câu
# Crawling: https://vi.wikipedia.org/wiki/D%E1%BB%B1_b%C3%A1o_th%E1%BB%9Di_ti%E1%BA%BFt
#  → lấy được 15 câu
# Crawling: https://vi.wikipedia.org/wiki/Internet
#  → lấy được 142 câu
# Crawling: https://vi.wikipedia.org/wiki/Gia_%C4%91%C3%ACnh_H%E1%BB%93_Ch%C3%AD_Minh
#  → lấy được 97 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%C3%A0i_Ti%E1%BA%BFng_n%C3%B3i_Vi%E1%BB%87t_Nam
#  → lấy được 17 câu
# Crawling: https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_%C4%90%E1%BA%A1i_h%E1%BB%8Dc_Giao_th%C3%B4ng_v%E1%BA%ADn_t%E1%BA%A3i_Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh
#  → lấy được 11 câu
# Crawling: https://vi.wikipedia.org/wiki/17_th%C3%A1ng_11
#  → lấy được 1 câu
# Crawling: https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_Th%C3%BAy_Anh
#  → lấy được 11 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%E1%BA%A1i_h%E1%BB%8Dc_%C4%91%C6%B0%E1%BB%9Dng_Nh%C3%A2n_d%C3%A2n
#  → lấy được 20 câu
# Crawling: https://vi.wikipedia.org/wiki/Vi%E1%BB%87n_Khoa_h%E1%BB%8Dc_v%C3%A0_C%C3%B4ng_ngh%E1%BB%87_Qu%C3%A2n_s%E1%BB%B1_%28Vi%E1%BB%87t_Nam%29
#  → lấy được 14 câu
# Crawling: https://vi.wikipedia.org/wiki/V%E1%BA%A5n_%C4%91%E1%BB%81_g%C3%A2y_tranh_c%C3%A3i_v%C3%A0_xung_%C4%91%E1%BB%99t_c%E1%BB%A7a_H%C6%B0%E1%BB%9Bng_%C4%91%E1%BA%A1o
#  → lấy được 71 câu
# Crawling: https://vi.wikipedia.org/wiki/V%E1%BB%A5_gi%E1%BA%BFt_c%E1%BA%A3_gia_%C4%91%C3%ACnh_Watts
#  → lấy được 54 câu
# Crawling: https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_Trung_h%E1%BB%8Dc_ph%E1%BB%95_th%C3%B4ng_chuy%C3%AAn_Qu%E1%BB%91c_H%E1%BB%8Dc_%E2%80%93_Hu%E1%BA%BF
#  → lấy được 12 câu
# Crawling: https://vi.wikipedia.org/wiki/Kar%C5%8Dshi
#  → lấy được 70 câu
# Crawling: https://vi.wikipedia.org/wiki/Tr%C3%AC_ho%C3%A3n
#  → lấy được 48 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%8Ba_ch%E1%BA%A5t_h%E1%BB%8Dc
#  → lấy được 115 câu
# Crawling: https://vi.wikipedia.org/wiki/T%C3%B4_L%C3%A2m
#  → lấy được 78 câu
# Crawling: https://vi.wikipedia.org/wiki/V%C4%83n_h%C3%B3a_%C4%90%C3%B4ng_S%C6%A1n
#  → lấy được 97 câu
# Crawling: https://vi.wikipedia.org/wiki/Gia_%C4%91%C3%ACnh_l%C3%A0_s%E1%BB%91_1
#  → lấy được 4 câu
# Crawling: https://vi.wikipedia.org/wiki/Th%C3%ADch-ca_M%C3%A2u-ni
#  → lấy được 170 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%9Di_s%E1%BB%91ng_t%C3%ACnh_d%E1%BB%A5c
#  → lấy được 3 câu
# Crawling: https://vi.wikipedia.org/wiki/Boeing_B-52_Stratofortress
#  → lấy được 168 câu
# Crawling: https://vi.wikipedia.org/wiki/Entropy
#  → lấy được 47 câu
# Crawling: https://vi.wikipedia.org/wiki/Mangaka
#  → lấy được 13 câu
# Crawling: https://vi.wikipedia.org/wiki/M%C6%B0a_%C4%91%E1%BB%8F_%28phim%29
#  → lấy được 95 câu
# Crawling: https://vi.wikipedia.org/wiki/Chuy%E1%BA%BFn_bay_171_c%E1%BB%A7a_Air_India
#  → lấy được 31 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%C6%B0%E1%BB%9Dng_giao_th%C3%B4ng
#  → lấy được 61 câu
# Crawling: https://vi.wikipedia.org/wiki/V%E1%BB%91n_h%E1%BB%8Dc_t%E1%BA%ADp
#  → lấy được 0 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%E1%BA%AFk_L%E1%BA%AFk
#  → lấy được 76 câu
# Crawling: https://vi.wikipedia.org/wiki/Th%E1%BB%91ng_k%C3%AA
#  → lấy được 138 câu
# Crawling: https://vi.wikipedia.org/wiki/T%C3%B4n_Ng%E1%BB%8Dc_H%E1%BA%A1nh
#  → lấy được 11 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%C3%A8o_Ngo%E1%BA%A1n_M%E1%BB%A5c
#  → lấy được 22 câu
# Crawling: https://vi.wikipedia.org/wiki/L%C3%AA_Minh_H%C6%B0ng
#  → lấy được 22 câu
# Crawling: https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_L%E1%BB%87_Xu%C3%A2n
#  → lấy được 63 câu
# Crawling: https://vi.wikipedia.org/wiki/V%E1%BB%A5_l%E1%BA%ADt_t%C3%A0u_V%E1%BB%8Bnh_Xanh_58
#  → lấy được 110 câu
# Crawling: https://vi.wikipedia.org/wiki/H%E1%BB%87_th%E1%BB%91ng_giao_th%C3%B4ng_Vi%E1%BB%87t_Nam
#  → lấy được 71 câu
# Crawling: https://vi.wikipedia.org/wiki/T%E1%BB%95ng_B%C3%AD_th%C6%B0_Ban_Ch%E1%BA%A5p_h%C3%A0nh_Trung_%C6%B0%C6%A1ng_%C4%90%E1%BA%A3ng_C%E1%BB%99ng_s%E1%BA%A3n_Vi%E1%BB%87t_Nam
#  → lấy được 14 câu
# Crawling: https://vi.wikipedia.org/wiki/M%C3%A1y_t%C3%ADnh
#  → lấy được 137 câu
# Crawling: https://vi.wikipedia.org/wiki/Khu_du_l%E1%BB%8Bch_N%C3%BAi_B%C3%A0_%C4%90en
#  → lấy được 118 câu
# Crawling: https://vi.wikipedia.org/wiki/B%E1%BB%99_Ch%C3%ADnh_tr%E1%BB%8B_Ban_Ch%E1%BA%A5p_h%C3%A0nh_Trung_%C6%B0%C6%A1ng_%C4%90%E1%BA%A3ng_C%E1%BB%99ng_s%E1%BA%A3n_Vi%E1%BB%87t_Nam
#  → lấy được 55 câu
# Crawling: https://vi.wikipedia.org/wiki/Nh%E1%BB%AFng_m%E1%BA%A3nh_gh%C3%A9p_c%E1%BA%A3m_x%C3%BAc
#  → lấy được 127 câu
# Crawling: https://vi.wikipedia.org/wiki/V%E1%BB%A5_tai_n%E1%BA%A1n_Chosonminhang_Ilyushin_Il-62_1983
#  → lấy được 11 câu
# Crawling: https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_%C4%90%E1%BA%A1i_h%E1%BB%8Dc_Khoa_h%E1%BB%8Dc_S%C3%A0i_G%C3%B2n
#  → lấy được 7 câu
# Crawling: https://vi.wikipedia.org/wiki/VnExpress
#  → lấy được 17 câu
# Crawling: https://vi.wikipedia.org/wiki/PubMed
#  → lấy được 7 câu
# Crawling: https://vi.wikipedia.org/wiki/T%C6%B0_M%C3%A3_%C3%9D
#  → lấy được 108 câu
# Crawling: https://vi.wikipedia.org/wiki/V%C4%83n_h%C3%B3a_Vi%E1%BB%87t_Nam
#  → lấy được 86 câu
# Crawling: https://vi.wikipedia.org/wiki/B%E1%BB%99_N%C3%B4ng_nghi%E1%BB%87p_v%C3%A0_M%C3%B4i_tr%C6%B0%E1%BB%9Dng
#  → lấy được 7 câu
# Crawling: https://vi.wikipedia.org/wiki/%C3%81i_k%E1%BB%B7
#  → lấy được 6 câu
# Crawling: https://vi.wikipedia.org/wiki/BreadTube
#  → lấy được 0 câu
# Crawling: https://vi.wikipedia.org/wiki/Utah
#  → lấy được 90 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%C6%B0%E1%BB%9Dng_cong_h%E1%BB%8Dc_t%E1%BA%ADp
#  → lấy được 27 câu
# Crawling: https://vi.wikipedia.org/wiki/%C4%90%C3%A8o_L%C3%B2_Xo
#  → lấy được 10 câu
# Crawling: https://vi.wikipedia.org/wiki/T%C3%A2m_l%C3%BD_h%E1%BB%8Dc
#  → lấy được 185 câu
# Crawling: https://vi.wikipedia.org/wiki/S%C3%A2n_bay_qu%E1%BB%91c_t%E1%BA%BF_Long_Th%C3%A0nh
#  → lấy được 70 câu
# Crawling: https://vi.wikipedia.org/wiki/Niihau
#  → lấy được 17 câu
# Crawling: https://vi.wikipedia.org/wiki/Giao_th%C3%B4ng
#  → lấy được 46 câu
# Crawling: https://vi.wikipedia.org/wiki/Li%C3%AAn_X%C3%B4
#  → lấy được 464 câu
# Crawling: https://vi.wikipedia.org/wiki/Kh%C3%B4ng_qu%C3%A2n_nh%C3%A2n_d%C3%A2n_Vi%E1%BB%87t_Nam
#  → lấy được 114 câu
# Crawling: https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_%C4%90%E1%BA%A1i_h%E1%BB%8Dc_C%C3%B4ng_nghi%E1%BB%87p_Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh
#  → lấy được 11 câu
# Crawling: https://vi.wikipedia.org/wiki/Ch%C3%ADnh_s%C3%A1ch_x%C3%A3_h%E1%BB%99i
#  → lấy được 6 câu
# Crawling: https://vi.wikipedia.org/wiki/M%C3%B4i_tr%C6%B0%E1%BB%9Dng_desktop
#  → lấy được 38 câu
# Crawling: https://vi.wikipedia.org/wiki/Gia_%C4%91%C3%ACnh_vui_v%E1%BA%BB
#  → lấy được 13 câu
# Crawling: https://vi.wikipedia.org/wiki/Oberhausen
#  → lấy được 10 câu
# Crawling: https://vi.wikipedia.org/wiki/B%E1%BB%99_T%C3%A0i_nguy%C3%AAn_v%C3%A0_M%C3%B4i_tr%C6%B0%E1%BB%9Dng_%28Vi%E1%BB%87t_Nam%29
#  → lấy được 0 câu
# Crawling: https://vi.wikipedia.org/wiki/Gaslighting
#  → lấy được 20 câu
# Crawling: https://vi.wikipedia.org/wiki/V%C4%83n_Mi%E1%BA%BFu_%E2%80%93_Qu%E1%BB%91c_T%E1%BB%AD_Gi%C3%A1m
#  → lấy được 142 câu
# Crawling: https://vi.wikipedia.org/wiki/Sinh_h%E1%BB%8Dc
#  → lấy được 127 câu
# Crawling: https://vi.wikipedia.org/wiki/Bi%E1%BA%BFn_m%C3%B4i_tr%C6%B0%E1%BB%9Dng
#  → lấy được 84 câu
# Crawling: https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Nam
#  → lấy được 203 câu
# Crawling: https://vi.wikipedia.org/wiki/H%C6%B0%C6%A1ng_Giang_Idol
#  → lấy được 65 câu
# Crawling: https://vi.wikipedia.org/wiki/D%E1%BA%A5u_ch%E1%BA%A5m_than
#  → lấy được 17 câu
# Crawling: https://vi.wikipedia.org/wiki/Tr%C3%AD_tu%E1%BB%87_x%C3%BAc_c%E1%BA%A3m
#  → lấy được 39 câu
# Crawling: https://vi.wikipedia.org/wiki/5_%C4%91i%E1%BB%81u_B%C3%A1c_H%E1%BB%93_d%E1%BA%A1y
#  → lấy được 23 câu
# Crawling: https://vi.wikipedia.org/wiki/C%E1%BB%A5c_C%E1%BA%A3nh_s%C3%A1t_giao_th%C3%B4ng_%28Vi%E1%BB%87t_Nam%29
#  → lấy được 0 câu
# Crawling: https://vi.wikipedia.org/wiki/B%E1%BB%99_Gi%C3%A1o_d%E1%BB%A5c_v%C3%A0_%C4%90%C3%A0o_t%E1%BA%A1o
#  → lấy được 38 câu
# Crawling: https://vi.wikipedia.org/wiki/H%E1%BB%8Dc_vi%E1%BB%87n_K%E1%BB%B9_thu%E1%BA%ADt_Qu%C3%A2n_s%E1%BB%B1
#  → lấy được 14 câu
# Crawling: https://vi.wikipedia.org/wiki/Th%C6%B0%C6%A1ng_hi%E1%BB%87u
#  → lấy được 33 câu
# Crawling: https://vi.wikipedia.org/wiki/Ch%C4%83m_Pa
#  → lấy được 107 câu
# Crawling: https://vi.wikipedia.org/wiki/M%C3%BCnchen
#  → lấy được 62 câu
# Tổng số câu sau khi unique: 5012
# DONE. Saved vi_wiki_5k.txt

# %% [markdown]
# ##### Load data file

# %%
with open("vi_wiki_5k.txt", "r", encoding="utf-8") as f:
    sentences = [line.strip() for line in f if line.strip()]

# bắt đầu từ dòng 2103 (index 2102)
sentences = sentences[3082:]

# %% [markdown]
# ##### Generate data for DPO

# %% [markdown]
# ###### Translate

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

def multi_translate(text, n=3):
    inp = "vi_en: " + text
    tokens = tokenizer(inp, return_tensors="pt").to("cuda")

    outputs = []

    # beam search
    beams = model.generate(**tokens, num_beams=5, num_return_sequences=2, max_length=64)
    outputs += tokenizer.batch_decode(beams, skip_special_tokens=True)

    # sampling
    samples = model.generate(
        **tokens,
        do_sample=True,
        top_k=40,
        top_p=0.9,
        temperature=1.2,
        num_return_sequences=n - 2,
        max_length=64
    )
    outputs += tokenizer.batch_decode(samples, skip_special_tokens=True)

    return outputs[:n]

# %%
text = "Du lịch là một trong những ngành kinh tế quan trọng của nhiều quốc gia."
multi_translate(text)
# Out:
# ['Tourism is one of the most important economic sectors in many countries.',
#  'Tourism is one of the most important economic sectors of many countries.',
#  'tourism is one of the key economic sectors in many countries.']

# %% [markdown]
# ###### gpt

# %%
from openai import OpenAI
client = OpenAI(api_key="key")

# %%
models = client.models.list()
for m in models.data:
    print(m.id)
# Out:
# gpt-4-0613
# gpt-4
# gpt-3.5-turbo
# gpt-5.1-codex-mini
# gpt-5.1-chat-latest
# gpt-5.1-2025-11-13
# gpt-5.1
# gpt-5.1-codex
# davinci-002
# babbage-002
# gpt-3.5-turbo-instruct
# gpt-3.5-turbo-instruct-0914
# dall-e-3
# dall-e-2
# gpt-4-1106-preview
# gpt-3.5-turbo-1106
# tts-1-hd
# tts-1-1106
# tts-1-hd-1106
# text-embedding-3-small
# text-embedding-3-large
# gpt-4-0125-preview
# gpt-4-turbo-preview
# gpt-3.5-turbo-0125
# gpt-4-turbo
# gpt-4-turbo-2024-04-09
# gpt-4o
# gpt-4o-2024-05-13
# gpt-4o-mini-2024-07-18
# gpt-4o-mini
# gpt-4o-2024-08-06
# chatgpt-4o-latest
# gpt-4o-realtime-preview-2024-10-01
# gpt-4o-audio-preview-2024-10-01
# gpt-4o-audio-preview
# gpt-4o-realtime-preview
# omni-moderation-latest
# omni-moderation-2024-09-26
# gpt-4o-realtime-preview-2024-12-17
# gpt-4o-audio-preview-2024-12-17
# gpt-4o-mini-realtime-preview-2024-12-17
# gpt-4o-mini-audio-preview-2024-12-17
# o1-2024-12-17
# o1
# gpt-4o-mini-realtime-preview
# gpt-4o-mini-audio-preview
# o3-mini
# o3-mini-2025-01-31
# gpt-4o-2024-11-20
# gpt-4o-search-preview-2025-03-11
# gpt-4o-search-preview
# gpt-4o-mini-search-preview-2025-03-11
# gpt-4o-mini-search-preview
# gpt-4o-transcribe
# gpt-4o-mini-transcribe
# o1-pro-2025-03-19
# o1-pro
# gpt-4o-mini-tts
# o3-2025-04-16
# o4-mini-2025-04-16
# o3
# o4-mini
# gpt-4.1-2025-04-14
# gpt-4.1
# gpt-4.1-mini-2025-04-14
# gpt-4.1-mini
# gpt-4.1-nano-2025-04-14
# gpt-4.1-nano
# gpt-image-1
# gpt-4o-realtime-preview-2025-06-03
# gpt-4o-audio-preview-2025-06-03
# gpt-4o-transcribe-diarize
# gpt-5-chat-latest
# gpt-5-2025-08-07
# gpt-5
# gpt-5-mini-2025-08-07
# gpt-5-mini
# gpt-5-nano-2025-08-07
# gpt-5-nano
# gpt-audio-2025-08-28
# gpt-realtime
# gpt-realtime-2025-08-28
# gpt-audio
# gpt-5-codex
# gpt-image-1-mini
# gpt-5-pro-2025-10-06
# gpt-5-pro
# gpt-audio-mini
# gpt-audio-mini-2025-10-06
# gpt-5-search-api
# gpt-realtime-mini
# gpt-realtime-mini-2025-10-06
# sora-2
# sora-2-pro
# gpt-5-search-api-2025-10-14
# gpt-3.5-turbo-16k
# tts-1
# whisper-1
# text-embedding-ada-002

# %%
import json

evaluation_prompt = """
You are a professional machine translation evaluator.

Your task:
- Compare the meaning of the source and the prediction.
- Evaluate fluency and correctness of the English translation.
- Evaluate semantic accuracy and information preservation.

Score the translation from 0 to 10.

Return ONLY valid JSON:
{{"score": <number>}}
Do not add any text besides JSON.

Source (VI): "{src}"
Prediction (EN): "{pred}"
"""


def score_translation(src, pred):
    msg = evaluation_prompt.format(src=src, pred=pred)

    resp = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": msg}],
        temperature=0
    )

    text = resp.choices[0].message.content
    try:
        data = json.loads(text[text.find("{"): text.rfind("}")+1])
        return data.get("score", None)
    except:
        return None

# %%
def create_best_bad(src):
    preds = multi_translate(src, n=3)

    scored = []
    for p in preds:
        s = score_translation(src, p)
        if s is not None:
            scored.append((p, s))

    if len(scored) < 2:
        return None

    scored = sorted(scored, key=lambda x: x[1], reverse=True)
    chosen = scored[0][0]
    rejected = scored[-1][0]

    return {
        "prompt": "vi_en: " + src,
        "chosen": chosen,
        "rejected": rejected
    }

# %%
import json
import time

def build_dpo_dataset(sentences, batch_size=30, save_path="dpo_data.jsonl"):
    with open(save_path, "w", encoding="utf8") as f:

        for i in range(0, len(sentences), batch_size):
            batch = sentences[i:i+batch_size]
            print(f"=== Batch {i//batch_size + 1} ===")

            for vi in batch:
                item = create_best_bad(vi)
                if item:
                    f.write(json.dumps(item, ensure_ascii=False) + "\n")
                    print("OK:", vi)
                else:
                    print("Skip:", vi)
            time.sleep(1)

    print("DONE. Saved to", save_path)

# %%
build_dpo_dataset(sentences, batch_size=30)
# Out:
# === Batch 1 ===
# OK: Bởi vì mối quan hệ họ hàng có vai trò quan trọng trong xã hội, nên tồn tại một hệ thống phân cấp phức tạp các mối quan hệ.
# OK: Mức độ tự do kinh tế ở nhóm trung bình với hạng 90 toàn cầu.
# OK: Ngoài ra còn có thể kể tới chả Leberkäs , bánh mì kẹp chả Leberkässemmel , bánh mì Brezn , bánh chiên Ausgezogene ein rundes Schmalzgebäck và nước uống Münchner Bier .
# OK: Tự yêu bản thân cũng được coi là một vấn đề xã hội hoặc văn hóa.
# OK: Ngược lại, họ cho rằng Vũ Xuân Thiều đã bị bắn rơi trước khi kịp tiếp cận B 52, bởi chiếc F 4D do Thiếu tá Harry McKee và Đại úy John Dubler điều khiển.
# OK: Các công sứ Pháp từ 1900 1930 là Đến ngày 9 tháng 2 năm 1913 thì tỉnh này trở thành 1 đơn vị hành chính trực thuộc tỉnh Kon Tum được thành lập cùng ngày.
# OK: Trong một bản phác thảo, các nhân vật lạc vào Cánh đồng ý tưởng , nơi họ có thể nuôi trồng các ý tưởng mới giống như người nông dân.
# OK: Các mạch điện tử được sử dụng để miêu tả các phép tính Boole .
# OK: Năm 1940, Giáo sư tâm lý thực nghiệm và năm 1952 là Giáo sư Trường Đại học Sorbonne, Paris.
# OK: Cụ thể là trước mắt giao cho các nhà máy 50 công việc bằng các đơn đặt hàng nhà nước, còn 50 còn lại các nhà máy tự tìm đơn đặt hàng.
# OK: Tính đến ngày 31 tháng 3 năm 2011 cập nhật , tổng số người dùng Internet ước tính là 2,095 tỷ 30,2 dân số thế giới .
# OK: Thật sự 2 tấm bia này cũng là những tư liệu quý.
# OK: Nhóm biển phụ, biển viết bằng chữ là nhóm biển nhằm thuyết minh bổ sung nội dung nhóm biển bên trên hoặc được sử dụng độc lập.
# OK: Kornilov bị đánh bại, nhưng sau biến cố này, Chính phủ lâm thời cũng thể hiện rõ sự yếu ớt, bất lực, không đủ khả năng lãnh đạo đất nước.
# OK: Ngày 18 tháng 6 năm 2015, Skype thêm gương mặt của năm cảm xúc vào bộ icon dùng trong dịch vụ chat.
# OK: 2 vụ bắn rơi này không được phía Việt Nam xác nhận và có lẽ là không có thật .
# OK: Yakovlev có sự thù hận đặc biệt đối với Cách mạng Tháng Mười và luôn muốn phủ định chủ nghĩa cộng sản tại Liên Xô.
# OK: Nhà sở hữu phải tìm cách gắn kết hình ảnh thương hiệu và căn cước của thương hiệu càng gần với nhau càng tốt.
# OK: Một cành chiết từ cây bồ đề nguyên thủy đã được vua Asoka gửi tặng cho vua Devanampiya Tissa Thiên Ái Đế Tu tại Sri Lanka vào năm 247 TCN .
# OK: Người da trắng là sắc dân chủ yếu tại Utah, chiếm khoảng 95 dân số.
# OK: Hai cụm cây hoa giấy che mát phần mộ được lấy giống từ Huế nơi bà mất và khu lăng mộ của ông Nguyễn Sinh Sắc ở Đồng Tháp.
# OK: 79 Trong đó, trường hợp của đạo diễn Tạ Huy Cường là một ví dụ điển hình.
# OK: Những hành động này bị chỉ trích bởi các lực lượng chống Liên Xô.
# OK: Để làm rắc rối thêm vấn đề, các tổ chức này đã áp dụng nhiều cách gài bẫy các tổ chức Hướng đạo mà họ hất cẳng.
# OK: Sau đó, Đế chế Byzantine tạm thời kiểm soát được vùng phía đông đất nước cho tới khi người Ả Rập xuất hiện vào thế kỷ thứ VIII.
# OK: Di truyền học quần thể xem xét toàn bộ quần thể 8 và hệ thống học quan tâm đến sự tiến hóa của nhiều loài thuộc các nhánh tiến hóa .
# OK: Tổng mức đầu tư cho dự án là 109.111,742 tỷ đồng, tương đương 4.664,89 triệu USD tỷ giá 1 USD 23.390VND công bố tại Vietcombank ngày 25 tháng 5 năm 2020 .
# OK: Đa đạ đà là âm của một từ có nghĩa là nước, nguồn nước, sông của vùng người dân tộc sinh sống.
# OK: Đến giai đoạn Đông Sơn, đồng chuyển mạnh vào lĩnh vực đồ dùng hằng ngày các loại thạp, thố, trống đồng đòi hỏi sản xuất nhiều.
# OK: Lịch sử vương quốc Chăm Pa chính thức dừng lại ở đây.
# === Batch 2 ===
# OK: Viện Hóa học Vật liệu Phố Hoàng Sâm, Hà Nội 7.
# OK: Từ năm 1988 đến năm 1998, đã nhận được tổng số 1806 cuộc gọi.
# OK: Vào những năm 1770, Pierre Jaquet Droz , một thợ đồng hồ Thụy Sĩ, đã chế tạo ra một con búp bê cơ khí có thể viết khi cầm bút lông.
# OK: Năm 2000, Viện Khoa học xã hội Trung Quốc xác lập việc nghiên cứu nguyên nhân Liên Xô tan rã là đề tài cấp quốc gia.
# OK: Việc áp dụng công nghệ mới hoặc làm giảm chi phí sản xuất không được đưa vào kế hoạch.
# OK: 22 Ngày 25 tháng 8 năm 2023, tỉnh Đồng Nai bàn giao toàn bộ 2532 ha đất dự án giai đoạn 1 cho chủ đầu tư.
# OK: Lực lượng vũ trang nhân dân Việt Nam bao gồm Quân đội nhân dân Việt Nam , Công an nhân dân Việt Nam và Dân quân tự vệ .
# OK: Chính giữa, trên giáp nóc có treo một bức hoành khắc 3 chữ Đại thành môn theo chiều ngang, đọc từ phải sang trái.
# OK: Thời nhà Hán , gia tộc Tư Mã đời đời đều ở đây.
# OK: Khi vụ án mạng đang diễn ra, Bella đã bước vào phòng của hai vợ chồng.
# OK: Công việc khảo sát địa chất thực tế hay thực địa thay đổi tùy theo nhiệm vụ được giao đặt ra .
# OK: Vì nội quy thay đổi không được công bố nên quyết định số ủy viên được xem là quyết định kín.
# OK: Thuật ngữ địa chất học được Jean André Deluc sử dụng lần đầu tiên vào năm 1778 và được Horace Bénédict de Saussure sử dụng là thuật ngữ chính thức từ năm 1779.
# OK: Tứ trụ có đôi câu đối chữ Hán Văn Miếu môn tức là cổng tam quan phía ngoài.
# OK: Sau Chiến tranh Falklands 1982 , các nhà lập kế hoạch quân sự Hoa Kỳ lo ngại về khả năng tấn công tầm xa của Liên Xô.
# OK: , Đi biển mà không mặc áo phao là quá chủ quan , Biết có bão mà vẫn cố đi, tiếc tiền à?
# OK: Việc không có được hòa bình như mong đợi khiến nhân dân và binh sỹ Nga trở nên bất bình.
# OK: Tuy nhiên, các học thuyết Ấn Độ vẫn ảnh hưởng tư tưởng phương Tây thông qua hội Thông Thiên, một tổ chức thời đại mới phổ biến trong giới tri thức Âu Mỹ.
# OK: Tất cả các tổ chức Nam và Nữ Hướng đạo Hà Lan nhập lại vào năm 1973 thành Hướng đạo Hà Lan SN .
# OK: Trong các sinh vật đa bào, mỗi tế bào trong cơ thể của cơ thể xuất phát từ một tế bào hợp tử duy nhất.
# OK: Một chiếc do Lê Minh Huân lái rơi gần bờ biển Sầm Sơn, gần xác chiếc F 105 do chính anh bắn hạ.
# OK: Ví dụ, chỉ với hai chiếc B 52, trong hai giờ, có thể giám sát 360.000 km 2 bề mặt đại dương .
# OK: Không lâu sau khi nhậm chức Tổng Bí thư, Tô Lâm thăm chính thức Trung Quốc .
# OK: Đất mặt thường được lột đi và lưu trữ ở gần đó để khôi phục dọc theo hai bên con đường mới được xây dựng.
# OK: Từ năm 1371 đến năm 1389, ông tổ chức nhiều cuộc tấn công ra Thăng Long kinh đô của Đại Việt.
# OK: Bầu ngày 8 tháng 5 năm 1960 .
# OK: Xfce là một dự án nhỏ được thành lập năm 1996, 7 và tập trung vào hiệu năng và mô đun, giống với LXDE được bắt đầu vào năm 2006.
# OK: Hợp tác quốc tế ban đầu trên mạng ARPANET là rất hiếm.
# OK: Thi hành thẩm tra việc tuân thủ Điều lệ Đảng , Cương lĩnh chính trị, nghị quyết Đại hội Đảng,...
# OK: Cuối thế kỉ 20, dân số tiểu bang Utah đã tăng lên nhanh chóng.
# === Batch 3 ===
# OK: Vào ngày 26 tháng 1 năm 2020, Lifetime đã phát hành một bộ phim có tên Chris Watts Confessions of a Killer như một phần của loạt phim truyện Ripped from the Headlines .
# OK: Tư vấn tâm lý thường được nhầm lẫn với tâm lý học lâm sàng vì chúng khá giống nhau.
# OK: 14 Trong khi đó, tâm lý học bình dân thường dùng để chỉ hiểu biết về tâm lý của đại chúng, phân biệt với hiểu biết của nhà tâm lý học.
# OK: Những tiểu thái giám xinh đẹp chừng mười mấy tuổi được tĩnh thân để tiến cung gọi là đồng giám hay hài giám thường được hoàng hậu , quý phi , quý nhân yêu thích.
# OK: Trên đường trở về quê hương Koliya, đoàn rước kiệu đi qua một khu vườn gọi là Lâm tỳ ni.
# OK: nối các huyện trong tỉnh, huyện lộ đường cái, đại lộ...
# OK: Là một bộ môn khoa học, tâm lý học từ lâu đã cố gắng để chống lại những chỉ trích cho rằng nó là một bộ môn khoa học yếu .
# OK: Đến năm 2013, do ảnh hưởng bởi Đại suy thoái , nền kinh tế đối mặt với áp lực lớn từ nợ xấu , lạm phát cùng nợ công tăng mạnh.
# OK: Giai đoạn từ năm 2011 đến 2014 triển khai báo cáo đầu tư và thu xếp vốn cho dự án.
# OK: Giai đoạn phát dục genital stage Độ tuổi dậy thì trở đi Vùng tập trung khoái cảm Hứng thú tính dục trưởng thành Maturing Sexual Interests .
# OK: Nhưng ngay sau đó nhờ gặp được Sa di Nigrodha, ông theo Phật giáo cải hối và làm rất nhiều điều thiện, chống lại bạo lực.
# OK: Trong 10 tháng trước đó, hoàng hậu Maya được vua cho phép giữ 8 giới thanh tịnh nhân dịp lễ cầu mưa Asadh Utsav .
# OK: Ngoài ra, Không quân Hoa Kỳ còn nâng cấp hiệu quả tấn công và tuần tra hàng hải của B 52 bằng thiết bị AN ASQ 236 Dragon s Eye.
# OK: Sau khi Liên Xô tan rã, lớp Đảng viên trung thành với chủ nghĩa cộng sản trong Đảng Cộng sản Liên Xô vừa căm phẫn cực độ, vừa bất lực.
# OK: Sinh học bắt đầu nhảy vọt với sự cải tiến vượt bậc kính hiển vi bởi Anton van Leeuwenhoek .
# OK: Mỗi năm Quốc hội họp thường kỳ 2 lần.
# OK: Nhà nước Xô viết trong tiếng Nga có nghĩa là một nước cộng hòa được thành lập theo cấu trúc nghị viện .
# OK: Với việc ra mắt trailer đầu tiên của phim vào tháng 12 năm 2014, việc Diane Lane và Kyle MacLachlan được lựa chọn vào vai bố mẹ của Riley cũng được tiết lộ.
# OK: Nguyên tắc xếp chồng để chỉ các lớp đá trầm tích trẻ hơn nằm trên các lớp đá trầm tích cổ trong vùng yên tĩnh kiến tạo.
# OK: Đại úy Nguyễn Văn Tỉnh làm Tham mưu trưởng.
# OK: Ước tính 70 phần trăm lưu lượng truy cập Internet của thế giới đi qua Ashburn , Virginia .
# OK: Chúng là một phần của môi trường mà một tiến trình chạy.
# OK: Hầu như toàn bộ số người này đã rời đi ngay sau khi nước này giành lại độc lập từ Pháp.
# OK: Inside Out đạt được vị trí dẫn đầu vào tuần thứ 3 với 29,8 triệu đô doanh thu.
# OK: là một trong những nguyên liệu tạo hương liệu trong món ăn.
# OK: 25 Tháng 5 năm 2017, Hương Giang nhận nhiều chỉ trích từ dư luận vì sử dụng lời lẽ khiếm nhã với nghệ sĩ Trung Dân trong chương trình Siêu sao đoán chữ .
# OK: Trầm hương của ta dùng đều là loại thượng hảo hạng từ xứ Ca tây Kāsi đưa về.
# OK: Đến cuối ngày 26 tháng 8, bộ phim cán mốc 150 tỷ.
# OK: Vì thế, ý tưởng về 1 sân bay mới được ra đời nhằm thúc đẩy kinh tế vùng Nam Bộ và cả nước.
# OK: Cánh được cải tiến vào năm 1964 trong chương trình ECP 1050 với chi phí 219 triệu Đô la Mỹ.
# === Batch 4 ===
# OK: Một chương trình đang chạy có thể truy cập các giá trị của các biến môi trường cho mục đích cấu hình.
# OK: Ngoài ra, thái giám vì bị khiếm khuyết các cơ ở hạ bộ nên thường hay bị són nước tiểu ra quần, thành thử nặng mùi nên cũng hay bị chế giễu.
# OK: Nhiều sự kiện biệt hóa tạo ra một hệ thống có cấu trúc cây về các mối quan hệ giữa các loài.
# OK: bên cạnh các vườn quốc gia, khu bảo tồn thiên nhiên Chư Yang Sin , Easo 48 ...
# OK: Đất nước đặc trưng bởi sự bao trùm của bộ máy đảng trong mọi chức năng xã hội và các kế hoạch phát triển kinh tế.
# OK: Năm 2002 , ngôi chùa Mahabodhi Đại Giác Ngộ tự ở Bodh Gaya đã trở thành Di sản thế giới .
# OK: Theo các Phật tử, ông đã nhập Niết bàn thông qua các mức thiền định , một trạng thái giải thoát hoàn toàn khổ đau của cuộc sống.
# OK: Cả hai đều chống lại sự cầm quyền độc Đảng nhưng cũng xung đột với nhau cả trong các trường đại học và trên đường phố trong thập kỷ 1980.
# OK: Bà Trần Lệ Xuân còn châm dầu vào lửa khi phát biểu của bà về việc tự thiêu của hòa thượng Thích Quảng Đức Để cho họ cháy và chúng tôi sẽ vỗ tay .
# OK: Tuy nhiên tướng Thục là Khương Duy và Dương Nghi cho quay lại giả cách như muốn đánh.
# OK: Nhà Trần đổi hai châu này thành hai châu Thuận và châu Hóa nay là vùng từ nam Quảng Trị cho đến Đà Nẵng, Điện Bàn .
# OK: Tương tự như vậy, phương rẽ trái sẽ di chuyển sang làn bên trái ngoài cùng.
# OK: Không may chồng bà mất sớm, để lại cho bà một người con trai còn đi chập chững.
# OK: Khoảng 127.000 vụ tai nạn lao động đã xảy ra trong bốn năm từ 1928 đến 1932 .
# OK: Các con Như vậy, phần lớn người thân của Trần Lệ Xuân đều có kết cục bi thảm
# OK: và có nguy cơ rất lớn rơi vào tình trạng đói nghèo.
# OK: 35 36 Về phía Mỹ, các tài liệu không thừa nhận có bất cứ chiếc B 52 nào bị bắn rơi trong đêm 28 tháng 12.
# OK: Tư Mã Ý sau đó đã nói với thuộc hạ rằng Gia Cát Lượng không thể sống lâu.
# OK: Lê Minh Hưng sinh ngày 11 tháng 12 năm 1970 tại Hà Tĩnh là một chính khách Việt Nam .
# OK: Ngày 15 tháng 8, bà Lucie Aubrac sinh hạ bé gái Elizabeth Aubrac .
# OK: Tính từ thời điểm này cho đến hết ngày 11 tháng 6 năm 2025, Tỉnh Đắk Lắk có 1 thành phố, 1 thị xã và 13 huyện.
# OK: Nhà Lê trung hưng sau 60 năm giao tranh đã chiến thắng, diệt Nhà Mạc .
# OK: Hoặc là giá trị thực hoặc trong phải trong một khoảng tin cậy.
# OK: Nhưng rồi ông Nhu vẫn bỏ qua tất cả, đánh điện gọi vợ về.
# OK: Máy tính có thể được phân loại tùy theo cách thức người dùng vận hành.
# OK: Nhiều quốc gia trong đó có Mỹ và các nước châu Âu đã cung cấp viện trợ lương thực để giúp nước Nga Xô viết giải quyết nạn đói.
# OK: Liên minh Viễn thông Quốc tế ITU ước tính, vào cuối năm 2017, 48 người dùng cá nhân thường xuyên kết nối Internet, tăng từ 34 vào năm 2012.
# OK: Khi lớp bùn được gạt ra, nhóm khai quật nhìn thấy người chết đặt nằm ngửa, thân bó vải, hai tay để xuôi, chân duỗi thẳng.
# OK: Xây dựng và bảo dưỡng đường sá là một hoạt động kinh tế vẫn chủ yếu thuộc lĩnh vực công dù thường xuyên qua các nhà thầu tư nhân .
# OK: Sinh học tiến hóa cũng bao hàm cả lĩnh vực cổ sinh vật học .
# === Batch 5 ===
# OK: Sự trì hoãn và tự nuông chiều bản thân không khác gì những tay chủ nợ rồi sẽ đến đòi bạn trả lãi Rory Vaden .
# OK: Trước khi trở thành Phật tử, ông có tính khí rất hung bạo, đã giết nhiều anh em của mình để cướp ngôi vua cũng như đã xua quân đánh chiếm nhiều lãnh thổ.
# OK: Kiến trúc Von Neumann chia máy tính ra làm bốn bộ phận chính Bộ nhớ máy tính có 2 phần chính là bộ nhớ trong và bộ nhớ ngoài.
# OK: Quốc Học là trường Trung học đệ Nhất cấp đầu tiên ở Huế.
# OK: Vào lúc khuya ngày 4, rạng sáng ngày 5, lễ tắm tượng Bà được tổ chức ngay tại điện thờ.
# OK: Chuyến bay 171 cất cánh từ đường băng 23 của Sân bay Ahmedabad lúc 13 38 IST 08 08 UTC trên đường đến sân bay London Gatwick .
# OK: Thống kê chính là việc cung cấp công cụ để nói trước và dự báo việc sử dụng các dữ liệu thông qua các mô hình thống kê.
# OK: Nó đã được chứng minh rằng loại công việc có thể dẫn đến các vấn đề liên quan đến sức khỏe xuống dòng.
# OK: Ngoài các diễn viên, tác phẩm còn có sự góp mặt của nhiều Tiktoker nổi bật như Hải Triều, Hà Pu, Phạm Vinh, David Vinh...
# OK: Chiều dài thiết kế của tàu khoảng 20,8 mét, với chiều dài lớn nhất ghi nhận là 24,04 mét.
# OK: Các cơ chế phát triển và di truyền chung của cả động vật và thực vật được nghiên cứu trong sinh học phân tử , di truyền phân tử và sinh học phát triển .
# OK: Đến ngày hôm sau, hai đại diện của hai du thuyền cũng đã thông báo và xin lỗi trên các nền tảng truyền thông chính thức.
# OK: Như năm 2006, khoảng 3000 mangaka chuyên nghiệp đang làm việc tại Nhật Bản .
# OK: Ông bắt đầu tưởng tượng điều gì xảy ra trong tâm trí con người khi các cảm xúc được thiết lập.
# OK: Đảng Cộng sản Liên Xô lãnh đạo xã hội tiến hành kháng chiến.
# OK: Thay vì có hình dạng cố định, nó là một tập hợp khổng lồ các hạt năng lượng.
# OK: Thorndike , đã sử dụng khái niệm hiểu biết xã hội để miêu tả kỹ năng hiểu và quản lý người khác.
# OK: Lúc tắm bà, cửa điện sẽ được đóng cửa, không cho du khách vào tham quan.
# OK: Công suất tối đa của sân bay Tân Sơn Nhất khoảng 25 triệu lượt khách mỗi năm.
# OK: Chủ tịch Quốc hội không được đồng thời là thành viên của Chính phủ .
# OK: Ái kỷ là một khái niệm trong lý thuyết phân tâm học , được giới thiệu phổ biến trong bài tiểu luận On Narcissism của Sigmund Freud 1914 .
# OK: Hai phiên bản của Giao thức Internet tồn tại, IPV4 và IPV6.
# OK: Phong tục học nghiên cứu nhóm hành vi của một tập hợp cá thể.
# OK: là từ tiếng Nhật nghĩa là người sáng tác truyện tranh .
# OK: là Quảng trường Kim Nhật Thành quảng trường công cộng lớn thứ ba trên thế giới nơi diễn ra các sự kiện quốc gia của đất nước.
# OK: Số ủy viên trong Bộ Chính trị không nhất định nên có thể thay đổi.
# OK: Vào ngày 14 tháng 12 năm 1960 , một chiếc B 52G lập kỷ lục thế giới bay không tiếp thêm nhiên liệu một quãng đường 10.078,84 dặm 8.762 hải lý, 16.227 km .
# OK: Nên ông tiếp tục yên lặng ngồi quán chiếu tâm chúng sinh dưới gốc cây Bồ đề một thời gian là 7 tuần lễ.
# OK: Các ISP phải thuê đường và cổng của một IAP .
# OK: Liên Xô trải rộng trên 10.000 km 6,200 mi theo hướng đông sang tây qua 10 múi giờ từ UTC 2 đến UTC 12 và hơn 7.200 km 4.500 mi từ bắc xuống nam .
# === Batch 6 ===
# OK: Văn ngôn với chữ Hán ghi âm Hán Việt được dùng trong các văn bản hành chính trước thế kỷ 20.
# OK: Suy luận có thể mở rộng để dự báo, tiên đoán và ước tính giá trị không được chú ý đến hoặc sự liên kết với tổng thể được nghiên cứu.
# OK: Vùng miền nam Utah với phong cảnh sa mạc là địa điểm ưa thích cho những bộ phim cao bồi.
# OK: Tháng 3 năm 2015, tại hội thảo khoa học Xây mới sân bay Long Thành hay nâng cấp Tân Sơn Nhất , PGS.TS.
# OK: Cũng như Chrisman 1998 13 và Van Den Berg 1991 .
# OK: Quan hệ họ hàng đóng một vai trò rất lớn ở Việt Nam.
# OK: Các loại máy tính phục vụ thường có hai hay nhiều bộ xử lý.
# OK: Đây cũng là khóa đầu tiên tiến hành việc Lấy phiếu tín nhiệm với các chức danh mà Quốc hội đầu ra vào kỳ họp thứ 5 diễn ra vào tháng 5 2013.
# OK: Dak Lak có nghĩa là nước mênh mông.
# OK: Các đơn vị tổ chức trung gian là Huyện và Tỉnh .
# OK: Dấu hiệu, tín hiệu, đánh dấu hay các tính năng khác thường được sử dụng để làm quyền ưu tiên trở nên rõ ràng.
# OK: bắt nguồn từ chữ iō 2 trong tiếng La tinh một cụm từ biểu thị niềm vui, niềm hân hoan.
# OK: Sau khi được huấn luyện một số kỹ năng chiến đấu cơ bản, Cường cùng các tân binh khác lên đường ra mặt trận.
# OK: Phim trường cũng được lực lượng công binh rà phá lại bom mìn để đảm bảo an toàn trong quá trình quay.
# OK: để tạo động lực cho bạn thân phấn đấu hơn nữa.
# OK: Ví dụ Về phương pháp chế tác các công cụ đồng, có thể nhận thấy ngoài một số ít công cụ cỡ nhỏ như lưỡi câu, mũi nhọn...
# OK: Cả cuộc đời của J.Piaget là cuộc đời của nhà Bác học và lao động không ngừng.
# OK: Do phân bổ tối đa nguồn lực cho ngành công nghiệp cùng với năng suất nông nghiệp giảm kể từ khi tập thể hóa, nạn đói đã xảy ra.
# OK: Giai đoạn 1954 1960, Trần Lệ Xuân chiếm cả một rừng cây quý 200 mẫu tại Định Quán , lấy gỗ chế tạo báng súng xuất khẩu nước ngoài.
# OK: Thành viên của Chính phủ không phải là đại biểu Quốc hội được mời tham dự các phiên họp toàn thể của Quốc hội.
# OK: Sau đó ông đi vào miền Nam và sinh sống tại Làng Hòa An, Cao Lãnh, Đồng Tháp nay là xã Hòa An , thành phố Cao Lãnh cho đến cuối đời.
# OK: Thời kỳ đó chủ yếu là xe hơi Pháp, đó là những chiếc Citroen , Peugeot và Renault , ba thương hiệu nổi trội hồi đầu thế kỷ XX.
# OK: Vua Gia Long nhà Nguyễn chính thức sử dụng quốc hiệu Việt Nam từ năm 1804.
# OK: Một số lính Giải phóng, bao gồm Cường, phải ở lại ngăn cản lực lượng biệt kích dù của Quang tấn công nhằm câu giờ cho những người khác rút lui.
# OK: Tới năm đó, nhà Lê đã tổ chức được 12 khoa thi cao cấp, Lê Thánh Tông 1460 1497 đã tổ chức đều đặn cứ ba năm một lần, đúng 12 khoa thi.
# OK: Coi đó là phương pháp mang lại hiệu quả hơn hẳn những phương pháp đương thời.
# OK: Lấy Phạm Ứng Thần giữ chức Thượng thư kiêm chức Đề điệu Quốc Tử viện để trông nom công việc học tập tại Quốc Tử giám .
# OK: Người Chăm thờ các vị thần như Po Nagar , Po Rome ,...
# OK: Máy tính hiện đại có khả năng tuân theo các tập hợp lệnh tổng quát, được gọi là chương trình .
# OK: Dưới cấp tỉnh và tương đương là các đơn vị hành chính phường , xã , đặc khu , được gọi chung là cấp xã.
# === Batch 7 ===
# OK: Kịch bản tương tự có thể xảy ra với sân bay Long Thành .
# OK: Kết quả là, toàn bộ chương trình bị tạm dừng trong sáu tháng.
# OK: Gian đầu hồi và gian thứ ba mặt trước, mặt sau đều có cửa bức bàn chấn song con tiện dẫn sang nhà Hậu đường.
# OK: Ngoài ra, theo lời kể của một người phụ nữ và cũng là nạn nhân sống sót trong tổng số mười người sống sót, chị đi cùng chồng, hai con và người thân.
# OK: Một bộ phận cộng đồng mạng đã đặt những câu hỏi như Tại sao lại đi chơi giữa lúc trời báo bão?
# OK: Để thực hiện một suy luận khi chưa biết số lượng, hoặc nhiều ước lượng được đánh giá bằng cách sử dụng mẫu.
# OK: Bakatin đã làm tê liệt Lực lượng Cảnh sát Liên Xô khi biệt phái nhiều sĩ quan sang các cơ quan, tổ chức khác và xóa bỏ mạng lưới đặc tình của lực lượng này.
# OK: Tổ chức Hướng đạo quốc tế lớn nhất là Tổ chức Phong trào Hướng đạo Thế giới , thành lập năm 1920.
# OK: Trong những năm 1950, quỹ Rockefeller và quỹ Ford phối hợp với Cơ quan Tình báo Trung ương Hoa Kỳ CIA tài trợ các nghiên cứu về tâm lý chiến.
# OK: Cuối cùng thì tàu được lật thành công vào khoảng 2 giờ sáng cùng ngày.
# OK: Hiện đại hóa đã mang lại những thay đổi lớn trong nhân khẩu Algérie.
# OK: Phần nửa diện tích của khu này là sân phía trước.
# OK: Ngoài ra việc tập thể hóa được tiến hành không tuân theo nguyên tắc tự nguyện, mang nặng tính cưỡng ép cũng đã khiến nhiều nông dân trở nên bất bình.
# OK: Các quốc gia này đều có hoặc từng có quân Liên Xô trú đóng trên lãnh thổ và bị Liên Xô chi phối về mặt chính trị và quân sự.
# OK: Tôi có khoảng 50 nhân viên và thậm chí nhiều anh em hơn.
# OK: Việc huấn luyện đội bay B 52 bao gồm năm tuần lớp học trên mặt đất và bốn tuần bay, tích lũy 35 50 giờ bay.
# OK: Nghiên cứu phong tục học cho thấy có 18 ngôn ngữ tại Algérie, chia thành hai nhóm chính là tiếng Ả Rập và Tamazight, ngoài ra còn có tiếng Korandje .
# OK: Nhóm biển hiệu lệnh là nhóm biển để báo các hiệu lệnh phải chấp hành.
# OK: Một cách phân loại máy tính ít mơ hồ hơn là theo mức độ hoàn thiện của công nghệ.
# OK: Cho đến mãi 30 năm sau, khi Đại dịch COVID 19 xảy ra, di sản về y tế của Liên Xô vẫn giúp nước Nga chế tạo vacxin với tiến độ rất nhanh chóng.
# OK: Sau này người Sri Lanka đã gọi cây bồ đề này là Sri Maha Bodhi , nghĩa là Cây Bồ Đề Cát Tường Vĩ Đại .
# OK: Nguồn vốn đến từ số tiền tiết kiệm được khi thực hiện giai đoạn 1 của dự án khoảng 4000 tỷ .
# OK: Phật dạy đại đức A nan đà rằng Cuộc đời ông cũng gặp nhiều người xấu muốn ám hại.
# OK: Có nhiều nguyên tắc quan trọng được phát triển từ khi sơ khai đến khi nó trở thành một ngành khoa học chính thức.
# OK: Tương tự cách biến các tuyến đường sắt từ đường đơn thành đường đôi , tuyến đường mới không phải luôn luôn được xây dựng dọc theo tuyến đường có sẵn.
# OK: 28 Theo các tài liệu Liên Xô được giải mật, trong khoảng thời gian từ năm 1937 tới năm 1938, có 1.548.367 người bị bắt giữ, trong đó 681.692 bị xử bắn.
# OK: Sau chiến tranh, tại những vùng lãnh thổ của Đế chế Nga cũ đã xuất hiện các nước cộng hòa xã hội chủ nghĩa mới thuộc Liên Xô Moldavia, Estonia, Latvia, Litva, Karelia.
# OK: Sai số bình phương có nghĩa khi được sử dụng cho việc ước lượng hiệu quả thu thập dữ liệu, một lớp được sử dụng rộng rãi trong ước lượng.
# OK: Lịch sử tự nhiên lại đặt nặng tư tưởng của Aristotle , đặc biệt là tư tưởng trật tự sự sống là cố định, bất biến.
# OK: Xem thêm Lịch sử phần cứng máy tính .
# === Batch 8 ===
# OK: Dragon s Eye được tích hợp dưới cánh máy bay ném bom B 52H, sở hữu radar quét mảng điện tử tiên tiến.
# OK: Ngày nay, Roscosmos đã vượt qua những thay đổi trong lĩnh vực công nghiệp vũ trụ của Nga và đang tiến lên với các thiết kế tên lửa và tàu vũ trụ mới.
# OK: Radar Dragon s Eye bổ sung cho cụm nhắm mục tiêu hồng ngoại Litening vốn có trên B 52, tăng cường khả năng trinh sát và tấn công tàu chiến của máy bay.
# OK: Một lỗ hổng của việc tổ chức giao thông có thể dẫn đến tắc nghẽn giao thông.
# OK: Lỗi chú thích Thẻ ref có tên Paul 2002 COM được định nghĩa trong references không được đoạn văn bản trên sử dụng.
# OK: Nhóm biển chỉ dẫn là nhóm biển báo dùng để cung cấp thông tin và các chỉ dẫn cần thiết cho người tham gia giao thông.
# OK: Chi tiết về các lĩnh vực cụ thể trong Tâm lý học có thể tìm Các chủ đề về tâm lý học và Các môn tâm lý .
# OK: Sau đây là một số tổ chức khí tượng phi chính phủ Dưới đây là những tổ chức khí tượng của chính phủ và hàn lâm.
# OK: Ông qua đời tại Nghệ An vào ngày 9 tháng 11 năm 1950 , chỉ gần 1 tháng sau chiến thắng Chiến dịch Biên giới , hưởng thọ 62 tuổi.
# OK: Tác phẩm sau đó được công chiếu chính thức trên toàn quốc vào ngày 22 tháng 8 năm 2025 nhân dịp kỷ niệm 80 năm ngày Quốc khánh Việt Nam .
# OK: Ông lập gia đình với bà Nguyễn Thị Giáng 1897 1960 và có với nhau ba người con nhưng đều chết sớm.
# OK: Kẻ bị bắn trúng mũi tên này không dám rút mũi tên ra việc này sẽ gây mất máu và dẫn đến tử vong rất nhanh.
# OK: Thay vào đó, dữ liệu được thu thập và mối tương quan giữa các yếu tố dự báo và trả lời cho các khám phá và kiểm tra.
# OK: Chiếc B 52 cũng đạt được tỉ lệ thời gian sẵn sàng chiến đấu cao nhất trong số ba kiểu máy bay ném bom hạng nặng đang được Không quân Hoa Kỳ sử dụng.
# OK: Văn miếu được xây dựng từ năm 1070 , tức năm Thần Vũ thứ hai đời Lý Thánh Tông .
# OK: Ngôi mộ của Putri Champa công chúa Chăm vẫn còn thấy ở Trowulan , nơi xưa kia là kinh đô của Majapahit.
# OK: Nước Việt Nam là đại gia đình của tôi.
# OK: Đây là tuyến kết nối đường T1 với cao tốc Thành phố Hồ Chí Minh Long Thành Dầu Giây .
# OK: Tuy nhiên, xuất bản và duy trì các trang web lớn, chuyên nghiệp với thông tin hấp dẫn, đa dạng và cập nhật vẫn là một đề xuất khó khăn và tốn kém.
# OK: Khoảng 90 dân số tập trung tại khu vực ven biển phía bắc, trong khi cư dân tại Sa mạc Sahara chủ yếu tập trung tại các ốc đảo.
# OK: Phim ngắn có tên Lava được chiếu cùng với Inside Out tại rạp.
# OK: Trong thập niên 1990 , việc phát triển của công nghệ World Wide Web đã làm cho ngay cả những người không chuyên nghiệp cũng có thể sử dụng internet.
# OK: Sang ngày hôm sau, ông có cuộc gặp mặt với các lãnh đạo Trung Quốc như Tập Cận Bình , Lý Cường , Triệu Lạc Tế và Vương Hỗ Ninh .
# OK: Ông Dharmapala ghi trong nhật ký ngày 21 1 1891 như sau Tại ngôi đền của ông Mahant hai bên cửa có những tượng Đức Thế Tôn đang thiền định hay đang thuyết pháp.
# OK: Các nghiên cứu liên ngành cũng phổ biến và các học giả như Georgy Shchedrovitsky đã phát triển các hệ thống lý luận chung về hành vi con người.
# OK: Chiếc YB 52 thực chất là chiếc XB 52 thứ hai với nhiều trang thiết bị hoạt động cất cánh lần đầu ngày 15 tháng 4 năm 1952 .
# OK: 31 Inside Out là bộ phim hoạt hình đầu tiên được phát hành dưới định dạng Dolby Vision và là phim thứ hai của Disney sau Tomorrowland .
# OK: Ngày 22 tháng 2 năm 1986, chia huyện Đắk Nông thành 2 huyện Đắk Nông và Đắk R lấp .
# OK: Ông Pan nói, Tôi không thể dừng lại hay chậm lại.
# OK: Nhưng Chính phủ Lâm thời vẫn chủ trương theo đuổi thế chiến thứ nhất bên phía khối Hiệp ước với Anh Pháp , bất chấp việc đất nước đã kiệt quệ vì chiến tranh.
# === Batch 9 ===
# OK: Thậm chí trước khi Tào Tháo mất, Tư Mã Ý đã cận kề với người kế vị ông ta là Tào Phi .
# OK: Các nhà cung cấp dịch vụ Internet ISP thiết lập kết nối toàn cầu giữa các mạng riêng lẻ ở nhiều cấp độ khác nhau.
# OK: Thương hiệu là tên gọi, thuật ngữ, thiết kế, hình tượng hoặc các dấu hiệu khác giúp phân biệt một tổ chức hoặc một sản phẩm với đối thủ trong mắt của người tiêu dùng.
# OK: như Đường 2 , đường 70 Hà Nội Tuyên Quang Lào Cai , đường 3 Hà Nội Thái Nguyên Cao Bằng , đường 5 Hà Nội Hải Phòng .
# OK: Không cần xây sân bay Long Thành quá tốn kém khi nợ công đã lên đến 80 tỉ USD .
# OK: Tuy nhiên, trên thực tế, cả hai dòng phái đều không tạo lập được khoa học khách quan về ý thức .
# OK: Vào tháng 5 năm 2019, một chiếc máy bay thứ hai được đưa trở lại từ nơi lưu trữ dài hạn tại Davis Monthan.
# OK: Việc phân loại các ngành con của sinh học rất đa dạng.
# OK: Tổng thiệt hại chiến tranh bao gồm các vùng lãnh thổ do Liên Xô sáp nhập năm 1939 1945.
# OK: Đồng Xoài giữ chức vụ Bí thư Thành ủy nhiệm kỳ 2015 2020 kể từ ngày 1 1 2020.
# OK: Về tỉ số giới tính trung bình vào năm 2019 là 99,1 nam 100 nữ.
# OK: Kinh Phật cho biết Cấp Cô Độc đã chở nhiều xe vàng và lót vàng khắp sân vườn để mua lại nó từ tay Thái tử Kỳ đà, con trai quốc vương Ba tư nặc.
# OK: Việc Nga hóa và Xô viết hóa hệ thống giáo dục và xã hội ở các quốc gia tự trị trên lãnh thổ Liên Xô cũng bị những nhóm này chỉ trích.
# OK: Sự giống nhau và khác nhau giữa các loại tế bào cũng được nghiên cứu trong sinh học phân tử và tế bào học.
# OK: Luật lệ trên đường và quy cách lái xe là những thông lệ và quy trình chung mà người tham gia giao thông bắt buộc phải tuân theo.
# OK: Ngoài ra còn có giáo, lao, dao găm, kiếm, qua, rìu chiến...
# OK: Tất đạt đa ăn xong cảm thấy thân thể khoẻ mạnh.
# OK: Cuộc bỏ phiếu vẫn không có tác động nào.
# OK: Do bộ phim có sự tham gia của nhiều diễn viên trong chương trình Saturday Night Live, các nhà làm phim dành một tuần để nghiên cứu các phân cảnh trong chương trình này.
# OK: Những nhà khoa học mà tôi tiếp xúc cũng rất thích VnExpress.net, vì thông tin cập nhật nhanh, bài vở phong phú, truy cập thuận lợi, kể cả từ nước ngoài.
# OK: Nước này xếp hạng 14 về trữ lượng dầu khí , với 11.8 tỷ thùng trữ lượng đã được chứng minh và ước tính số thực có thể vượt mức trên.
# OK: Tới thập niên 1930, cùng với sự ra đời của các môn âm nhạc, mỹ thuật hiện đại, điện ảnh cũng bắt đầu được người Việt Nam thực hiện.
# OK: Nếu để việc khó và quan trọng đến cuối ngày, lúc đó năng lượng và sự hưng phấn đã giảm đáng kể dẫn đến sẽ khó hoàn thành tốt những công việc hệ trọng.
# OK: Việc không hoàn thành chỉ tiêu có thể bị khép vào tội phản quốc.
# OK: Ước tính kinh tế Liên Xô đã sụt giảm 20 do cuộc khủng hoảng chính trị năm 1991.
# OK: nhằm thúc đẩy sự tiến bộ của các dân tộc chậm tiến tại các vùng này.
# OK: Điều này cho thấy Tư Mã Ý là một tướng tài, không chỉ giỏi mưu kế mà còn biết tự lượng sức mình.
# OK: Ở vùng Tây Nguyên truyền thống nhiều gia đình trong một gia tộc cư trú trong một nhà dài vẫn còn phổ biến.
# OK: Những khái niệm về nhiệt động học tiếp tục được phát triển bởi James Clerk Maxwell 1871 và Max Planck 1903 .
# OK: Nhưng nó cũng bị phản bác, đáng chú ý nhất là từ những nhà hành vi học cực đoan như John B.
# === Batch 10 ===
# OK: Tương tự, Xô viết địa phương bầu ra Ủy ban hành chính Испольнительный коммитет , viết tắt là Исполком Ispolkom để đảm nhiệm chức năng hành pháp ở địa phương.
# OK: Khảo sát của hai cơ quan điều tra dư luận ở Nga cho thấy đa số người dân Liên Xô cũng không muốn đất nước Liên Xô tan rã.
# OK: Khi trình bày trên văn bản, ta có thể tạo ra một khoảng cách nhỏ, giữa từ cuối cùng với dấu chấm than, hoặc viết sát vào nhau cũng được.
# OK: Doanh nghiệp nào không nhìn nhận ra và không biết duy trì những tải sản quý như vậy đều có thể chịu sự thất bại nặng nề.
# OK: Nó hoạt động mà không có một cơ quan quản lý trung ương nào.
# OK: Họ không thể làm thông qua biện pháp dân chủ vì trưng cầu dân ý cho thấy 76 cử tri vẫn ủng hộ duy trì Liên Xô .
# OK: Các phi đội B 52 đã rèn luyện kỹ thuật bay lướt trên biển, giúp họ vượt qua hệ thống phòng thủ kiên cố của đối phương và tấn công các tàu chiến Liên Xô.
# OK: Thang đo danh nghĩa không có thứ tự xếp hạng có ý nghĩa trong các giá trị, và cho phép chuyển đổi một một.
# OK: Kết hợp dấu chấm than với dấu hỏi tạo ra sắc thái ngạc nhiên, đến mức giật mình, hoặc phản đối, ví dụ Cậu định đội thứ đó lên đầu?!
# OK: Đặc điểm giao thông tại các giao lộ là có số lượng điểm xung đột giữa các dòng xe cắt nhau, tách dòng, nhập dòng lớn.
# OK: Dù vậy, họ vẫn tiếp tục mua sắm các máy bay hiện đại Su 27 30 hiện đại hơn, dù chỉ với số lượng ít và nhỏ giọt.
# OK: Giao lộ vuông góc là loại giao lộ điển hình và thường gặp nhất cho thể loại giao lộ và những loại cơ bản nhất.
# OK: Bà sinh ngày 7 12 1963 tại phường Tiên Cát, Việt Trì , Phú Thọ .
# OK: Dòng suối theo mùa Beaver Dam Wash là điểm thấp nhất của Utah với độ cao 610 m.
# OK: Văn phòng đại diện được đặt tại tầng 6, Tòa nhà Exchange Tower số 1 đường Nam Kỳ Khởi Nghĩa, Phường Nguyễn Thái Bình, Quận 1, thành phố Hồ Chí Minh.
# OK: Kỹ thuật toán học được sử dụng bao gồm các phân tích toán học, đại số tuyến tính, phân tích ngẫu nhiên, phương trình vi phân, lý thuyết xác suất và thống kê toán.
# OK: Mỗi năm có hàng nghìn bác sĩ và dược sĩ đại học tốt nghiệp ra trường.
# OK: Lợi nhuận thu được từ xuất khẩu dầu mỏ và khí đốt đã làm giảm bớt những tác động của khủng hoảng.
# OK: Trong DOS, OS 2 và các trình thông dịch dòng lệnh của Windows như COMMAND.
# OK: Năm 2014, Hương Giang hẹn hò với Criss Lai, bạn đồng hành trong chương trình Cuộc đua kỳ thú mùa thứ ba .
# OK: Sẽ phải chi phí khoảng 2,56 tỷ đô la Mỹ 36 triệu × 71 máy bay .
# OK: Cụ thể, năm 1865 Gregor Mendel đã tiến hành thí nghiệm lai giống thực vật và được phát hiện lại vào năm 1900, khai sinh ra Di truyền học .
# OK: Một thương hiệu được thừa nhận rộng rãi trên thị trường tức là đã đạt được sự khẳng định thương hiệu.
# OK: Tầng dưới là 4 trụ gạch vuông, mỗi cạnh của trụ có chiều dài một mét và trên các mặt trụ đều có chạm trổ các hoa văn rất tinh vi và sắc sảo.
# OK: Dù vậy, mỗi người dân Liên Xô đã có những nỗ lực lao động phi thường để bù đắp tổn thất và góp phần làm nên chiến thắng chung cuộc.
# OK: Cũng năm ấy hội đã trở thành thành viên của Tổ chức Phong trào Hướng đạo Thế giới WOSM .
# OK: Sau khi tắm trong hồ, các thiên thần đã mặc cho bà bộ quần áo của cõi trời, xức dầu thơm cho bà, và trang điểm cho bà bằng những bông hoa tuyệt đẹp.
# OK: Hoa tiêu Lê Thành Chơn cho biết Trên thực tế, tôi không thể sử dụng các chiến thuật được huấn luyện tại Trung Quốc để chống lại Mỹ.
# OK: Quy trình đo lường để tạo ra các dữ liệu thống kê cũng có thể bị lỗi.
# OK: Phim tài liệu có các cảnh quay lưu trữ bao gồm video gia đình, các bài đăng trên mạng xã hội, tin nhắn văn bản và các đoạn ghi âm thực thi pháp luật.
# === Batch 11 ===
# OK: Chương trình máy tính đơn giản chỉ là một danh sách các chỉ thị để máy tính thực thi, có thể với các bảng dữ liệu.
# OK: Ý tưởng áp dụng kỹ thuật tiếng ồn vào việc thiết kế đường lần đầu xuất hiện khoảng năm 1973.
# OK: Chùa nằm cách chùa Bà khoảng 100 bậc thang, ngôi chùa theo theo hệ phái Bắc Tông được thành lập vào năm 1830, 69 1 trùng tu năm 1995.
# OK: Tư Mã Ý nằm trong số các cố vấn hối thúc Tào Tháo áp dụng hệ thống Đồn điền chế và ủng hộ Tào Tháo lên nắm chức Ngụy Vương.
# OK: Năm 227 , Mạnh Đạt bắt đầu các cuộc thương lượng với Ngô và Thục, hứa hẹn sẽ quay sang chống Ngụy khi có cơ hội.
# OK: Các phương thức kết nối mạng chính cho phép Internet được chứa trong các RFC được chỉ định đặc biệt cấu thành các Tiêu chuẩn Internet .
# OK: Phi công Ách là thuật ngữ thông dụng trong hàng không quân sự dùng để chỉ các phi công đã bắn hạ từ 5 máy bay đối phương trở lên.
# OK: Coi trọng công việc , không được chủ quan, đánh giá thấp công việc vì dù công việc có bình thường thế nào, nó đều tiêu tốn thời gian và công sức nhất định.
# OK: Thờ cúng tổ tiên và cúng giỗ người đã mất là một tục lệ lâu đời của người Việt và một số dân tộc khác.
# OK: Các thiết bị đầu cuối này được truy cập rộng rãi cho các mục đích sử dụng khác nhau, chẳng hạn như đặt vé, gửi tiền ngân hàng hoặc thanh toán trực tuyến.
# OK: Dọc theo sông Isar là các công viên tự nhiên nhỏ, một phần được tái tự nhiên hóa nhân dịp triển lãm vườn của liên bang năm 2005 .
# OK: Trong lúc này, nhang trong điện được thắp sáng và mở cửa đón du khách trở lại.
# OK: Một miền quan trọng là để tập hợp các giá trị của các ước lượng dẫn đến bác bỏ giả thuyết rỗng.
# OK: Hiện tượng này cũng phổ biến rộng rãi ở Hàn Quốc , Nhật Bản và một phần ở Trung Quốc .
# OK: Như vậy là, ở giai đoạn đầu thời Hùng Vương quan hệ cộng đồng nguyên thủy mới bước vào quá trình tan rã.
# OK: Trong số này, người miền Đông Ukraina đa số là người gốc Nga có tỷ lệ tiếc nuối cao gấp đôi so với người miền Tây muốn Ukraina gia nhập EU và NATO .
# OK: Quân đội Hoa Kỳ cũng bắt đầu triển khai Bài kiểm tra phân loại quân binh phổ thông AGCT và bắt đầu nghiên cứu quy mô lớn về tinh thần của binh sĩ.
# OK: Pearson phát triền các hệ số tương quan, được định nghĩa như là tích số quan trọng.
# OK: Cây cối trong khu vực xây dựng dường có thể được đánh dấu để giữ lại.
# OK: Nhưng hầu hết mọi người đều không nhìn ra giá trị sai lệch hay sai số, vì vậy những lỗi sai này không được sửa chữa.
# OK: Đường xa lộ vành đai A99 bao bọc gần như toàn bộ München.
# OK: Ngày 23 tháng 1 năm 1984, chia huyện Ea Súp thành 2 huyện Ea Súp và Cư M gar .
# OK: Động vật học là ngành học liên quan đến các loài động vật, bao gồm sinh lý học , giải phẫu học và phôi học .
# OK: Tại Nga, Inside Out là bộ phim hoạt hình của Disney và Pixar có doanh thu cao thứ hai và là phim đầu tiên của Pixar có doanh thu vượt qua 1 tỷ rúp.
# OK: Thủ tướng Chính phủ là người đứng đầu Chính phủ Việt Nam , kiêm Bí thư Đảng ủy Chính phủ, đồng thời là Phó Chủ tịch Hội đồng Quốc phòng và An ninh .
# OK: Kiến trúc ngày nay là hoàn toàn mới.
# OK: Từ những năm 1950 đến nay, sinh học đã được mở rộng rất nhiều trong lĩnh vực phân tử.
# OK: Mặc dù giữa Chăm Pa và đế quốc Khmer luôn có chiến tranh, nhưng thương mại và văn hóa vẫn được giao lưu về cả hai phía.
# OK: Năm 1961, Tổ chức Phong trào Hướng đạo Thế giới chấm dứt công nhận hội viên của Hướng đạo Cuba vì cho rằng họ đã không còn tồn tại.
# OK: Từ thời điểm đó, vua A dục, người đã từng được miêu tả như là A dục ác vương Chandashoka , bắt đầu được mô tả như là A dục sùng đạo Dharmashoka .
# === Batch 12 ===
# OK: Cũng trong năm đó, một nhóm phóng viên của Thiếu niên Tiền phong và Nhi đồng đã yêu cầu ông viết lời tiếng Việt cho ca khúc.
# OK: Ai Cập của Gamal Abdel Nasser , Indonesia của Sukarno và Ấn Độ của Jawaharlal Nehru đều được hưởng lợi từ chính sách này.
# OK: Như vậy, phần lớn người dân Liên Xô vẫn muốn đất nước tồn tại.
# OK: Khi Nguyễn Thị Minh Khai đến Moskva cuối năm 1934, bà đã viết rằng bà đã có gia đình với Lin , bí danh của Hồ Chí Minh vào thời điểm này.
# OK: Anh ta cũng đưa ra những chi tiết mới về vụ sát hại các con gái của mình cố gắng giết chúng trên giường tại nhà, nhưng không thành công.
# OK: ngày sau khi đắc đạo, Phật chỉ thiền định, không ăn uống.
# OK: Khám phá về sự biểu hiện vật lý của di truyền đã đến cùng với các nguyên tắc tiến hoá và di truyền quần thể .
# OK: Trên Unix , một chương trình setuid được cung cấp cho một môi trường do người gọi của nó chọn, nhưng nó chạy với quyền hạn khác với người gọi của nó.
# OK: Các tổ chức Hướng đạo đã từng lâm vào những kiểu xung đột và các vấn đề gây tranh cãi cả nội bộ lẫn quốc tế.
# OK: Có một số các vấn đề gây tranh cãi vì trong hàng ngũ lãnh đạo cao cấp của Vùng Âu Á có các cựu lãnh đạo Thiếu niên Tiền phong .
# OK: Người được vua Lê Thánh Tông phong vương xứ Kauthara Hoa Anh là Bàn La Trà Duyệt.
# OK: Định nghĩa này được chấp nhận rộng rãi trong nhiều thập niên.
# OK: Thậm chí cha của bà là Trần Văn Chương , đã phát biểu chống lại Trần Lệ Xuân.
# OK: Các nước thuộc địa vừa giành được độc lập trở thành khu vực cạnh tranh ảnh hưởng của Liên Xô, Mỹ và Trung Quốc.
# OK: Một nhiễm sắc thể là một cấu trúc được tổ chức bao gồm DNA và protein histone .
# OK: Khi nắp quan tài bật mở, người ta thấy tất cả bùn đất tích tụ từ thiên niên kỷ I T CN phủ kín hiện vật.
# OK: Từ đây cho tới cuối thế kỷ, tôi e rằng tâm lý học thế giới chỉ việc khai thác riêng các ý tưởng của J.
# OK: Internet được chạy trên các máy tính và nó kết nối hàng trăm triệu máy tính khác và người dùng của chúng Máy tính ban đầu chỉ được coi là thiết bị tính toán.
# OK: Người da trắng tại Utah chủ yếu có gốc từ các nước Tây Âu và Bắc Âu như Anh , Đức , Ireland , Scotland , Thụy Điển , Đan Mạch ...
# OK: Năm 1941, ông bị buộc phải trở lại Huế để Pháp dễ bề theo dõi ông.
# OK: Khi Riley Kaitlyn Dias thủ vai lên 11, cô và cha mẹ chuyển đến San Francisco nơi cha cô bắt đầu công việc mới.
# OK: Các hệ sinh thái thường được nghiên cứu ở nhiều cấp độ khác nhau từ cá thể individual và các quần thể cho đến các hệ sinh thái và sinh quyển .
# OK: Bốn nhà nghiên cứu có uy tín khác viết về Văn hóa Đông Sơn đầu tiên ở Việt Nam là V.
# OK: Algérie có nhiều gió nóng ẩm , một loại gió nóng mang theo bụi và cát đặc biệt thường xảy ra vào mùa hè .
# OK: Theo số liệu của Bộ Nội vụ Liên Xô vào tháng 1 năm 1953, số người định cư đặc biệt từ 17 tuổi trở lên là 1.810.140 người, trong đó có 56.589 người Nga.
# OK: Các nhiệm vụ và quyền hạn cụ thể của Quốc hội Việt Nam được quy định theo Điều 70 trong Hiến pháp nước Cộng hòa Xã hội chủ nghĩa Việt Nam .
# OK: Ví dụ như nếu Quốc hội bất tín nhiệm nhân sự trong chính phủ nhưng Đảng vẫn tín nhiệm thì sao?
# OK: Các vấn đề liên quan đến cá độ trong hoạt động thể thao rơi phần nhiều ở bóng đá.
# OK: Ngược lại, Làm giàu với ma 2 vẫn quyết định giữ nguyên lịch công chiếu vào ngày 29 tháng 8, đồng thời tung thêm các suất chiếu sớm trước ngày khởi chiếu chính thức.
# OK: Theo nghĩa Hán Việt, Phong là nền nếp đã lan truyền rộng rãi và Tục là thói quen lâu đời.
# === Batch 13 ===
# OK: Một vấn đề lớn nhằm làm tăng kích cỡ mẫu được lựa chọn là mẫu đại diện.
# OK: Thể dục, thể thao phổ biến cũng như thể thao hàng đầu, được nhà nước Liên Xô thúc đẩy mạnh mẽ.
# OK: Mô phỏng lưu lượng giao thông có tổ chức thường liên quan đến lý thuyết xếp hàng, quy trình ngẫu nhiên và phương trình vật lý toán học áp dụng cho lưu lượng giao thông.
# OK: Đến thời Trung cổ, những người ghi chép quyết định thêm các dấu câu vào bản thảo để tạo ra giọng điệu cho câu văn, hoặc đơn giản chỉ để ngắt quãng.
# OK: Ngày 13 tháng 4 năm 2016, Bộ Chính trị đã quyết định phân công Tô Lâm giữ chức Bí thư Đảng ủy Công an Trung ương .
# OK: Có 4 nguyên lý tạo thành nền tảng cho sinh học hiện đại lý thuyết tế bào , tiến hóa , di truyền và cân bằng nội môi .
# OK: Họ gặp nhau vào năm 2010 và kết hôn tại Quận Mecklenburg vào ngày 3 tháng 11 năm 2012, theo hồ sơ trực tuyến.
# OK: Neil McElroy cũng là chiến lược gia của thời chiến tranh lạnh cạnh tranh ngành vũ trụ với Liên Xô và nhà hoạch định chiến lược thương hiệu NASA.
# OK: Các đá bị kéo giãn cũng có thể tạo thành dạng thấu kính, được gọi là boudin , sau này tiếng Pháp gọi là xúc xích , vì chúng nhìn giống nhau.
# OK: Rồi trong một đêm, ông lặng lẽ từ biệt hoàng cung, quyết định sống cảnh không nhà của một tu sĩ.
# OK: Ở lần thứ hai, anh thấy được ánh sáng và bơi ra được ngoài.
# OK: Loại hình này được phát hiện lần đầu vào năm 1972.
# OK: Người Nhật trẻ tuổi đang lựa chọn công việc bán thời gian, trái ngược với những người lớn tuổi làm thêm giờ.
# OK: Bạn có kết thúc được một công việc, thì một công việc khác mới có thể bắt đầu Khuyết danh .
# OK: Đoàn Chủ tịch Xô viết Tối cao Liên Xô là nguyên thủ quốc gia trên danh nghĩa, nhưng Tổng Bí thư Ủy ban Trung ương Đảng Cộng sản mới là nhân vật số một.
# OK: Là vị trí cũng có thể được bầu vào Bộ Chính trị.
# OK: Một công dân Anh 40 tuổi tên là Vishwash Kumar Ramesh đã thoát nạn và là người duy nhất sống sót trên máy bay.
# OK: Phương Tây cũng cho rằng những biểu tượng quan trọng trong văn hóa Việt Nam bao gồm rồng , rùa , hoa sen và tre .
# OK: cần dẫn nguồn Các dự án Appeal 17 và ToPaZ 18 tập trung vào việc mang lại những tiến bộ mới trong phiên bản tiếp theo của cả KDE và GNOME tương ứng.
# OK: Quang, một trung úy biệt kích dù thuộc Quân lực Việt Nam Cộng hòa , đã phải lòng một cô gái tên Hồng trong một lần giúp cô di tản khỏi vùng nguy hiểm.
# OK: Ông được cho là đã tiếp tục Chiến dịch đốt lò do người tiền nhiệm của ông là cố Tổng Bí thư Nguyễn Phú Trọng khởi xướng.
# OK: Chính những nét đó làm nên cốt cách, hình hài và bản sắc của dân tộc Việt Nam.
# OK: Sinh kế của họ phụ thuộc vào thành công của tôi.
# OK: Lĩnh vực năng lượng hóa thạch là xương sống của nền kinh tế, chiếm khoảng 60 thu ngân sách, 30 GDP , và hơn 95 thu nhập xuất khẩu.
# OK: J.Piaget là người lao động không mệt mỏi.
# OK: Ngày 19 tháng 5 năm 1951, gia đình ông bà Walter R.
# OK: Theo đó, các dự án freedesktop.org được thành lập như một khu vực hợp tác chính thức với mục tiêu là để giảm trùng lặp.
# OK: Trong vòng 20 năm qua, nền kinh tế Việt Nam đã tăng trưởng nhanh.
# OK: Người ta phải nương vào ngón tay để thấy được mặt trăng, còn nếu chỉ cố chấp vào ngón tay, chỉ tập trung nhìn ngón tay thì sẽ không bao giờ thấy được mặt trăng.
# OK: Sản lượng lương thực của nước Nga Sa hoàng năm 1913 là 4,8 triệu pud, còn Liên Xô năm 1937 đã tăng lên tới 6,8 triệu pud.
# === Batch 14 ===
# OK: Lỗi chú thích Thẻ ref có tên Kotulla 1987 Environment được định nghĩa trong references không được đoạn văn bản trên sử dụng.
# OK: Sau Đại Bái Đường, song song với Đại Bái Đường là tòa Thượng Điện, có quy mô tương tự cả về chiều cao lẫn bề rộng.
# OK: Ban đầu, ông Nguyễn Sinh Khiêm đem cả hài cốt bà Hà Thị Hy và bà Hoàng Thị Loan lên táng gần nhau ở chân núi Động Tranh thấp.
# OK: Khu vực thành thị trấn vào năm 1874, Oberhausen sáp nhập nhiều đơn vị lân cận như quận của Alstaden, các bộ phận của Styrum và Dümpten năm 1910.
# OK: Mỗi năm, khoảng 30.000 người ở Nhật Bản tự sát.
# OK: Điểm trao đổi Internet là các trao đổi lưu lượng truy cập lớn với các kết nối vật lý đến nhiều ISP.
# OK: Đường là một lộ trình, đường đi có thể phân biệt giữa các địa điểm .
# OK: , 60 người Nga tin rằng sự sụp đổ của Liên Xô gây nhiều tác hại nhiều hơn là lợi ích.
# OK: Tuy nhiên, không có thương tích vào xảy ra.
# OK: Tại Hội nghị Trung ương Đảng lần thứ 10, khóa II, Hồ Chí Minh với chức vụ Chủ tịch Đảng được Trung ương Đảng phân công kiêm nhiệm chức vụ Tổng Bí thư.
# OK: Mỗi trong số chúng cung cấp Trong đầu thập niên 2000, KDE đạt đến sự trưởng thành cùng với GNOME.
# OK: Bộ trưởng Tô Lâm đã có cuộc hội đàm với Bộ trưởng Tư pháp Iran, ông Amin Houssein Rahimi.
# OK: Cách hiểu sự tương quan giữa các TTXC tự báo và các tính cách biên đổi và không nhất quán.
# OK: Chính Vua Tần bà sa la đã dâng cung cho Tăng đoàn ngôi tu viện đầu tiên trong lịch sử Phật giáo, đó là Tịnh xá Trúc Lâm Veluvana tại kinh đô Vương xá.
# OK: Trong mỗi trung đoàn gồm có các đơn vị hỗ trợ với biên chế tiểu đoàn tiểu đoàn hậu cần, tiểu đoàn kỹ thuật...
# OK: Ông được thông qua, miễn nhiệm, kết thúc hơn 20 năm công tác trong lĩnh vực tài chính, tiền tệ và ngân hàng, bước sang một giai đoạn sự nghiệp mới.
# OK: Niʻihau tiếng Hawaii ˈniʔiˈhɐw là đảo cực tây và là đảo có người ở lớn thứ bảy trong quần đảo Hawaiʻi .
# OK: Sau sự cố, 1.400 tấn đất bị nhiễm phóng xạ được gửi sang Hoa Kỳ.
# OK: Công cuộc cải cách tinh gọn bộ máy được đặt nền tảng bởi Nghị quyết số 18 NQ TW năm 2017, đã được thực hiện nhưng với quy mô không lớn và không quyết liệt.
# OK: Ngày 17 tháng 11 cùng năm, bộ phim chính thức được ra mắt trên nền tảng TV360 với độ phân giải 4K .
# OK: Đơn vị của entropy là Joule trên Kelvin , ký hiệu J.K 1 , thể hiện lượng entropy lấy được bởi hệ khi hệ nhận được 1 Joule nhiệt lượng trên độ Kelvin.
# OK: Phần xá lợi này do bộ tộc Śākya, nước Śrāvastī phụng thờ .
# OK: Thành công lớn từ bộ phim năm 2009 của Docter Vút bay thúc đẩy Pixar cho phép ông tạo ra một bộ phim khác với cốt truyện phức tạp và tinh tế hơn.
# OK: Moskva có ảnh hưởng mạnh lên các Đảng cộng sản tại các quốc gia Đông Âu và họ thường ủng hộ các chính sách của Kremlin.
# OK: 60 Xét trên toàn bộ phim Việt, thành tích của Mưa đỏ chỉ xếp sau các phim của Trấn Thành, lần lượt là Mai 6 ngày và Bộ tứ báo thủ 5 ngày .
# OK: Ngay cả khi các kỹ thuật thống kê được áp dụng một cách chính xác, kết quả có thể khó để giải thích cho những người thiếu chuyên môn.
# OK: Các nhà tâm lý học ở Đức, Đan Mạch, Áo, Anh Quốc và Hoa Kỳ nhanh chóng theo Wundt thiết lập các phòng thí nghiệm.
# OK: Trường hợp thanh thiếu niên từ 18 đến 22 tuổi sẽ được hỗ trợ học phí và đào tạo nghề nếu có nhu cầu.
# OK: Khi Vương quốc Anh , Pháp và Israel xâm lược Ai Cập vào năm 1956, Liên Xô đã hỗ trợ nước này đẩy lui các thế lực thực dân cũ.
# OK: Năm 1611 Nguyễn Hoàng đã thực hiện cuộc Nam tiến đầu tiên sau khi trấn giữ Thuận Quảng.
# === Batch 15 ===
# OK: Tạo thói quen đơn giản là luôn bắt đầu tiến hành mọi việc sớm hơn một chút , mọi công việc sẽ trở nên nhẹ nhàng và trôi chảy hơn.
# OK: Gorbachev cũng khuyến khích đẩy mạnh sự tiếp xúc giữa công dân Liên Xô và thế giới phương Tây , đặc biệt là với Hoa Kỳ .
# OK: 19 Nhiều kiểu quảng cáo trực tuyến phổ biến đang gây tranh cãi và ngày càng phải tuân theo quy định.
# OK: 28 Nhìn chung, cả Vietnam hay Viet Nam đều được chấp nhận trong tiếng Anh, trong đó Vietnam được dùng phổ biến hơn trong các phương tiện truyền thông từ nước ngoài.
# OK: Một số tư tưởng Nho giáo cho tới nay vẫn giữ vai trò nhất định trong trật tự xã hội Việt Nam.
# OK: Siêu tôi Super Ego Vận hành theo nguyên tắc ngăn cấm, kiểm duyệt.
# OK: Tại đây, khi nhìn ra còn có thể thấy được hồ Dầu Tiếng và suối Tha La.
# OK: Không phải tất cả các quốc gia đều ký kết công ước, và ngay cả trong số các bên ký kết, các ngoại lệ trong thực tế đều có thể được tìm thấy.
# OK: Chỉ thị SYS SET trong DR DOS 6.0 trở lên và chỉ với SWITCHES L đối với cho phép tên chữ thường trong DR DOS 7.02 trở lên .
# OK: Sau khi thực hiện hợp nhất, Bộ Nông nghiệp và Môi trường chỉ còn 30 đơn vị, được coi là một trong những Bộ tinh giản đầu mối nhiều nhất.
# OK: Bản thân các nhân viên nên nhận ra nhu cầu của họ để thực hiện các biện pháp phòng ngừa kịp thời và có biện pháp phòng ngừa khi cần thiết.
# OK: Bạn có thể giúp Wikipedia mở rộng nội dung để bài được hoàn chỉnh hơn.
# OK: Sau chiến tranh thế giới hai, Liên Xô bị tàn phá nặng nề.
# OK: Rừng ở Việt Nam chủ yếu là rừng rậm nhiệt đới khu vực đồi núi còn vùng đất thấp ven biển có rừng ngập mặn .
# OK: Thuyết kiến tạo mảng giải quyết được hai vấn đề chính đó là tách giãn đáy đại dương và trôi dạt lục địa .
# OK: Vụ tai nạn này là vụ mất thân máy bay và là vụ tai nạn chết người đầu tiên của dòng máy bay Boeing 787 Dreamliner .
# ...
# OK: Các phóng viên thực hiện loạt bài này cũng bị hàng loạt tài khoản nặc danh gửi tin nhắn công kích, đe dọa.
# OK: Nam Hướng đạo Mỹ nói rằng các chính sách này là thiết yếu trong sứ mệnh làm thấm nhuần giới trẻ bằng các giá trị của luật Hướng đạo và lời hứa Hướng đạo.
# OK: Điều này được gọi là đa nhiệm multitasking .
# OK: Dưới quyền của vua Ludwig I München trở thành một thành phố nghệ thuật nổi tiếng.
# OK: Tìm các dấu hiệu này trên đá có thể xác định được loại đứt gãy đó là đứt gãy thường hay đứt gãy sâu trong toàn vỏ Trái Đất .
# OK: Quan họ có ở Bắc Ninh và Bắc Giang .
# OK: Dự án này do Tổng công ty Quản lý bay Việt Nam VATM làm chủ đầu tư.
# OK: Ngày 21 tháng 5 năm 1975, Bộ Quốc phòng đã quyết định thành lập 2 trung đoàn trực thăng 917 và 918, và 2 trung đoàn máy bay chiến đấu 935 và 937.
# OK: Tuy nhiên, World Wide Web hoặc Web chỉ là một trong số lượng lớn các dịch vụ Internet.
# OK: Việc thiết kế các thiết bị tính toán có một mục đích hay có mục đích đặc biệt hiện nay là những bài tập khái niệm thuần túy bao gồm các phần mềm thiết kế.
# OK: Kiến trúc Von Neumann đã giải quyết vấn đề thuộc về thiết kế của máy ENIAC và sửa đổi bằng cách lưu trữ chương trình của máy trong bộ nhớ của nó.
# OK: Tuy trải qua suốt phần đời còn lại 45 năm đi giảng dạy, nhưng ông lại lưu ý với các đệ tử rằng Đối với chân lý , Như Lai chưa từng nói lời nào.
# OK: Kulak không muốn chia đất cho nông dân nghèo, họ huy động nông dân làm thuê tiến hành bạo động để chống lại tập thể hóa.
# OK: Smith được lựa chọn bởi Rivera khi ông đang xem Bad Teacher và thấy cô trong một cảnh ăn trưa.
# OK: Chiếc xe của cô vẫn còn đang ở trong ga ra.
# OK: Theo truyền thống, công nhân Nhật Bản là những nhân viên rất trung thành.
# OK: Niʻihau rộng 6,2 dặm và dài 18,6 dặm 10 km x 30 km .
# === Batch 27 ===
# OK: Thời gian đầu đi hát, Hương Giang thường hát tại các show diễn nhỏ lẻ.
# OK: lãnh thổ có đến năm vùng khí hậu lãnh nguyên , taiga , thảo nguyên , sa mạc và núi .
# OK: Mạng tiền thân chính, ARPANET , ban đầu đóng vai trò là xương sống để kết nối các mạng lưới học thuật và quân sự khu vực trong những năm 1970.
# OK: Phải đợi đến năm Minh Mạng thứ 17 17.3.1836 , nhà vua mới ban hành một chỉ dụ quan trọng nhằm hạn chế quyền hạn của hàng hoạn quan trong triều đình.
# OK: So với phương tiện truyền thông in ấn, sách, bách khoa toàn thư và thư viện truyền thống, World Wide Web đã cho phép phân cấp thông tin trên quy mô lớn.
# OK: Thậm chí, những môn đệ của S.Freud, những nhà Phân tâm học xảy ra những mâu thuẫn với các lý thuyết của S.
# OK: Chiếc B 52B ký hiệu 52 8711 được đưa vào sử dụng tại Phi Đội Ném bom Hạng nặng 93 tại Căn cứ không quân Castle , California ngày 29 tháng 6 1955 .
# OK: Ông đã phát triển mô hình thử nghiệm nghiêm ngặt và cũng hệ thống đầy đủ dữ liệu, thống kê phụ thuộc, phân biệt tuyến tính của Fisher và thông tin Fisher.
# OK: Knuth Wolfgang Walther Hartmann trở thành kỹ thuật viên chăn nuôi bò sữa.
# OK: Họ thấy rằng Joy là nhân vật phức tạp nhất để xây dựng do cô thể hiện một phạm vi rộng lớn các cảm xúc hạnh phúc .
# OK: Ngô Đình Nhu nói Để cứu vãn tình hình, Trần Lệ Xuân đã có chuyến công du các trường đại học Mỹ để phát biểu bảo vệ chế độ Sài Gòn.
# OK: Năm 1942 , cải táng tại núi Động Tranh thấp, thuộc dãy núi Đại Huệ.
# OK: Tuy nhiên, vào cuối những năm 1960, những xu hướng này đã bị đảo ngược một lần nữa và nhiều nhà văn trở lại im lặng hoặc rời khỏi đất nước.
# OK: Ẩm thực Việt Nam có sự kết hợp của 5 yếu tố cơ bản cay, chua, đắng, mặn và ngọt.
# OK: Vào năm 1965, Trịnh Thanh Đàm một người Trung Quốc sinh ra và lớn lên ở Việt Nam đã phổ nhạc 5 điều Bác Hồ dạy bằng tiếng Trung.
# OK: Cuối cùng, Liên Xô đã giải quyết được các vấn đề về Soyuz và trạm Salyut đã dẫn đến một dự án hợp tác chung với NASA về dự án Apollo Soyuz .
# OK: Tôi tin rằng mọi quỷ sứ ở địa ngục đều chống lại chúng tôi .
# OK: các chương trình setuid thường bỏ đặt các biến môi trường không xác định và kiểm tra các biến khác hoặc đặt chúng thành các giá trị hợp lý.
# OK: Việc sử dụng các phương pháp thống kê là được chấp nhận khi các phương pháp hoặc thống kê mẫu tổng thể đủ thông tin để chấp nhận giả thuyết.
# OK: Ban đầu, ông tưởng đó là một chiếc phao , nhưng khi quan sát kỹ hơn ở khoảng cách 200 mét thì ông mới nhận thấy có một cánh tay đang vẫy gọi.
# OK: Tham khảo Quest for Performance 2 68 Trên màn ảnh, B 52 thường được miêu tả như một biểu tượng cho sức mạnh hủy diệt.
# OK: Đây cũng là nơi đầu tiên của Việt Nam vận hành loại hình du lịch máng trượt và cáp treo.
# OK: Thời gian thi công nhà ga hành khách là 39 tháng, dự kiến đưa vào hoạt động và khai thác từ năm 2026.
# OK: Từ năm 1988 cơ quan quyền lực cao nhất là Đại hội Đại biểu Nhân dân , cơ quan thường trực của nó là Xô viết Tối cao .
# OK: Tâm lý có cơ sở tự nhiên và cơ sở xã hội, và được hình thành trong hoạt động, giao tiếp và các mối quan hệ xã hội.
# OK: IAAP được xem là hiệp hội quốc tế về tâm lý học lâu đời nhất hiện nay.
# OK: Phía Mỹ chỉ công nhận rơi 2 chiếc.
# OK: Họ sinh sống chủ yếu bằng nông nghiệp, các hoạt động thủ công và công nghiệp nhẹ.
# OK: Tại thành phố, chính sách mới khuyến khích đầu tư của tư bản trong nước và nước ngoài, nhà nước chỉ kiểm soát những ngành quan trọng với quốc gia như điện lực, ngân hàng...
# OK: Đội bay được yêu cầu rút gọn còn 5 người và chỉ trang bị vũ khí tự vệ duy nhất là tháp súng đuôi.
# === Batch 28 ===
# OK: Những tổn thất trong giai đoạn đầu là do phi công học theo cách đánh của Trung Quốc nhưng rồi chúng tôi bắt đầu sử dụng chiến thuật của chính mình .
# OK: Năm 1985 , nhân dân và chính quyền địa phương xây dựng tại đây một khu lăng mộ dành cho bà.
# OK: Chris Ntrong vaihawathy của Entertainment Weekly ca ngợi bộ phim siêu việt và cảm động....
# OK: Tục ngữ Việt Nam có câu Làng đi đôi với nước .
# OK: Nó được thiết kế để giải quyết tới 4,3 tỷ 10 9 máy chủ lưu trữ.
# OK: Trong một khoảng thời gian, GNOME và KDE là môi trường desktop phổ biến nhất trên Linux sau đó một số môi trường desktop khác bắt đầu phổ biến.
# OK: Người dân Niʻihau được biết đến với việc tạo tác lei pūpū shell lei , và việc sử dụng tiếng Hawaii như ngôn ngữ chính.
# OK: Trong Dynasty Warriors 7 , ông trở lại sử dụng cầm Quạt lông có tên Fenghuang Wing và là lãnh đạo của nước Tấn Jin một nước mới của trò chơi.
# OK: Cụ thể, B 1 đạt trung bình 53,7 , B 2 Spirit chỉ đạt 30,3 , trong khi B 52 đạt tới 80,5 .
# OK: Tiếp đó, vào năm 1069 quân Việt tấn công Chăm Pa.
# OK: Abram người thay William Westmoreland làm Tư lệnh Bộ Chỉ huy quân Mỹ tại Sài Gòn, tuyên bố Sẽ cho B52 ném thật nhiều bom đến mức ...
# OK: Những năm gần đây các phiên họp của Bộ Chính trị một số phiên họp đã công khai tương tự các phiên họp của Ban Bí thư cũng vậy .
# OK: Các máy tính hiện đại nhận được khả năng tổng thể của chúng theo cách mà các đặc trưng này tác động qua lại với nhau.
# OK: Từ những quan điểm, kết luận như vậy là không có nghĩa, như là giá trị thực không phải là một biến ngẫu nhiên.
# OK: 28 Vào một tập tháng 12 năm 2018 của loạt phim ABC News 20 20 , cha mẹ của Shanann đã được phỏng vấn lần đầu tiên kể từ sau vụ giết người.
# OK: Các trường đại học chủ yếu tập trung ở Hà Nội và TP.
# OK: Sechenov phát triển ý tưởng về phản xạ não bộ và ủng hộ mạnh mẽ thuyết quyết định về hành vi con người.
# OK: Tháng 3 năm 1999 , trường được nâng cấp lên thành Trường Cao đẳng Công nghiệp IV, vẫn trực thuộc Bộ Công nghiệp.
# OK: Trong tiếng Việt, Xô viết là từ được viết theo kiểu đọc phiên âm tiếng Việt cho từ Soviet .
# OK: Planisphere là một bản đồ sao do Abū Rayhān al Bīrūnī phát minh vào đầu thế kỷ 11.
# OK: Năm 2015, Hương Giang tham gia chương trình Bước nhảy hoàn vũ mùa 6 và lọt vào top 5 chung cuộc.
# OK: Làm việc quá sức cũng có tác động tiêu cực đến gia đình.
# OK: Bà cũng được cho là ủng hộ các luật nhằm đóng cửa các nhà chứa và ổ thuốc phiện.
# OK: Ví dụ, Mosteller và Tukey 1977 11 phân lớp, phân bậc, tính phân số, đếm, tổng số lượng và cân bằng.
# OK: Ủy ban nhân dân tỉnh Quảng Ninh đã công bố mức hỗ trợ cho mỗi trường hợp tử vong là 25 triệu đồng và mức hỗ trợ cho người bị thương là 8 triệu đồng.
# OK: Nhiệt độ chính thức cao nhất từ trước đến nay do Cục thời tiết Đức đo được là 37,2 độ Celcius vào tháng 7 năm 1983 .
# OK: Cửa này là cửa chính cũng xây 3 gian, có mái lợp và cánh cửa đóng mở.
# OK: Ngoài ra, do sự tập luyện của ông đã đạt đến mức độ xuất sắc, nên mới đủ để vượt qua những thử thách khốc liệt về sức khỏe.
# OK: Lộ trình ấy làm phác thảo một hướng đường bộ qua đèo Bellevue , tức Ngoạn Mục ngày nay và một hướng đường sắt răng cưa được xây dựng đến năm 1917.
# OK: Công trình kiến trúc được xây dựng theo kiểu Pháp vào đầu thế kỷ XX .
# === Batch 29 ===
# OK: Nguyễn Văn Ba đã được tuyên dương Anh hùng lực lượng vũ trang nhân dân vào tháng 8 năm 1995.
# OK: Khăn và xiêm áo của ta cũng may toàn bằng hàng lụa bậc nhất từ Ca tây chở đến .
# OK: Chính phủ đã ký sắc lệnh quan trọng thành lập Nha bình dân học vụ, chống nạn mù chữ.
# OK: Sau khi Liên Xô tan rã, theo liệu pháp sốc do người Mỹ tư vấn, chính phủ Nga tiến hành cưỡng chế tư hữu hóa trong lĩnh vực kinh tế.
# OK: Bốn cạnh sàn có diềm gỗ chạm trổ tinh vi.
# OK: Nhà tâm lý học sử dụng các phương thức nghiên cứu kinh nghiệm để diễn giải mối quan hệ nhân quả và tương quan giữa những yếu tố tâm lý xã hội.
# OK: Trước khi ngồi, ông thầm nghĩ làm thế nào có một tòa ngồi cho yên tĩnh, trang nghiêm.
# OK: Chủ tịch Quốc hội đầu tiên lúc đó gọi là Trưởng ban Thường trực Quốc hội là Nguyễn Văn Tố .
# OK: Những nỗ lực cơ sở đã dẫn đến các mạng cộng đồng không dây .
# OK: Vào tháng 6 năm 2021, Inside Edition đã báo cáo những lời thú nhận khác của Chris Watts với một người viết.
# OK: Ngoài ra, tại các vùng phía Bắc , con người sinh sống trong các hang động đá vôi và sống bằng các hoạt động săn thú, hái lượm.
# OK: Tiểu sử chính thức của Đảng Cộng sản Việt Nam cho biết Hồ Chí Minh tên thật là Nguyễn Sinh Cung, tự là Tất Thành.
# OK: 1988 1890 1969 1907 1986 Chủ tịch Hồ Chí Minh là người duy nhất nắm giữ chức vụ này trong giai đoạn 1951 1969.
# OK: Điều này khác với một số báo, ở nước ngoài truy cập tương đối khó khăn.
# OK: Khu vườn này gần vương quốc Nepal, dưới chân dãy núi Himalaya.
# OK: Chúng ta hãy thực hiện một giai đoạn chuyển đổi nào đó.
# OK: 10 2019 học trò Chấn Quốc đã lên ngôi vị giải nhất Giọng Hát Việt Nhí 2019.
# OK: Hang động cách chân núi khoảng 500 m nhưng địa hình khá hiểm trở, một con suối cắt ngang với một chiếc cầu treo nối hai bờ vực.
# OK: Các đặc trưng này phần lớn không phụ thuộc vào mức độ hoàn thiện của công nghệ.
# OK: Thế kỷ 20 xuất hiện các thể loại tân nhạc Việt Nam .
# OK: Các hệ ngôn ngữ ở Việt Nam bao gồm Nam Á , Kra Dai , Hán Tạng , H Mông Miền và Nam Đảo .
# OK: Tháng 3 năm 2011, Ngọc Hiếu đến Thái Lan để làm thực hiện ca phẫu thuật chuyển giới thành nữ .
# OK: Sinh thời, Hồ Chí Minh có ba người con đỡ đầu ở Pháp, Đức và Nga.
# OK: Thời kỳ xung quanh Cách mạng Nga năm 1917 được đánh dấu bằng một đợt bùng nổ thử nghiệm và sáng tạo văn hóa.
# OK: Hình ảnh của Tất đạt đa Cồ đàm có thể được tìm thấy trong cả Tòa Thánh và trên bàn thờ ở nhà.
# OK: Lấy mẫu đại diện phải đảm bảo rằng nó được suy luận và kết luận một cách chính xác từ việc chọn mẫu cho toàn bộ tổng thể.
# OK: Như vậy, ý nguyện của phần lớn người dân Liên Xô là vẫn muốn đất nước tồn tại.
# OK: Iraq là một trong các nước Á Rập đầu tiên đón nhận phong trào Hướng đạo.
# OK: Nhưng giá trị của thương hiệu không chỉ là con số chênh lệch giữa giá bán và giá thành.
# OK: Các nhà thống kê tổng hợp dữ liệu về toàn bộ tổng thể hoạt động điều tra mẫu tổng thể .
# === Batch 30 ===
# OK: Thay vào đó giao diện dòng lệnh CLI truyền thống vẫn được sử dụng khi có các yêu cầu kiểm soát toàn bộ hệ thống.
# OK: Một số tín đồ Phật giáo Trung Quốc thời sơ khai từng nghĩ Tất đạt đa Cồ đàm là hóa thân của Lão Tử trong Đạo giáo .
# OK: Hai trong số bốn trái bom bị vỡ một phần do một vụ nổ nhỏ, gây phát tán nghiêm trọng các chất liệu phóng xạ plutonium và uranium .
# OK: Trong một cuộc phỏng vấn về Dr.Phil , luật sư của Christopher khai rằng anh ta thú nhận đã giết Shanann sau một cuộc tranh cãi liên quan đến việc ly hôn.
# OK: 87 Đây được xem là lễ hội dân gian lớn ở Tây Ninh và khu vực Đông Nam Bộ.
# OK: Năm 1076 , Lý Nhân Tông cho lập trường Quốc Tử giám ở bên cạnh Văn miếu, có thể coi đây là trường đại học đầu tiên ở Việt Nam.
# OK: Quyền hạn của Tổng Bí thư và Thường trực Ban Bí thư được quy định riêng.
# OK: Tại Đèo Lò Xo cũng từng xảy ra các tai nạn giao thông nghiêm trọng.
# OK: Hai bộ tộc có những cách sinh hoạt và trang phục khác nhau và có nhiều lợi ích xung đột dẫn đến tranh chấp thậm chí chiến tranh.
# OK: Nhờ thế mà các ông sớm biết được tin Nhật đầu hàng quân đội Đồng Minh vào trung tuần tháng 8 năm 1945.
# OK: Bất thường chỉ là tiến độ chứ không coi nhẹ chất lượng .
# OK: Các nhà tâm lý học tìm hiểu về những tính chất rõ nét của não bộ và những hiện tượng đa dạng liên kết với những tính chất trên.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-2876799098.py in <cell line: 0>()
# ----> 1 build_dpo_dataset(sentences, batch_size=30)
#
# /tmp/ipython-input-1183908273.py in build_dpo_dataset(sentences, batch_size, save_path)
#      10
#      11             for vi in batch:
# ---> 12                 item = create_best_bad(vi)
#      13                 if item:
#      14                     f.write(json.dumps(item, ensure_ascii=False) + "\n")
#
# /tmp/ipython-input-280022975.py in create_best_bad(src)
#       4     scored = []
#       5     for p in preds:
# ----> 6         s = score_translation(src, p)
#       7         if s is not None:
#       8             scored.append((p, s))
#
# /tmp/ipython-input-902405061.py in score_translation(src, pred)
#      23     msg = evaluation_prompt.format(src=src, pred=pred)
#      24
# ---> 25     resp = client.chat.completions.create(
#      26         model="gpt-4o-mini",
#      27         messages=[{"role": "user", "content": msg}],
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     284                         msg = f"Missing required argument: {quote(missing[0])}"
#     285                 raise TypeError(msg)
# --> 286             return func(*args, **kwargs)
#     287
#     288         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1187     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1188         validate_response_format(response_format)
# -> 1189         return self._post(
#    1190             "/chat/completions",
#    1191             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1257             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258         )
# -> 1259         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1260
#    1261     def patch(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1045
#    1046                 log.debug("Re-raising status error")
# -> 1047                 raise self._make_status_error_from_response(err.response) from None
#    1048
#    1049             break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-fEoImeF4VLBEqfSwWxkGcw1p on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ##### Train DPO

# %%
# !pip install trl accelerate transformers datasets --quiet
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.5/465.5 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 120.1 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 40.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 90.0 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.6 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.1 MB/s eta 0:00:000:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
# %%writefile dpo_mt_train_script.py

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

import wandb
wandb.init(mode="disabled")


from trl import DPOConfig, DPOTrainer
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "tnguyen20604/machine-translation-v1-data400k"

model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

dataset = load_dataset(
    "json",
    data_files="/kaggle/input/dpo-mt-data/dpo_data_filtered.jsonl",
    split="train"
)

args = DPOConfig(
    output_dir="./dpo-vit5"
)

trainer = DPOTrainer(
    model=model,
    args=args,
    train_dataset=dataset,
    processing_class=tokenizer,
)

trainer.train()
trainer.save_model("./dpo-vit5-final")
# Out:
# Overwriting dpo_mt_train_script.py

# %%
# !pip install accelerate
# !accelerate config default
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (7.1.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0.0,>=1.17->accelerate) (2.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0.0,>=1.17->accelerate) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0.0,>=1.17->accelerate) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.10.5)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0.0,>=1.17->accelerate) (2024.2.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Configuration already exists at /root/.cache/huggingface/accelerate/default_config.yaml, will not override. Run `accelerate config` manually or pass a different `save_location`.

# %%
# !accelerate launch dpo_mt_train_script.py
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# 2025-11-29 13:15:01.799006: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-29 13:15:01.814603: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764422101.820522     544 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764422101.826935     544 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764422101.835720     543 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764422101.842134     543 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# [rank1]:[W1129 13:15:10.080956826 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 1]  using GPU 1 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# [rank0]:[W1129 13:15:10.100650016 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# {'loss': 0.6837, 'grad_norm': 8.614681243896484, 'learning_rate': 9.898305084745762e-07, 'rewards/chosen': -0.14659026265144348, 'rewards/rejected': -0.18586960434913635, 'rewards/accuracies': 0.6000000238418579, 'rewards/margins': 0.039279330521821976, 'logps/chosen': -15.20733642578125, 'logps/rejected': -29.748157501220703, 'logits/chosen': 2.5777432918548584, 'logits/rejected': 2.72798228263855, 'epoch': 0.03}
# {'loss': 0.6989, 'grad_norm': 7.677008628845215, 'learning_rate': 9.785310734463277e-07, 'rewards/chosen': -0.13855071365833282, 'rewards/rejected': -0.14380091428756714, 'rewards/accuracies': 0.48750001192092896, 'rewards/margins': 0.005250186659395695, 'logps/chosen': -14.813497543334961, 'logps/rejected': -30.298877716064453, 'logits/chosen': 2.5871264934539795, 'logits/rejected': 2.735264539718628, 'epoch': 0.07}
# {'loss': 0.6892, 'grad_norm': 6.599298477172852, 'learning_rate': 9.672316384180792e-07, 'rewards/chosen': -0.13956166803836823, 'rewards/rejected': -0.16174013912677765, 'rewards/accuracies': 0.5375000238418579, 'rewards/margins': 0.022178472951054573, 'logps/chosen': -13.453526496887207, 'logps/rejected': -26.495738983154297, 'logits/chosen': 2.4514448642730713, 'logits/rejected': 2.5568301677703857, 'epoch': 0.1}
# {'loss': 0.7045, 'grad_norm': 6.662172794342041, 'learning_rate': 9.559322033898305e-07, 'rewards/chosen': -0.13293378055095673, 'rewards/rejected': -0.13188360631465912, 'rewards/accuracies': 0.518750011920929, 'rewards/margins': -0.0010501742362976074, 'logps/chosen': -15.178192138671875, 'logps/rejected': -30.38921546936035, 'logits/chosen': 2.548323154449463, 'logits/rejected': 2.6947715282440186, 'epoch': 0.14}
# {'loss': 0.6737, 'grad_norm': 6.410477638244629, 'learning_rate': 9.446327683615819e-07, 'rewards/chosen': -0.11232160031795502, 'rewards/rejected': -0.16841325163841248, 'rewards/accuracies': 0.574999988079071, 'rewards/margins': 0.05609165504574776, 'logps/chosen': -14.440325736999512, 'logps/rejected': -29.49087905883789, 'logits/chosen': 2.454868793487549, 'logits/rejected': 2.6217880249023438, 'epoch': 0.17}
# {'loss': 0.684, 'grad_norm': 5.596027374267578, 'learning_rate': 9.333333333333333e-07, 'rewards/chosen': -0.116874560713768, 'rewards/rejected': -0.15570902824401855, 'rewards/accuracies': 0.5687500238418579, 'rewards/margins': 0.03883443772792816, 'logps/chosen': -14.263453483581543, 'logps/rejected': -27.680835723876953, 'logits/chosen': 2.506225347518921, 'logits/rejected': 2.6422882080078125, 'epoch': 0.2}
# {'loss': 0.6801, 'grad_norm': 6.749515056610107, 'learning_rate': 9.220338983050847e-07, 'rewards/chosen': -0.14196181297302246, 'rewards/rejected': -0.188238263130188, 'rewards/accuracies': 0.5874999761581421, 'rewards/margins': 0.046276457607746124, 'logps/chosen': -14.901956558227539, 'logps/rejected': -33.3348388671875, 'logits/chosen': 2.566981792449951, 'logits/rejected': 2.739905834197998, 'epoch': 0.24}
# {'loss': 0.6847, 'grad_norm': 5.102209568023682, 'learning_rate': 9.107344632768361e-07, 'rewards/chosen': -0.10539038479328156, 'rewards/rejected': -0.14536647498607635, 'rewards/accuracies': 0.6000000238418579, 'rewards/margins': 0.03997611999511719, 'logps/chosen': -14.29979133605957, 'logps/rejected': -29.236780166625977, 'logits/chosen': 2.4629414081573486, 'logits/rejected': 2.6054444313049316, 'epoch': 0.27}
# {'loss': 0.6823, 'grad_norm': 8.177358627319336, 'learning_rate': 8.994350282485876e-07, 'rewards/chosen': -0.14380423724651337, 'rewards/rejected': -0.18433238565921783, 'rewards/accuracies': 0.5375000238418579, 'rewards/margins': 0.04052813723683357, 'logps/chosen': -13.780217170715332, 'logps/rejected': -28.172855377197266, 'logits/chosen': 2.513791561126709, 'logits/rejected': 2.678589344024658, 'epoch': 0.31}
# {'loss': 0.6723, 'grad_norm': 6.996386528015137, 'learning_rate': 8.88135593220339e-07, 'rewards/chosen': -0.10210474580526352, 'rewards/rejected': -0.16513247787952423, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.06302772462368011, 'logps/chosen': -13.463058471679688, 'logps/rejected': -27.57489585876465, 'logits/chosen': 2.331368923187256, 'logits/rejected': 2.4596915245056152, 'epoch': 0.34}
# {'loss': 0.6576, 'grad_norm': 9.043174743652344, 'learning_rate': 8.768361581920903e-07, 'rewards/chosen': -0.08457325398921967, 'rewards/rejected': -0.17886009812355042, 'rewards/accuracies': 0.6625000238418579, 'rewards/margins': 0.09428683668375015, 'logps/chosen': -13.442888259887695, 'logps/rejected': -28.3012752532959, 'logits/chosen': 2.431530475616455, 'logits/rejected': 2.590223789215088, 'epoch': 0.37}
# {'loss': 0.6521, 'grad_norm': 6.466280460357666, 'learning_rate': 8.655367231638417e-07, 'rewards/chosen': -0.10416465997695923, 'rewards/rejected': -0.21565070748329163, 'rewards/accuracies': 0.6187499761581421, 'rewards/margins': 0.1114860400557518, 'logps/chosen': -13.918510437011719, 'logps/rejected': -29.465662002563477, 'logits/chosen': 2.3890442848205566, 'logits/rejected': 2.560699701309204, 'epoch': 0.41}
# {'loss': 0.7056, 'grad_norm': 7.218240737915039, 'learning_rate': 8.542372881355931e-07, 'rewards/chosen': -0.1216360330581665, 'rewards/rejected': -0.12547394633293152, 'rewards/accuracies': 0.543749988079071, 'rewards/margins': 0.0038379188627004623, 'logps/chosen': -15.08397102355957, 'logps/rejected': -28.052724838256836, 'logits/chosen': 2.4444217681884766, 'logits/rejected': 2.563479423522949, 'epoch': 0.44}
# {'loss': 0.6722, 'grad_norm': 5.987286567687988, 'learning_rate': 8.429378531073446e-07, 'rewards/chosen': -0.07884147018194199, 'rewards/rejected': -0.14104430377483368, 'rewards/accuracies': 0.6312500238418579, 'rewards/margins': 0.0622028224170208, 'logps/chosen': -13.221872329711914, 'logps/rejected': -26.337677001953125, 'logits/chosen': 2.3915767669677734, 'logits/rejected': 2.5201544761657715, 'epoch': 0.47}
# {'loss': 0.654, 'grad_norm': 6.948227882385254, 'learning_rate': 8.31638418079096e-07, 'rewards/chosen': -0.06589595973491669, 'rewards/rejected': -0.17016521096229553, 'rewards/accuracies': 0.643750011920929, 'rewards/margins': 0.10426922887563705, 'logps/chosen': -13.411539077758789, 'logps/rejected': -28.496692657470703, 'logits/chosen': 2.375291109085083, 'logits/rejected': 2.5216994285583496, 'epoch': 0.51}
# {'loss': 0.6807, 'grad_norm': 7.350550651550293, 'learning_rate': 8.203389830508474e-07, 'rewards/chosen': -0.08898423612117767, 'rewards/rejected': -0.1502508968114853, 'rewards/accuracies': 0.6000000238418579, 'rewards/margins': 0.06126667186617851, 'logps/chosen': -14.75440502166748, 'logps/rejected': -28.827804565429688, 'logits/chosen': 2.4166178703308105, 'logits/rejected': 2.587463855743408, 'epoch': 0.54}
# {'loss': 0.6466, 'grad_norm': 5.764400005340576, 'learning_rate': 8.090395480225988e-07, 'rewards/chosen': -0.07390860468149185, 'rewards/rejected': -0.19531488418579102, 'rewards/accuracies': 0.625, 'rewards/margins': 0.12140625715255737, 'logps/chosen': -13.942060470581055, 'logps/rejected': -28.36594009399414, 'logits/chosen': 2.426621913909912, 'logits/rejected': 2.5550124645233154, 'epoch': 0.58}
# {'loss': 0.652, 'grad_norm': 7.712264537811279, 'learning_rate': 7.977401129943503e-07, 'rewards/chosen': -0.07133416831493378, 'rewards/rejected': -0.17779091000556946, 'rewards/accuracies': 0.643750011920929, 'rewards/margins': 0.1064567118883133, 'logps/chosen': -13.81452751159668, 'logps/rejected': -26.40139389038086, 'logits/chosen': 2.3714776039123535, 'logits/rejected': 2.5159335136413574, 'epoch': 0.61}
# {'loss': 0.6435, 'grad_norm': 5.927464962005615, 'learning_rate': 7.864406779661017e-07, 'rewards/chosen': -0.0619124174118042, 'rewards/rejected': -0.18744999170303345, 'rewards/accuracies': 0.6625000238418579, 'rewards/margins': 0.12553758919239044, 'logps/chosen': -13.09210205078125, 'logps/rejected': -28.938989639282227, 'logits/chosen': 2.393484592437744, 'logits/rejected': 2.5140905380249023, 'epoch': 0.64}
# {'loss': 0.6522, 'grad_norm': 6.327577590942383, 'learning_rate': 7.751412429378531e-07, 'rewards/chosen': -0.08704117685556412, 'rewards/rejected': -0.1991591900587082, 'rewards/accuracies': 0.6499999761581421, 'rewards/margins': 0.11211802810430527, 'logps/chosen': -13.723630905151367, 'logps/rejected': -28.4389705657959, 'logits/chosen': 2.247082233428955, 'logits/rejected': 2.4298298358917236, 'epoch': 0.68}
# {'loss': 0.6666, 'grad_norm': 10.064531326293945, 'learning_rate': 7.638418079096045e-07, 'rewards/chosen': -0.09132679551839828, 'rewards/rejected': -0.17133626341819763, 'rewards/accuracies': 0.59375, 'rewards/margins': 0.08000947535037994, 'logps/chosen': -13.62708854675293, 'logps/rejected': -28.023462295532227, 'logits/chosen': 2.2973473072052, 'logits/rejected': 2.4224517345428467, 'epoch': 0.71}
# {'loss': 0.6634, 'grad_norm': 5.99285888671875, 'learning_rate': 7.52542372881356e-07, 'rewards/chosen': -0.09387649595737457, 'rewards/rejected': -0.17818696796894073, 'rewards/accuracies': 0.6312500238418579, 'rewards/margins': 0.08431047201156616, 'logps/chosen': -13.461545944213867, 'logps/rejected': -28.805267333984375, 'logits/chosen': 2.398146152496338, 'logits/rejected': 2.5615668296813965, 'epoch': 0.75}
# {'loss': 0.6427, 'grad_norm': 5.4434943199157715, 'learning_rate': 7.412429378531073e-07, 'rewards/chosen': -0.0945260152220726, 'rewards/rejected': -0.22911112010478973, 'rewards/accuracies': 0.675000011920929, 'rewards/margins': 0.13458508253097534, 'logps/chosen': -13.987963676452637, 'logps/rejected': -29.785648345947266, 'logits/chosen': 2.313466787338257, 'logits/rejected': 2.4694578647613525, 'epoch': 0.78}
# {'loss': 0.6528, 'grad_norm': 8.276043891906738, 'learning_rate': 7.299435028248587e-07, 'rewards/chosen': -0.06066979840397835, 'rewards/rejected': -0.1719127595424652, 'rewards/accuracies': 0.6499999761581421, 'rewards/margins': 0.11124296486377716, 'logps/chosen': -13.322786331176758, 'logps/rejected': -28.474477767944336, 'logits/chosen': 2.248574733734131, 'logits/rejected': 2.4022669792175293, 'epoch': 0.81}
# {'loss': 0.6455, 'grad_norm': 6.554923057556152, 'learning_rate': 7.186440677966101e-07, 'rewards/chosen': -0.0863652378320694, 'rewards/rejected': -0.21946211159229279, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.1330968588590622, 'logps/chosen': -13.607667922973633, 'logps/rejected': -27.467565536499023, 'logits/chosen': 2.318514585494995, 'logits/rejected': 2.4716060161590576, 'epoch': 0.85}
# {'loss': 0.6571, 'grad_norm': 7.547388076782227, 'learning_rate': 7.073446327683616e-07, 'rewards/chosen': -0.06368230283260345, 'rewards/rejected': -0.16764722764492035, 'rewards/accuracies': 0.606249988079071, 'rewards/margins': 0.1039649248123169, 'logps/chosen': -13.43541431427002, 'logps/rejected': -27.681034088134766, 'logits/chosen': 2.322669506072998, 'logits/rejected': 2.4245314598083496, 'epoch': 0.88}
# {'loss': 0.6468, 'grad_norm': 6.202918529510498, 'learning_rate': 6.96045197740113e-07, 'rewards/chosen': -0.06736677139997482, 'rewards/rejected': -0.19758327305316925, 'rewards/accuracies': 0.6312500238418579, 'rewards/margins': 0.13021649420261383, 'logps/chosen': -12.406736373901367, 'logps/rejected': -28.162668228149414, 'logits/chosen': 2.186645746231079, 'logits/rejected': 2.3318233489990234, 'epoch': 0.92}
# {'loss': 0.6203, 'grad_norm': 5.789121150970459, 'learning_rate': 6.847457627118643e-07, 'rewards/chosen': -0.06637798249721527, 'rewards/rejected': -0.25458139181137085, 'rewards/accuracies': 0.731249988079071, 'rewards/margins': 0.18820340931415558, 'logps/chosen': -13.039196968078613, 'logps/rejected': -32.07158279418945, 'logits/chosen': 2.256171226501465, 'logits/rejected': 2.433483123779297, 'epoch': 0.95}
# {'loss': 0.6304, 'grad_norm': 8.128244400024414, 'learning_rate': 6.734463276836157e-07, 'rewards/chosen': -0.09878645837306976, 'rewards/rejected': -0.26404890418052673, 'rewards/accuracies': 0.6812499761581421, 'rewards/margins': 0.16526247560977936, 'logps/chosen': -14.381858825683594, 'logps/rejected': -29.919998168945312, 'logits/chosen': 2.2108094692230225, 'logits/rejected': 2.369892120361328, 'epoch': 0.98}
# {'loss': 0.6156, 'grad_norm': 5.471200466156006, 'learning_rate': 6.621468926553671e-07, 'rewards/chosen': -0.07484105974435806, 'rewards/rejected': -0.2538427710533142, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.17900171875953674, 'logps/chosen': -14.100512504577637, 'logps/rejected': -28.608402252197266, 'logits/chosen': 2.3065950870513916, 'logits/rejected': 2.4503703117370605, 'epoch': 1.02}
# {'loss': 0.6204, 'grad_norm': 7.447844505310059, 'learning_rate': 6.508474576271186e-07, 'rewards/chosen': -0.08904950320720673, 'rewards/rejected': -0.2949228882789612, 'rewards/accuracies': 0.706250011920929, 'rewards/margins': 0.20587339997291565, 'logps/chosen': -14.477770805358887, 'logps/rejected': -29.88614273071289, 'logits/chosen': 2.2309226989746094, 'logits/rejected': 2.37515926361084, 'epoch': 1.05}
# {'loss': 0.6094, 'grad_norm': 5.826766014099121, 'learning_rate': 6.3954802259887e-07, 'rewards/chosen': -0.026032060384750366, 'rewards/rejected': -0.2397572100162506, 'rewards/accuracies': 0.731249988079071, 'rewards/margins': 0.21372516453266144, 'logps/chosen': -11.873713493347168, 'logps/rejected': -26.23586082458496, 'logits/chosen': 2.1878228187561035, 'logits/rejected': 2.316798448562622, 'epoch': 1.08}
# {'loss': 0.6039, 'grad_norm': 8.953540802001953, 'learning_rate': 6.282485875706215e-07, 'rewards/chosen': -0.06823252886533737, 'rewards/rejected': -0.29998549818992615, 'rewards/accuracies': 0.71875, 'rewards/margins': 0.23175299167633057, 'logps/chosen': -14.111429214477539, 'logps/rejected': -26.6390380859375, 'logits/chosen': 2.2182703018188477, 'logits/rejected': 2.3477282524108887, 'epoch': 1.12}
# {'loss': 0.5958, 'grad_norm': 5.8493781089782715, 'learning_rate': 6.169491525423728e-07, 'rewards/chosen': -0.044239167124032974, 'rewards/rejected': -0.2958900034427643, 'rewards/accuracies': 0.7250000238418579, 'rewards/margins': 0.2516508400440216, 'logps/chosen': -13.255950927734375, 'logps/rejected': -29.481731414794922, 'logits/chosen': 2.275578022003174, 'logits/rejected': 2.424680233001709, 'epoch': 1.15}
# {'loss': 0.6171, 'grad_norm': 7.353651523590088, 'learning_rate': 6.056497175141243e-07, 'rewards/chosen': -0.11244694888591766, 'rewards/rejected': -0.31661590933799744, 'rewards/accuracies': 0.699999988079071, 'rewards/margins': 0.20416894555091858, 'logps/chosen': -14.44482707977295, 'logps/rejected': -31.1324462890625, 'logits/chosen': 2.2522592544555664, 'logits/rejected': 2.3809189796447754, 'epoch': 1.19}
# {'loss': 0.5997, 'grad_norm': 7.275363922119141, 'learning_rate': 5.943502824858757e-07, 'rewards/chosen': -0.08436412364244461, 'rewards/rejected': -0.32612818479537964, 'rewards/accuracies': 0.706250011920929, 'rewards/margins': 0.24176406860351562, 'logps/chosen': -13.978569030761719, 'logps/rejected': -31.49956703186035, 'logits/chosen': 2.186283588409424, 'logits/rejected': 2.3544888496398926, 'epoch': 1.22}
# {'loss': 0.5896, 'grad_norm': 8.348506927490234, 'learning_rate': 5.830508474576271e-07, 'rewards/chosen': -0.050774265080690384, 'rewards/rejected': -0.33023324608802795, 'rewards/accuracies': 0.737500011920929, 'rewards/margins': 0.2794589698314667, 'logps/chosen': -12.38532543182373, 'logps/rejected': -29.934839248657227, 'logits/chosen': 2.1499953269958496, 'logits/rejected': 2.3121750354766846, 'epoch': 1.25}
# {'loss': 0.6186, 'grad_norm': 6.086013317108154, 'learning_rate': 5.717514124293785e-07, 'rewards/chosen': -0.086459219455719, 'rewards/rejected': -0.2884751260280609, 'rewards/accuracies': 0.6937500238418579, 'rewards/margins': 0.2020159214735031, 'logps/chosen': -15.746835708618164, 'logps/rejected': -30.88724708557129, 'logits/chosen': 2.1959826946258545, 'logits/rejected': 2.348814010620117, 'epoch': 1.29}
# {'loss': 0.5838, 'grad_norm': 5.132711410522461, 'learning_rate': 5.6045197740113e-07, 'rewards/chosen': -0.04510498046875, 'rewards/rejected': -0.3450912535190582, 'rewards/accuracies': 0.7437499761581421, 'rewards/margins': 0.29998624324798584, 'logps/chosen': -12.529688835144043, 'logps/rejected': -29.758209228515625, 'logits/chosen': 2.151296854019165, 'logits/rejected': 2.3119659423828125, 'epoch': 1.32}
# {'loss': 0.6174, 'grad_norm': 7.234837532043457, 'learning_rate': 5.491525423728813e-07, 'rewards/chosen': -0.08636222034692764, 'rewards/rejected': -0.28119349479675293, 'rewards/accuracies': 0.706250011920929, 'rewards/margins': 0.1948312520980835, 'logps/chosen': -13.907308578491211, 'logps/rejected': -30.070911407470703, 'logits/chosen': 2.218564987182617, 'logits/rejected': 2.3550548553466797, 'epoch': 1.36}
# {'loss': 0.5798, 'grad_norm': 7.045517921447754, 'learning_rate': 5.378531073446327e-07, 'rewards/chosen': -0.07898552715778351, 'rewards/rejected': -0.3819926977157593, 'rewards/accuracies': 0.7124999761581421, 'rewards/margins': 0.30300718545913696, 'logps/chosen': -14.190709114074707, 'logps/rejected': -33.15471649169922, 'logits/chosen': 2.1401784420013428, 'logits/rejected': 2.3012654781341553, 'epoch': 1.39}
# {'loss': 0.5763, 'grad_norm': 5.513820171356201, 'learning_rate': 5.265536723163841e-07, 'rewards/chosen': -0.09574086964130402, 'rewards/rejected': -0.41960960626602173, 'rewards/accuracies': 0.78125, 'rewards/margins': 0.3238687217235565, 'logps/chosen': -15.120762825012207, 'logps/rejected': -33.75978088378906, 'logits/chosen': 2.2534570693969727, 'logits/rejected': 2.4033520221710205, 'epoch': 1.42}
# {'loss': 0.5761, 'grad_norm': 5.68411922454834, 'learning_rate': 5.152542372881356e-07, 'rewards/chosen': -0.014759929850697517, 'rewards/rejected': -0.32255998253822327, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3078000247478485, 'logps/chosen': -13.017680168151855, 'logps/rejected': -31.52462387084961, 'logits/chosen': 2.139343738555908, 'logits/rejected': 2.329934597015381, 'epoch': 1.46}
# {'loss': 0.6062, 'grad_norm': 5.500673294067383, 'learning_rate': 5.03954802259887e-07, 'rewards/chosen': -0.04698175936937332, 'rewards/rejected': -0.2814910113811493, 'rewards/accuracies': 0.75, 'rewards/margins': 0.23450925946235657, 'logps/chosen': -13.006474494934082, 'logps/rejected': -28.22223472595215, 'logits/chosen': 2.1487672328948975, 'logits/rejected': 2.2465176582336426, 'epoch': 1.49}
# {'loss': 0.5789, 'grad_norm': 7.459840297698975, 'learning_rate': 4.926553672316385e-07, 'rewards/chosen': -0.038139913231134415, 'rewards/rejected': -0.3475481867790222, 'rewards/accuracies': 0.737500011920929, 'rewards/margins': 0.3094082772731781, 'logps/chosen': -13.470738410949707, 'logps/rejected': -28.403827667236328, 'logits/chosen': 2.0845048427581787, 'logits/rejected': 2.2307190895080566, 'epoch': 1.53}
# {'loss': 0.6182, 'grad_norm': 9.20613956451416, 'learning_rate': 4.813559322033898e-07, 'rewards/chosen': -0.07582562416791916, 'rewards/rejected': -0.3010934293270111, 'rewards/accuracies': 0.6812499761581421, 'rewards/margins': 0.22526781260967255, 'logps/chosen': -13.336418151855469, 'logps/rejected': -29.29266357421875, 'logits/chosen': 2.175640821456909, 'logits/rejected': 2.3078067302703857, 'epoch': 1.56}
# {'loss': 0.5492, 'grad_norm': 6.003823280334473, 'learning_rate': 4.7005649717514123e-07, 'rewards/chosen': -0.02774367667734623, 'rewards/rejected': -0.38596656918525696, 'rewards/accuracies': 0.831250011920929, 'rewards/margins': 0.3582229018211365, 'logps/chosen': -12.296096801757812, 'logps/rejected': -30.287796020507812, 'logits/chosen': 2.074728488922119, 'logits/rejected': 2.2475829124450684, 'epoch': 1.59}
# {'loss': 0.5673, 'grad_norm': 5.733065128326416, 'learning_rate': 4.5875706214689266e-07, 'rewards/chosen': -0.07392154633998871, 'rewards/rejected': -0.42037302255630493, 'rewards/accuracies': 0.7562500238418579, 'rewards/margins': 0.3464514911174774, 'logps/chosen': -13.506750106811523, 'logps/rejected': -32.61480712890625, 'logits/chosen': 2.1731297969818115, 'logits/rejected': 2.3200020790100098, 'epoch': 1.63}
# {'loss': 0.533, 'grad_norm': 7.796138763427734, 'learning_rate': 4.4745762711864404e-07, 'rewards/chosen': -0.02630331739783287, 'rewards/rejected': -0.4364784359931946, 'rewards/accuracies': 0.831250011920929, 'rewards/margins': 0.410175085067749, 'logps/chosen': -13.369709968566895, 'logps/rejected': -33.09430694580078, 'logits/chosen': 2.0889389514923096, 'logits/rejected': 2.260652780532837, 'epoch': 1.66}
# {'loss': 0.5792, 'grad_norm': 8.361337661743164, 'learning_rate': 4.361581920903954e-07, 'rewards/chosen': -0.11281043291091919, 'rewards/rejected': -0.42744550108909607, 'rewards/accuracies': 0.731249988079071, 'rewards/margins': 0.3146350681781769, 'logps/chosen': -14.136624336242676, 'logps/rejected': -32.239200592041016, 'logits/chosen': 2.133913516998291, 'logits/rejected': 2.3024020195007324, 'epoch': 1.69}
# {'loss': 0.5855, 'grad_norm': 5.88944673538208, 'learning_rate': 4.2485875706214686e-07, 'rewards/chosen': -0.06948938965797424, 'rewards/rejected': -0.3694821894168854, 'rewards/accuracies': 0.7250000238418579, 'rewards/margins': 0.29999276995658875, 'logps/chosen': -13.4906005859375, 'logps/rejected': -31.904468536376953, 'logits/chosen': 2.097822666168213, 'logits/rejected': 2.274892807006836, 'epoch': 1.73}
# {'loss': 0.5885, 'grad_norm': 7.247652053833008, 'learning_rate': 4.1355932203389824e-07, 'rewards/chosen': -0.07174378633499146, 'rewards/rejected': -0.3708198666572571, 'rewards/accuracies': 0.7437499761581421, 'rewards/margins': 0.2990760803222656, 'logps/chosen': -13.597908020019531, 'logps/rejected': -29.590396881103516, 'logits/chosen': 2.139301300048828, 'logits/rejected': 2.259474039077759, 'epoch': 1.76}
# {'loss': 0.5607, 'grad_norm': 6.864294528961182, 'learning_rate': 4.0225988700564973e-07, 'rewards/chosen': -0.05359889194369316, 'rewards/rejected': -0.403177410364151, 'rewards/accuracies': 0.7875000238418579, 'rewards/margins': 0.34957852959632874, 'logps/chosen': -13.618471145629883, 'logps/rejected': -32.094512939453125, 'logits/chosen': 2.098137855529785, 'logits/rejected': 2.2679569721221924, 'epoch': 1.8}
# {'loss': 0.5629, 'grad_norm': 6.476764678955078, 'learning_rate': 3.909604519774011e-07, 'rewards/chosen': -0.08360795676708221, 'rewards/rejected': -0.45350462198257446, 'rewards/accuracies': 0.7124999761581421, 'rewards/margins': 0.36989665031433105, 'logps/chosen': -14.443763732910156, 'logps/rejected': -31.444042205810547, 'logits/chosen': 2.1234776973724365, 'logits/rejected': 2.2578141689300537, 'epoch': 1.83}
# {'loss': 0.5804, 'grad_norm': 8.00861644744873, 'learning_rate': 3.7966101694915254e-07, 'rewards/chosen': -0.07030458748340607, 'rewards/rejected': -0.3771302103996277, 'rewards/accuracies': 0.7437499761581421, 'rewards/margins': 0.30682557821273804, 'logps/chosen': -13.425341606140137, 'logps/rejected': -31.178939819335938, 'logits/chosen': 2.1545376777648926, 'logits/rejected': 2.3339545726776123, 'epoch': 1.86}
# {'loss': 0.577, 'grad_norm': 6.361344814300537, 'learning_rate': 3.683615819209039e-07, 'rewards/chosen': -0.036641694605350494, 'rewards/rejected': -0.3506370186805725, 'rewards/accuracies': 0.71875, 'rewards/margins': 0.3139953017234802, 'logps/chosen': -11.669992446899414, 'logps/rejected': -28.307964324951172, 'logits/chosen': 2.10347580909729, 'logits/rejected': 2.2518932819366455, 'epoch': 1.9}
# {'loss': 0.5631, 'grad_norm': 5.764658451080322, 'learning_rate': 3.5706214689265536e-07, 'rewards/chosen': -0.0842282623052597, 'rewards/rejected': -0.46334537863731384, 'rewards/accuracies': 0.71875, 'rewards/margins': 0.3791171610355377, 'logps/chosen': -14.571513175964355, 'logps/rejected': -32.809112548828125, 'logits/chosen': 2.170574188232422, 'logits/rejected': 2.324655055999756, 'epoch': 1.93}
# {'loss': 0.6046, 'grad_norm': 4.858672142028809, 'learning_rate': 3.4576271186440674e-07, 'rewards/chosen': -0.06364628672599792, 'rewards/rejected': -0.32187190651893616, 'rewards/accuracies': 0.6812499761581421, 'rewards/margins': 0.25822561979293823, 'logps/chosen': -12.720057487487793, 'logps/rejected': -28.671077728271484, 'logits/chosen': 2.0448412895202637, 'logits/rejected': 2.199737071990967, 'epoch': 1.97}
# {'loss': 0.5789, 'grad_norm': 8.829694747924805, 'learning_rate': 3.3446327683615817e-07, 'rewards/chosen': -0.06068822741508484, 'rewards/rejected': -0.3769940733909607, 'rewards/accuracies': 0.7124999761581421, 'rewards/margins': 0.31630587577819824, 'logps/chosen': -12.48166275024414, 'logps/rejected': -29.295795440673828, 'logits/chosen': 1.9618685245513916, 'logits/rejected': 2.1139891147613525, 'epoch': 2.0}
# {'loss': 0.566, 'grad_norm': 6.801031589508057, 'learning_rate': 3.2316384180790955e-07, 'rewards/chosen': -0.08622336387634277, 'rewards/rejected': -0.4299696981906891, 'rewards/accuracies': 0.768750011920929, 'rewards/margins': 0.3437463641166687, 'logps/chosen': -13.816645622253418, 'logps/rejected': -32.31873321533203, 'logits/chosen': 2.126546859741211, 'logits/rejected': 2.2739949226379395, 'epoch': 2.03}
# {'loss': 0.5495, 'grad_norm': 6.643407821655273, 'learning_rate': 3.1186440677966104e-07, 'rewards/chosen': -0.040778834372758865, 'rewards/rejected': -0.41890010237693787, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.3781212568283081, 'logps/chosen': -13.72142505645752, 'logps/rejected': -29.455368041992188, 'logits/chosen': 2.115265369415283, 'logits/rejected': 2.2372519969940186, 'epoch': 2.07}
# {'loss': 0.5733, 'grad_norm': 6.919539928436279, 'learning_rate': 3.005649717514124e-07, 'rewards/chosen': -0.08749421685934067, 'rewards/rejected': -0.4257221221923828, 'rewards/accuracies': 0.7562500238418579, 'rewards/margins': 0.33822789788246155, 'logps/chosen': -13.019569396972656, 'logps/rejected': -31.138824462890625, 'logits/chosen': 2.0363895893096924, 'logits/rejected': 2.205148220062256, 'epoch': 2.1}
# {'loss': 0.5547, 'grad_norm': 6.713970184326172, 'learning_rate': 2.8926553672316386e-07, 'rewards/chosen': -0.04757985472679138, 'rewards/rejected': -0.43417781591415405, 'rewards/accuracies': 0.7875000238418579, 'rewards/margins': 0.38659802079200745, 'logps/chosen': -13.105311393737793, 'logps/rejected': -29.772449493408203, 'logits/chosen': 2.072012424468994, 'logits/rejected': 2.183922290802002, 'epoch': 2.14}
# {'loss': 0.5533, 'grad_norm': 6.142385005950928, 'learning_rate': 2.7796610169491524e-07, 'rewards/chosen': -0.05688043683767319, 'rewards/rejected': -0.4469706416130066, 'rewards/accuracies': 0.768750011920929, 'rewards/margins': 0.3900901973247528, 'logps/chosen': -12.774130821228027, 'logps/rejected': -31.684185028076172, 'logits/chosen': 2.0392189025878906, 'logits/rejected': 2.186983585357666, 'epoch': 2.17}
# {'loss': 0.5494, 'grad_norm': 5.256424903869629, 'learning_rate': 2.6666666666666667e-07, 'rewards/chosen': -0.03604362532496452, 'rewards/rejected': -0.43297886848449707, 'rewards/accuracies': 0.78125, 'rewards/margins': 0.39693525433540344, 'logps/chosen': -13.042793273925781, 'logps/rejected': -29.91636085510254, 'logits/chosen': 2.073096752166748, 'logits/rejected': 2.206127166748047, 'epoch': 2.2}
# {'loss': 0.5133, 'grad_norm': 6.700985431671143, 'learning_rate': 2.5536723163841805e-07, 'rewards/chosen': -0.02601749077439308, 'rewards/rejected': -0.5167554616928101, 'rewards/accuracies': 0.8374999761581421, 'rewards/margins': 0.4907379746437073, 'logps/chosen': -12.571746826171875, 'logps/rejected': -29.839645385742188, 'logits/chosen': 1.9857219457626343, 'logits/rejected': 2.1898648738861084, 'epoch': 2.24}
# {'loss': 0.5438, 'grad_norm': 7.668890476226807, 'learning_rate': 2.440677966101695e-07, 'rewards/chosen': -0.08938778936862946, 'rewards/rejected': -0.5278221368789673, 'rewards/accuracies': 0.768750011920929, 'rewards/margins': 0.43843430280685425, 'logps/chosen': -13.854960441589355, 'logps/rejected': -33.91619873046875, 'logits/chosen': 2.0482254028320312, 'logits/rejected': 2.2084908485412598, 'epoch': 2.27}
# {'loss': 0.5444, 'grad_norm': 5.870182514190674, 'learning_rate': 2.327683615819209e-07, 'rewards/chosen': -0.08254411816596985, 'rewards/rejected': -0.5148030519485474, 'rewards/accuracies': 0.78125, 'rewards/margins': 0.4322589039802551, 'logps/chosen': -13.746053695678711, 'logps/rejected': -31.379714965820312, 'logits/chosen': 2.018645763397217, 'logits/rejected': 2.1645874977111816, 'epoch': 2.31}
# {'loss': 0.5609, 'grad_norm': 11.06429672241211, 'learning_rate': 2.214689265536723e-07, 'rewards/chosen': -0.09286296367645264, 'rewards/rejected': -0.4690205454826355, 'rewards/accuracies': 0.7749999761581421, 'rewards/margins': 0.3761575222015381, 'logps/chosen': -13.909811019897461, 'logps/rejected': -32.0262565612793, 'logits/chosen': 2.0645978450775146, 'logits/rejected': 2.2108871936798096, 'epoch': 2.34}
# {'loss': 0.5337, 'grad_norm': 7.462802410125732, 'learning_rate': 2.101694915254237e-07, 'rewards/chosen': -0.05471330136060715, 'rewards/rejected': -0.5078333020210266, 'rewards/accuracies': 0.8374999761581421, 'rewards/margins': 0.4531199336051941, 'logps/chosen': -12.925397872924805, 'logps/rejected': -32.04969024658203, 'logits/chosen': 2.0440545082092285, 'logits/rejected': 2.2116684913635254, 'epoch': 2.37}
# {'loss': 0.551, 'grad_norm': 5.743225574493408, 'learning_rate': 1.9887005649717514e-07, 'rewards/chosen': -0.05650259926915169, 'rewards/rejected': -0.4575514793395996, 'rewards/accuracies': 0.768750011920929, 'rewards/margins': 0.4010488986968994, 'logps/chosen': -12.744638442993164, 'logps/rejected': -30.216014862060547, 'logits/chosen': 1.9739938974380493, 'logits/rejected': 2.1299281120300293, 'epoch': 2.41}
# {'loss': 0.5608, 'grad_norm': 8.633058547973633, 'learning_rate': 1.8757062146892655e-07, 'rewards/chosen': -0.11749830096960068, 'rewards/rejected': -0.4692820906639099, 'rewards/accuracies': 0.7749999761581421, 'rewards/margins': 0.3517838418483734, 'logps/chosen': -15.752252578735352, 'logps/rejected': -32.737762451171875, 'logits/chosen': 2.0963406562805176, 'logits/rejected': 2.237100839614868, 'epoch': 2.44}
# {'loss': 0.5326, 'grad_norm': 6.958573341369629, 'learning_rate': 1.7627118644067796e-07, 'rewards/chosen': -0.04181595519185066, 'rewards/rejected': -0.47524070739746094, 'rewards/accuracies': 0.793749988079071, 'rewards/margins': 0.43342477083206177, 'logps/chosen': -13.098895072937012, 'logps/rejected': -31.058298110961914, 'logits/chosen': 1.9829117059707642, 'logits/rejected': 2.1352882385253906, 'epoch': 2.47}
# {'loss': 0.5348, 'grad_norm': 7.061657428741455, 'learning_rate': 1.6497175141242937e-07, 'rewards/chosen': -0.05477029085159302, 'rewards/rejected': -0.5001708269119263, 'rewards/accuracies': 0.800000011920929, 'rewards/margins': 0.4454004764556885, 'logps/chosen': -14.234098434448242, 'logps/rejected': -34.3128547668457, 'logits/chosen': 2.0994644165039062, 'logits/rejected': 2.2763373851776123, 'epoch': 2.51}
# {'loss': 0.5199, 'grad_norm': 6.357748031616211, 'learning_rate': 1.536723163841808e-07, 'rewards/chosen': -0.027816176414489746, 'rewards/rejected': -0.5041510462760925, 'rewards/accuracies': 0.8062499761581421, 'rewards/margins': 0.47633489966392517, 'logps/chosen': -13.779054641723633, 'logps/rejected': -30.86698341369629, 'logits/chosen': 2.0703113079071045, 'logits/rejected': 2.196951389312744, 'epoch': 2.54}
# {'loss': 0.5525, 'grad_norm': 5.2866716384887695, 'learning_rate': 1.423728813559322e-07, 'rewards/chosen': -0.10155089199542999, 'rewards/rejected': -0.5422202348709106, 'rewards/accuracies': 0.737500011920929, 'rewards/margins': 0.44066929817199707, 'logps/chosen': -14.767095565795898, 'logps/rejected': -34.331844329833984, 'logits/chosen': 2.0459914207458496, 'logits/rejected': 2.1811366081237793, 'epoch': 2.58}
# {'loss': 0.5317, 'grad_norm': 5.511175632476807, 'learning_rate': 1.3107344632768362e-07, 'rewards/chosen': -0.07360605895519257, 'rewards/rejected': -0.5118554830551147, 'rewards/accuracies': 0.824999988079071, 'rewards/margins': 0.438249409198761, 'logps/chosen': -13.307565689086914, 'logps/rejected': -31.400802612304688, 'logits/chosen': 1.9865134954452515, 'logits/rejected': 2.128566265106201, 'epoch': 2.61}
# {'loss': 0.5157, 'grad_norm': 5.599174499511719, 'learning_rate': 1.1977401129943503e-07, 'rewards/chosen': -0.03725336864590645, 'rewards/rejected': -0.5574238300323486, 'rewards/accuracies': 0.793749988079071, 'rewards/margins': 0.5201703906059265, 'logps/chosen': -14.189738273620605, 'logps/rejected': -34.263282775878906, 'logits/chosen': 2.0597262382507324, 'logits/rejected': 2.220000743865967, 'epoch': 2.64}
# {'loss': 0.5201, 'grad_norm': 5.7180609703063965, 'learning_rate': 1.0847457627118643e-07, 'rewards/chosen': -0.10729081928730011, 'rewards/rejected': -0.5924345254898071, 'rewards/accuracies': 0.7875000238418579, 'rewards/margins': 0.4851437211036682, 'logps/chosen': -13.960790634155273, 'logps/rejected': -35.274322509765625, 'logits/chosen': 2.0536532402038574, 'logits/rejected': 2.229146718978882, 'epoch': 2.68}
# {'loss': 0.5155, 'grad_norm': 6.9315972328186035, 'learning_rate': 9.717514124293785e-08, 'rewards/chosen': -0.041474565863609314, 'rewards/rejected': -0.5569528341293335, 'rewards/accuracies': 0.831250011920929, 'rewards/margins': 0.5154783129692078, 'logps/chosen': -12.116436958312988, 'logps/rejected': -32.08245086669922, 'logits/chosen': 1.995301604270935, 'logits/rejected': 2.170039653778076, 'epoch': 2.71}
# {'loss': 0.562, 'grad_norm': 6.0014472007751465, 'learning_rate': 8.587570621468926e-08, 'rewards/chosen': -0.059610895812511444, 'rewards/rejected': -0.433870404958725, 'rewards/accuracies': 0.737500011920929, 'rewards/margins': 0.3742595613002777, 'logps/chosen': -12.665971755981445, 'logps/rejected': -29.04852294921875, 'logits/chosen': 2.0078256130218506, 'logits/rejected': 2.170050621032715, 'epoch': 2.75}
# {'loss': 0.5215, 'grad_norm': 5.921777725219727, 'learning_rate': 7.457627118644068e-08, 'rewards/chosen': -0.11963723599910736, 'rewards/rejected': -0.6002390384674072, 'rewards/accuracies': 0.800000011920929, 'rewards/margins': 0.4806017279624939, 'logps/chosen': -14.496365547180176, 'logps/rejected': -32.627113342285156, 'logits/chosen': 2.0332465171813965, 'logits/rejected': 2.161541700363159, 'epoch': 2.78}
# {'loss': 0.5594, 'grad_norm': 6.426346778869629, 'learning_rate': 6.327683615819209e-08, 'rewards/chosen': -0.05265643447637558, 'rewards/rejected': -0.40954867005348206, 'rewards/accuracies': 0.762499988079071, 'rewards/margins': 0.35689225792884827, 'logps/chosen': -12.968366622924805, 'logps/rejected': -29.688892364501953, 'logits/chosen': 2.0726497173309326, 'logits/rejected': 2.217183828353882, 'epoch': 2.81}
# {'loss': 0.5469, 'grad_norm': 4.046971321105957, 'learning_rate': 5.19774011299435e-08, 'rewards/chosen': -0.07109790295362473, 'rewards/rejected': -0.4946172833442688, 'rewards/accuracies': 0.7562500238418579, 'rewards/margins': 0.4235193729400635, 'logps/chosen': -14.330541610717773, 'logps/rejected': -33.60875701904297, 'logits/chosen': 2.084627866744995, 'logits/rejected': 2.2209677696228027, 'epoch': 2.85}
# {'loss': 0.5411, 'grad_norm': 6.36799430847168, 'learning_rate': 4.067796610169491e-08, 'rewards/chosen': -0.041465673595666885, 'rewards/rejected': -0.47107845544815063, 'rewards/accuracies': 0.7875000238418579, 'rewards/margins': 0.42961278557777405, 'logps/chosen': -13.050621032714844, 'logps/rejected': -31.28753089904785, 'logits/chosen': 1.9830421209335327, 'logits/rejected': 2.138371467590332, 'epoch': 2.88}
# {'loss': 0.5447, 'grad_norm': 6.247906684875488, 'learning_rate': 2.9378531073446327e-08, 'rewards/chosen': -0.0980248898267746, 'rewards/rejected': -0.5421995520591736, 'rewards/accuracies': 0.75, 'rewards/margins': 0.4441746175289154, 'logps/chosen': -14.596247673034668, 'logps/rejected': -33.524261474609375, 'logits/chosen': 2.0546329021453857, 'logits/rejected': 2.222374439239502, 'epoch': 2.92}
# {'loss': 0.5442, 'grad_norm': 6.06243371963501, 'learning_rate': 1.807909604519774e-08, 'rewards/chosen': -0.06925027072429657, 'rewards/rejected': -0.469827800989151, 'rewards/accuracies': 0.8187500238418579, 'rewards/margins': 0.40057748556137085, 'logps/chosen': -13.22050952911377, 'logps/rejected': -29.372325897216797, 'logits/chosen': 2.0666775703430176, 'logits/rejected': 2.2061100006103516, 'epoch': 2.95}
# {'loss': 0.5369, 'grad_norm': 5.633999824523926, 'learning_rate': 6.779661016949152e-09, 'rewards/chosen': -0.07948435097932816, 'rewards/rejected': -0.5299318432807922, 'rewards/accuracies': 0.737500011920929, 'rewards/margins': 0.4504474699497223, 'logps/chosen': -13.870153427124023, 'logps/rejected': -32.54595947265625, 'logits/chosen': 2.0360724925994873, 'logits/rejected': 2.1918997764587402, 'epoch': 2.98}
# {'train_runtime': 936.5972, 'train_samples_per_second': 15.093, 'train_steps_per_second': 0.945, 'train_loss': 0.5979835273182325, 'epoch': 3.0}
# 100%|█████████████████████████████████████████| 885/885 [15:36<00:00,  1.06s/it]
# [rank0]:[W1129 13:30:51.159433350 ProcessGroupNCCL.cpp:1496] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_path = "./dpo-vit5-final"  # đường dẫn model bạn lưu

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path).to("cuda")

def translate_vi_en(sentence):
    input_text = f"vi_en: {sentence}"
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")

    output = model.generate(
        **inputs,
        max_length=128,
        num_beams=5,
        early_stopping=True,
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# ----- Test -----
test_sentences = [
    "Đêm trường trung cổ là nỗi ám ảnh kinh hoàng của lịch sử châu Âu",
    "Chùa Một Cột được xây dựng vào năm 1049.",
    "Trường Đại học Bách Khoa là một trường nổi tiếng.",
]

for s in test_sentences:
    print("VI:", s)
    print("EN:", translate_vi_en(s))
    print("-----")
# Out:
# VI: Đêm trường trung cổ là nỗi ám ảnh kinh hoàng của lịch sử châu Âu
# EN: Medieval school night is the horrific obsession of European history
# -----
# VI: Chùa Một Cột được xây dựng vào năm 1049.
# EN: The One Column Pagoda was built in 1049.
# -----
# VI: Trường Đại học Bách Khoa là một trường nổi tiếng.
# EN: The Polytechnic University is a well-known school.
# -----

# %% [markdown]
# ##### Push DPO to HF

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/dpo-nonsyn-vit5-final.zip
# Out:
# Archive:  /content/drive/MyDrive/dpo-nonsyn-vit5-final.zip
#    creating: dpo-nonsyn-vit5-final/
#   inflating: dpo-nonsyn-vit5-final/config.json
#   inflating: dpo-nonsyn-vit5-final/generation_config.json
#   inflating: dpo-nonsyn-vit5-final/model.safetensors
#   inflating: dpo-nonsyn-vit5-final/special_tokens_map.json
#   inflating: dpo-nonsyn-vit5-final/spiece.model
#   inflating: dpo-nonsyn-vit5-final/tokenizer.json
#   inflating: dpo-nonsyn-vit5-final/tokenizer_config.json
#   inflating: dpo-nonsyn-vit5-final/training_args.bin

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_path = "/content/dpo-nonsyn-vit5-final"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path).to("cuda")

text = "vi_en: Đêm trường trung cổ là nỗi ám ảnh kinh hoàng của lịch sử châu Âu"
inputs = tokenizer(text, return_tensors="pt").to("cuda")
output = model.generate(
    **inputs,
    max_length=128,
    num_beams=5,
    early_stopping=True,
)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Medieval school night is the horrific obsession of European history

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from huggingface_hub import create_repo
create_repo("machine-translation-dpo-v1-data400k", private=True)
# Out:
# RepoUrl('https://huggingface.co/tnguyen20604/machine-translation-dpo-v1-data400k', endpoint='https://huggingface.co', repo_type='model', repo_id='tnguyen20604/machine-translation-dpo-v1-data400k')

# %%
from huggingface_hub import upload_folder

upload_folder(
    repo_id="tnguyen20604/machine-translation-dpo-v1-data400k",
    folder_path="dpo-nonsyn-vit5-final",
    commit_message="Upload model"
)
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...n-vit5-final/spiece.model: 100%|##########|  820kB /  820kB
#   ...5-final/model.safetensors:   0%|          |  555kB /  904MB
#   ...5-final/training_args.bin:   2%|1         |   109B / 6.39kB
# CommitInfo(commit_url='https://huggingface.co/tnguyen20604/machine-translation-dpo-v1-data400k/commit/e16d8a86a40ad77653dd4d18e60f34b4d57fe359', commit_message='Upload model', commit_description='', oid='e16d8a86a40ad77653dd4d18e60f34b4d57fe359', pr_url=None, repo_url=RepoUrl('https://huggingface.co/tnguyen20604/machine-translation-dpo-v1-data400k', endpoint='https://huggingface.co', repo_type='model', repo_id='tnguyen20604/machine-translation-dpo-v1-data400k'), pr_revision=None, pr_num=None)

# %% [markdown]
# #### Load model

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("tnguyen20604/machine-translation-dpo-v1-data400k")

model = AutoModelForSeq2SeqLM.from_pretrained(
    "tnguyen20604/machine-translation-dpo-v1-data400k",
    torch_dtype="float16",
    device_map="auto"
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/820k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/904M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/122 [00:00<?, ?B/s]

# %% [markdown]
# #### Evaluate

# %% [markdown]
# ##### a)

# %%
# !pip install evaluate
# !pip install sacrebleu
# !pip install rouge_score sacrebleu
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.2 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2.0.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (6.0.2)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 7.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.2.0 sacrebleu-2.5.1
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.12/dist-packages (2.5.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (6.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=f7e619d8211c6ad231547888e4175b200b62f967de29ee8532c2a0c9f9a4da01
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# !pip install pyarrow==14.0.1
# !pip install datasets==2.19.1
# !pip install evaluate==0.4.1
# Out:
# Collecting pyarrow==14.0.1
#   Downloading pyarrow-14.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.12/dist-packages (from pyarrow==14.0.1) (2.0.2)
# Downloading pyarrow-14.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (38.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 20.1 MB/s eta 0:00:00
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.29.1 requires pyarrow>=15.0.2, but you have pyarrow 14.0.1 which is incompatible.
# datasets 4.0.0 requires pyarrow>=15.0.0, but you have pyarrow 14.0.1 which is incompatible.
# cudf-cu12 25.10.0 requires pyarrow>=15.0.0; platform_machine == "x86_64", but you have pyarrow 14.0.1 which is incompatible.
# Successfully installed pyarrow-14.0.1
# Collecting datasets==2.19.1
#   Downloading datasets-2.19.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (2.0.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (14.0.1)
# Collecting pyarrow-hotfix (from datasets==2.19.1)
#   Downloading pyarrow_hotfix-0.7-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (0.70.16)
# Collecting fsspec<=2024.3.1,>=2023.1.0 (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets==2.19.1)
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (3.13.2)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.19.1) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.19.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.19.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.19.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.19.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.19.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.19.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.19.1) (1.22.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets==2.19.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets==2.19.1) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.19.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.19.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.19.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.19.1) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.19.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.19.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.19.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.19.1) (1.17.0)
# Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 12.6 MB/s eta 0:00:00
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 12.1 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.7-py3-none-any.whl (7.9 kB)
# Installing collected packages: pyarrow-hotfix, fsspec, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.29.1 requires pyarrow>=15.0.2, but you have pyarrow 14.0.1 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.3.1 which is incompatible.
# cudf-cu12 25.10.0 requires pyarrow>=15.0.0; platform_machine == "x86_64", but you have pyarrow 14.0.1 which is incompatible.
# Successfully installed datasets-2.19.1 fsspec-2024.3.1 pyarrow-hotfix-0.7
# Collecting evaluate==0.4.1
#   Downloading evaluate-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (2.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate==0.4.1) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate==0.4.1) (25.0)
# Collecting responses<0.19 (from evaluate==0.4.1)
#   Downloading responses-0.18.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate==0.4.1) (3.20.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate==0.4.1) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate==0.4.1) (0.7)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate==0.4.1) (3.13.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate==0.4.1) (6.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate==0.4.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate==0.4.1) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate==0.4.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate==0.4.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate==0.4.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate==0.4.1) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate==0.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate==0.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate==0.4.1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.1) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate==0.4.1) (1.17.0)
# Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.1 MB/s eta 0:00:00
# Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Installing collected packages: responses, evaluate
#   Attempting uninstall: evaluate
#     Found existing installation: evaluate 0.4.6
#     Uninstalling evaluate-0.4.6:
#       Successfully uninstalled evaluate-0.4.6
# Successfully installed evaluate-0.4.1 responses-0.18.0

# %%
import evaluate

# %%
def tokenize_fn(batch):
    model_inputs = tokenizer(
        batch["input_text"],
        max_length=64,
        padding="max_length",
        truncation=True,
    )

    labels = tokenizer(
        batch["target_text"],
        max_length=64,
        padding="max_length",
        truncation=True,
    )["input_ids"]

    labels = [
        [(t if t != tokenizer.pad_token_id else -100) for t in label]
        for label in labels
    ]

    model_inputs["labels"] = labels
    return model_inputs

# train_tok = ds_train.map(tokenize_fn, batched=True, remove_columns=ds_train_bi.column_names)
# valid_tok = ds_valid.map(tokenize_fn, batched=True, remove_columns=ds_valid_bi.column_names)
test_tok  = ds_vi2en_test.map(tokenize_fn,  batched=True, remove_columns=ds_vi2en_test.column_names)
# Out:
# Map:   0%|          | 0/48569 [00:00<?, ? examples/s]

# %%
def batch_generate(model, tokenizer, texts, batch_size=32):
    preds = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]

        inputs = tokenizer(
            batch,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=64
        ).to("cuda")

        outputs = model.generate(
            **inputs,
            max_length=64,
            num_beams=1   # nhanh nhất
        )

        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        preds.extend(decoded)

    return preds

# %%
# Chuẩn bị dữ liệu
texts = [item["input_text"] for item in ds_vi2en_test]
refs  = [item["target_text"] for item in ds_vi2en_test]

# Generate
preds = batch_generate(model, tokenizer, texts, batch_size=32)

# %%
bleu = evaluate.load("sacrebleu")
chrf = evaluate.load("chrf")
rouge = evaluate.load("rouge")

bleu_res = bleu.compute(predictions=preds, references=refs)
chrf_res = chrf.compute(predictions=preds, references=refs)
rouge_res = rouge.compute(predictions=preds, references=refs)

print("BLEU:", bleu_res)
print("chrF:", chrf_res)
print("ROUGE:", rouge_res)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# BLEU: {'score': 38.59884350933488, 'counts': [758212, 492423, 348347, 254302], 'totals': [1080005, 1031436, 982868, 934477], 'precisions': [70.20448979402873, 47.741498260677346, 35.441890467489024, 27.21329684946767], 'bp': 0.9103000155541592, 'sys_len': 1080005, 'ref_len': 1181505}
# chrF: {'score': 60.70558025881474, 'char_order': 6, 'word_order': 0, 'beta': 2}
# ROUGE: {'rouge1': np.float64(0.6484330060456176), 'rouge2': np.float64(0.4290706521531863), 'rougeL': np.float64(0.6221217502289262), 'rougeLsum': np.float64(0.6221153898547964)}

# %%
# metric = evaluate.load("sacrebleu")

# def postprocess_text(preds, labels):
#     preds = [pred.strip() for pred in preds]
#     labels = [[label.strip()] for label in labels]

#     return preds, labels


# def compute_metrics(eval_preds):
#     preds, labels = eval_preds
#     if isinstance(preds, tuple):
#         preds = preds[0]
#     decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

#     labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
#     decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

#     decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

#     result = metric.compute(predictions=decoded_preds, references=decoded_labels)
#     result = {"bleu": result["score"]}

#     prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
#     result["gen_len"] = np.mean(prediction_lens)
#     result = {k: round(v, 4) for k, v in result.items()}
#     return result

# %%
# from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq

# training_args = Seq2SeqTrainingArguments(
#     output_dir="./nlp_mt_endterm_v4_data400k",
#     eval_strategy="steps",
#     eval_steps=20000,

#     save_strategy="epoch",
#     push_to_hub=True,
#     hub_model_id="tnguyen20604/nlp_mt_endterm_v4_data400k",
#     hub_strategy="every_save",
#     hub_private_repo=False,

#     logging_strategy="steps",
#     logging_steps=20000,

#     per_device_train_batch_size=16,
#     per_device_eval_batch_size=16,
#     gradient_accumulation_steps=2,

#     num_train_epochs=3,
#     learning_rate=1e-4,
#     warmup_ratio=0.05,
#     label_smoothing_factor=0.1,
#     weight_decay=0.01,


#     fp16=True,
#     report_to="none",
#     run_name="vit5_en_vi_ft",
#     group_by_length=True,
#     # gradient_checkpointing=True,
#     predict_with_generate=True,
# )

# %%
# data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# trainer = Seq2SeqTrainer(
#     model=model,
#     args=training_args,
#     eval_dataset=test_tok,
#     tokenizer=tokenizer,
#     data_collator=data_collator,
#     compute_metrics=compute_metrics
# )

# %%
# test_results = trainer.evaluate(eval_dataset=test_tok)

# %%
# test_loss = test_results["eval_loss"]
# test_ppl = math.exp(test_loss)
# print("Test Perplexity:", test_ppl)

# %% [markdown]
# ##### b)

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="key")
gemini_model = genai.GenerativeModel("gemini-2.5-flash")

# %%
# import google.generativeai as genai
# from google.colab import userdata

# # Get the API key from Colab secrets
# # GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# # Configure the Gemini API
# # genai.configure(api_key=GOOGLE_API_KEY)

# try:
#     print("Available Gemini models:")
#     for m in genai.list_models():
#         if 'generateContent' in m.supported_generation_methods:
#             print(f"- {m.name}")
# except Exception as e:
#     print(f"An error occurred while fetching models: {e}")

# %%
evaluation_prompt = """
You are an expert evaluator for machine translation.

Evaluate the translation on:
- Adequacy (meaning preserved)
- Fluency (naturalness)
- Faithfulness (no hallucination)

Score the translation from 0 to 10.

Return ONLY a JSON object:
{{"score": <number>, "comment": "<short explanation>"}}

[Source]: "{src}"
[Prediction]: "{pred}"
[Reference]: "{ref}"
"""

# %%
import json
import re

def extract_json(text):
    match = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if match:
        try:
            return json.loads(match.group())
        except:
            return {"score": None, "comment": "JSON parse failed", "raw": text}
    return {"score": None, "comment": "No JSON found", "raw": text}

# %%
def llm_evaluate(src, pred, ref):
    prompt = evaluation_prompt.format(src=src, pred=pred, ref=ref)
    response = gemini_model.generate_content(prompt).text
    return extract_json(response)

# %%
# print(ds_test_bi[0])
# type(ds_test_bi[0])

# %%
samples = ds_vi2en_test.select(range(200))
# samples = list(ds_test_bi.values())

llm_scores = []
llm_comments = []

for item in samples:
    src = item["input_text"]
    ref = item["target_text"]

    pred = batch_generate(model, tokenizer, [src])[0]

    result = llm_evaluate(src, pred, ref)
    llm_scores.append(result["score"])
    llm_comments.append(result.get("comment", ""))

# %%
import numpy as np

clean_scores = [s for s in llm_scores if s is not None]

final_score = np.nanmean(clean_scores)
print("LLM-based Score:", final_score)
print("LLM-based Comments:", llm_comments)
# Out:
# LLM-based Score: 7.215
# LLM-based Comments: ["Meaning is largely preserved, but the translation is literal and lacks naturalness, especially in specialized police terminology like 'theft and murder board' and 'Higher Criminal Unit'.", 'The translation is perfectly adequate, fluent, and faithful, accurately capturing the meaning and informal, reassuring tone of the source, including the future tense.', "Excellent translation. All meaning is preserved, the output is perfectly fluent and natural, and there is no hallucination. It matches the reference very closely with only a synonymous word choice ('signifies' instead of 'denotes').", 'The translation for the first part ("He stayed, trying") is accurate and fluent. However, \'đừng đánh động tới cô bé\' is mistranslated as \'not to touch her,\' which misses the nuance of disturbing or engaging and significantly alters the intended meaning of the second clause. Adequacy is low for the latter half, despite good fluency.', "The translation is highly accurate, fluent, and faithfully preserves the original meaning. It even improves upon the provided reference in terms of faithfulness to the source's singular noun and tense.", "Excellent fluency and largely accurate meaning. 'Mọi người' (everyone/all people) was translated as 'you', which is a minor loss in precision, but otherwise the translation is very natural and faithful.", 'The translation is perfect, accurately conveying all meaning from the source with excellent fluency and faithfulness. It matches the reference exactly.', "The translation is highly accurate and fluent. It preserves the meaning well. The only minor point is translating 'nhiều hơn nữa' as 'and more' instead of 'and many more,' which slightly under-translates the quantity.", "Adequacy is significantly impacted by the mistranslation of 'hôn ước' (engagement/marriage promise) as 'a marriage'. Fluency suffers from awkward phrasing and the ungrammatical 'We and her'.", 'Excellent translation, accurately preserving all meaning from the source and maintaining high fluency. The phrasing is natural and faithful to the original intent.', "The translation is highly fluent and faithful, accurately conveying the literal meaning of the source. The phrase 'theo một cách nghệ thuật' is translated naturally as 'in an artistic way.' However, the reference suggests a more specific interpretation of 'nghệ thuật' as a location ('Fine Arts wing'), which the prediction misses, slightly impacting adequacy if that nuance was intended.", "The translation is severely incomplete at the end, omitting the crucial information 'vaccinated' and leaving the sentence dangling. It also mistranslates 'não mô cầu' (meningococcal) as 'meningeal', which is a medical inaccuracy.", 'The translation perfectly preserves the meaning, is highly fluent, and completely faithful to the source text.', "The translation is highly accurate and fluent, capturing the core meaning effectively. It only slightly understates the intensity of 'rất khó' by translating it as 'difficult' instead of 'very difficult' or 'so hard'.", "The translation suffers from a critical misinterpretation: 'encouraging corporate taxes' reverses the intended meaning of 'khuyến khích thuế doanh nghiệp' (tax incentives/reductions). 'Credit income taxes' is also awkward and less fluent than 'income tax credits'.", "Awkward phrasing ('gave her home' instead of 'sent her home') and a critical truncation at the end ('in a serious shock th') significantly impact fluency and completeness.", "The translation contains a major error, rendering 'con người' (humanity) as 'the man,' which fundamentally changes the target of the lawsuit. 'Ong Citizen' is also unnatural phrasing.", 'The translation is highly accurate, fluent, and preserves the full meaning of the source text perfectly. Small stylistic differences with the reference do not impact quality.', "The translation is highly accurate and faithful to the source meaning. The only minor point is the slightly less natural open ...
